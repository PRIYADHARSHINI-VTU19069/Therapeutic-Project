# %% [markdown]
# #circle the word

# %%
#20
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Define a function to create and save the plots
def create_plot(words, title, color, pdf):
    # Reshape the words into a 10x8 matrix
    words_matrix = np.array(words).reshape(10, 8)

    # Set up the plot
    fig, ax = plt.subplots(figsize=(12, 12))

    # Set font properties with a monospaced font
    fontdict = {'fontsize': 20, 'color': color, 'family': 'monospace'}

    # Remove axes
    ax.axis('off')

    # Add the words to the plot with adjusted alignment and spacing
    x_spacing = 0.5  # Increase horizontal spacing
    y_spacing = 0.5# Increase vertical spacing
    for i in range(words_matrix.shape[0]):
        for j in range(words_matrix.shape[1]):
            ax.text(j * x_spacing, -i * y_spacing, words_matrix[i, j], ha='center', va='center', fontdict=fontdict)

    # Adjust the plot limits to add spacing between words
    ax.set_xlim(-0.5, 7.5 * x_spacing)
    ax.set_ylim(-9.5 * y_spacing, 0.5 * y_spacing)
    # Add title
    plt.title(title, fontsize=20, color=color, pad=20)

    # Save the plot to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Define the words in rows and columns for each plot
words_list = [
    [
        "goat", "weak", "fake", "bold", "goat", "skew", "calm", "haul", "cook", "goat",
        "tote", "gain", "deal", "fine", "haul", "hope", "cool", "fame", "dope", "blue",
        "shut", "goat", "haul", "goat", "busy", "goat", "goat", "fair", "goat", "food",
        "dice", "kind", "load", "free", "soft", "haul", "goat", "fish", "wipe", "goat",
        "goat", "fall", "love", "flag", "dust", "free", "open", "deep", "envy", "dirt",
        "flow", "seal", "seal", "haul", "goat", "fold", "exit", "goat", "goat", "edge",
        "haul", "book", "come", "goat", "goat", "find", "seal", "goat", "fear", "gain",
        "fade", "wash", "bake", "food", "gift", "glad", "gold", "goat", "cake", "haul"
    ],
    [
        "deal", "blue", "deep", "envy", "fake", "gain", "blue", "beam", "cook", "dust",
        "fair", "blue", "envy", "fold", "blue", "food", "envy", "love", "wipe", "food",
        "blue", "envy", "flow", "blue", "glad", "gift", "blue", "bold", "goat", "dust",
        "envy", "dope", "blue", "hunt", "free", "haul", "weak", "tote", "cook", "goat",
        "blue", "fish", "gain", "book", "open", "edge", "blue", "exit", "envy", "food",
        "seal", "free", "shut", "envy", "cake", "dice", "load", "seal", "wipe", "dust",
        "fear", "blue", "gold", "blue", "soft", "wipe", "blue", "cool", "envy", "dust",
        "cold", "blue", "skew", "fine", "blue", "envy", "kind", "fame", "goat", "dust"
    ],
    [
        "fall", "fold", "cold", "seal", "fine", "envy", "cook", "cool", "busy", "goat",
        "seal", "goat", "goat", "edge", "cake", "come", "fear", "deal", "flag", "goat",
        "goat", "free", "exit", "food", "goat", "load", "glad", "goat", "seal", "haul",
        "goat", "find", "fake", "love", "goat", "flow", "dust", "goat", "skew", "goat",
        "gain", "book", "wipe", "shut", "seal", "goat", "hunt", "bake", "goat", "fish",
        "wash", "goat", "seal", "bold", "fade", "dope", "goat", "open", "fair", "fame",
        "goat", "seal", "calm", "gain", "free", "dirt", "tote", "deep", "seal", "soft",
        "beam", "kind", "weak", "goat", "fast", "gift", "hope", "food", "blue", "seal"
    ],
    [
        "free", "bake", "free", "fame", "exit", "rock", "rock", "dope", "fake", "flag",
        "love", "fade", "rock", "weak", "calm", "cool", "shut", "gain", "fame", "dope",
        "fame", "cold", "flag", "fast", "deep", "rock", "blue", "skew", "rock", "fair",
        "gold", "rock", "busy", "dust", "fame", "tote", "kind", "rock", "haul", "fish",
        "hope", "cake", "edge", "rock", "bold", "fall", "fair", "rock", "fame", "fold",
        "rock", "food", "fame", "soft", "dice", "rock", "seal", "fear", "load", "fold",
        "rock", "rock", "rock", "rock", "rock", "dirt", "fold", "deal", "food", "envy",
        "flow", "fish", "fine", "gain", "wipe", "fame", "rock", "envy", "find", "deep"
    ]
]

titles = ['CIRCLE HAUL', 'CIRCLE ENVY', 'CIRCLE SEAL', 'CIRCLE FAME']
colors = ['#DCFFDB', '#DCFFDB', '#DCFFDB', '#DCFFDB']

# Create a PDF to save the plots
with PdfPages('circle_the_word_fnt_20_green.pdf') as pdf:
    for words, title, color in zip(words_list, titles, colors):
        create_plot(words, title, color, pdf)

# %%
#14
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Define a function to create and save the plots
def create_plot(words, title, color, pdf):
    # Reshape the words into a 10x8 matrix
    words_matrix = np.array(words).reshape(10, 8)

    # Set up the plot
    fig, ax = plt.subplots(figsize=(10, 10))

    # Set font properties with a monospaced font
    fontdict = {'fontsize': 14, 'color': color, 'family': 'monospace'}

    # Remove axes

    ax.axis('off')

    # Add the words to the plot with adjusted alignment and spacing
    x_spacing = 0.5  # Increase horizontal spacing
    y_spacing = 0.5# Increase vertical spacing
    for i in range(words_matrix.shape[0]):
        for j in range(words_matrix.shape[1]):
            ax.text(j * x_spacing, -i * y_spacing, words_matrix[i, j], ha='center', va='center', fontdict=fontdict)

    # Adjust the plot limits to add spacing between words
    ax.set_xlim(-0.5, 7.5 * x_spacing)
    ax.set_ylim(-9.5 * y_spacing, 0.5 * y_spacing)
    # Add title
    plt.title(title, fontsize=14, color=color, pad=14)

    # Save the plot to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Define the words in rows and columns for each plot
words_list = [
    [
        "goat", "weak", "fake", "bold", "goat", "skew", "calm", "haul", "cook", "goat",
        "tote", "gain", "deal", "fine", "haul", "hope", "cool", "fame", "dope", "blue",
        "shut", "goat", "haul", "goat", "busy", "goat", "goat", "fair", "goat", "food",
        "dice", "kind", "load", "free", "soft", "haul", "goat", "fish", "wipe", "goat",
        "goat", "fall", "love", "flag", "dust", "free", "open", "deep", "envy", "dirt",
        "flow", "seal", "seal", "haul", "goat", "fold", "exit", "goat", "goat", "edge",
        "haul", "book", "come", "goat", "goat", "find", "seal", "goat", "fear", "gain",
        "fade", "wash", "bake", "food", "gift", "glad", "gold", "goat", "cake", "haul"
    ],
    [
        "deal", "blue", "deep", "envy", "fake", "gain", "blue", "beam", "cook", "dust",
        "fair", "blue", "envy", "fold", "blue", "food", "envy", "love", "wipe", "food",
        "blue", "envy", "flow", "blue", "glad", "gift", "blue", "bold", "goat", "dust",
        "envy", "dope", "blue", "hunt", "free", "haul", "weak", "tote", "cook", "goat",
        "blue", "fish", "gain", "book", "open", "edge", "blue", "exit", "envy", "food",
        "seal", "free", "shut", "envy", "cake", "dice", "load", "seal", "wipe", "dust",
        "fear", "blue", "gold", "blue", "soft", "wipe", "blue", "cool", "envy", "dust",
        "cold", "blue", "skew", "fine", "blue", "envy", "kind", "fame", "goat", "dust"
    ],
    [
        "fall", "fold", "cold", "seal", "fine", "envy", "cook", "cool", "busy", "goat",
        "seal", "goat", "goat", "edge", "cake", "come", "fear", "deal", "flag", "goat",
        "goat", "free", "exit", "food", "goat", "load", "glad", "goat", "seal", "haul",
        "goat", "find", "fake", "love", "goat", "flow", "dust", "goat", "skew", "goat",
        "gain", "book", "wipe", "shut", "seal", "goat", "hunt", "bake", "goat", "fish",
        "wash", "goat", "seal", "bold", "fade", "dope", "goat", "open", "fair", "fame",
        "goat", "seal", "calm", "gain", "free", "dirt", "tote", "deep", "seal", "soft",
        "beam", "kind", "weak", "goat", "fast", "gift", "hope", "food", "blue", "seal"
    ],
    [
        "free", "bake", "free", "fame", "exit", "rock", "rock", "dope", "fake", "flag",
        "love", "fade", "rock", "weak", "calm", "cool", "shut", "gain", "fame", "dope",
        "fame", "cold", "flag", "fast", "deep", "rock", "blue", "skew", "rock", "fair",
        "gold", "rock", "busy", "dust", "fame", "tote", "kind", "rock", "haul", "fish",
        "hope", "cake", "edge", "rock", "bold", "fall", "fair", "rock", "fame", "fold",
        "rock", "food", "fame", "soft", "dice", "rock", "seal", "fear", "load", "fold",
        "rock", "rock", "rock", "rock", "rock", "dirt", "fold", "deal", "food", "envy",
        "flow", "fish", "fine", "gain", "wipe", "fame", "rock", "envy", "find", "deep"
    ]
]

titles = ['CIRCLE HAUL', 'CIRCLE ENVY', 'CIRCLE SEAL', 'CIRCLE FAME']
colors = ['#E5FFCC', '#E5FFCC', '#E5FFCC', '#E5FFCC']

# Create a PDF to save the plots
with PdfPages('circle_the_word_fnt_14_green.pdf') as pdf:
    for words, title, color in zip(words_list, titles, colors):
        create_plot(words, title, color, pdf)

# %%
#10
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Define a function to create and save the plots
def create_plot(words, title, color, pdf):
    # Reshape the words into a 10x8 matrix
    words_matrix = np.array(words).reshape(10, 8)

    # Set up the plot
    fig, ax = plt.subplots(figsize=(8, 8))

    # Set font properties with a monospaced font
    fontdict = {'fontsize': 10, 'color': color, 'family': 'monospace'}

    # Remove axes
    ax.axis('off')

    # Add the words to the plot with adjusted alignment and spacing
    x_spacing = 0.5  # Increase horizontal spacing
    y_spacing = 0.5# Increase vertical spacing
    for i in range(words_matrix.shape[0]):
        for j in range(words_matrix.shape[1]):
            ax.text(j * x_spacing, -i * y_spacing, words_matrix[i, j], ha='center', va='center', fontdict=fontdict)

    # Adjust the plot limits to add spacing between words
    ax.set_xlim(-0.5, 7.5 * x_spacing)
    ax.set_ylim(-9.5 * y_spacing, 0.5 * y_spacing)
    # Add title
    plt.title(title, fontsize=10, color=color, pad=10)

    # Save the plot to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Define the words in rows and columns for each plot
words_list = [
    [
        "goat", "weak", "fake", "bold", "goat", "skew", "calm", "haul", "cook", "goat",
        "tote", "gain", "deal", "fine", "haul", "hope", "cool", "fame", "dope", "blue",
        "shut", "goat", "haul", "goat", "busy", "goat", "goat", "fair", "goat", "food",
        "dice", "kind", "load", "free", "soft", "haul", "goat", "fish", "wipe", "goat",
        "goat", "fall", "love", "flag", "dust", "free", "open", "deep", "envy", "dirt",
        "flow", "seal", "seal", "haul", "goat", "fold", "exit", "goat", "goat", "edge",
        "haul", "book", "come", "goat", "goat", "find", "seal", "goat", "fear", "gain",
        "fade", "wash", "bake", "food", "gift", "glad", "gold", "goat", "cake", "haul"
    ],
    [
        "deal", "blue", "deep", "envy", "fake", "gain", "blue", "beam", "cook", "dust",
        "fair", "blue", "envy", "fold", "blue", "food", "envy", "love", "wipe", "food",
        "blue", "envy", "flow", "blue", "glad", "gift", "blue", "bold", "goat", "dust",
        "envy", "dope", "blue", "hunt", "free", "haul", "weak", "tote", "cook", "goat",
        "blue", "fish", "gain", "book", "open", "edge", "blue", "exit", "envy", "food",
        "seal", "free", "shut", "envy", "cake", "dice", "load", "seal", "wipe", "dust",
        "fear", "blue", "gold", "blue", "soft", "wipe", "blue", "cool", "envy", "dust",
        "cold", "blue", "skew", "fine", "blue", "envy", "kind", "fame", "goat", "dust"
    ],
    [
        "fall", "fold", "cold", "seal", "fine", "envy", "cook", "cool", "busy", "goat",
        "seal", "goat", "goat", "edge", "cake", "come", "fear", "deal", "flag", "goat",
        "goat", "free", "exit", "food", "goat", "load", "glad", "goat", "seal", "haul",
        "goat", "find", "fake", "love", "goat", "flow", "dust", "goat", "skew", "goat",
        "gain", "book", "wipe", "shut", "seal", "goat", "hunt", "bake", "goat", "fish",
        "wash", "goat", "seal", "bold", "fade", "dope", "goat", "open", "fair", "fame",
        "goat", "seal", "calm", "gain", "free", "dirt", "tote", "deep", "seal", "soft",
        "beam", "kind", "weak", "goat", "fast", "gift", "hope", "food", "blue", "seal"
    ],
    [
        "free", "bake", "free", "fame", "exit", "rock", "rock", "dope", "fake", "flag",
        "love", "fade", "rock", "weak", "calm", "cool", "shut", "gain", "fame", "dope",
        "fame", "cold", "flag", "fast", "deep", "rock", "blue", "skew", "rock", "fair",
        "gold", "rock", "busy", "dust", "fame", "tote", "kind", "rock", "haul", "fish",
        "hope", "cake", "edge", "rock", "bold", "fall", "fair", "rock", "fame", "fold",
        "rock", "food", "fame", "soft", "dice", "rock", "seal", "fear", "load", "fold",
        "rock", "rock", "rock", "rock", "rock", "dirt", "fold", "deal", "food", "envy",
        "flow", "fish", "fine", "gain", "wipe", "fame", "rock", "envy", "find", "deep"
    ]
]

titles = ['CIRCLE HAUL', 'CIRCLE ENVY', 'CIRCLE SEAL', 'CIRCLE FAME']
colors = ['#E5FFCC', '#E5FFCC', '#E5FFCC', '#E5FFCC']

# Create a PDF to save the plots
with PdfPages('circle_the_word_fnt_10_green.pdf') as pdf:
    for words, title, color in zip(words_list, titles, colors):
        create_plot(words, title, color, pdf)

# %%
#8
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Define a function to create and save the plots
def create_plot(words, title, color, pdf):
    # Reshape the words into a 10x8 matrix
    words_matrix = np.array(words).reshape(10, 8)

    # Set up the plot
    fig, ax = plt.subplots(figsize=(6, 6))

    # Set font properties with a monospaced font
    fontdict = {'fontsize': 8, 'color': color, 'family': 'monospace'}

    # Remove axes
    ax.axis('off')

    # Add the words to the plot with adjusted alignment and spacing
    x_spacing = 0.5  # Increase horizontal spacing
    y_spacing = 0.5# Increase vertical spacing
    for i in range(words_matrix.shape[0]):
        for j in range(words_matrix.shape[1]):
            ax.text(j * x_spacing, -i * y_spacing, words_matrix[i, j], ha='center', va='center', fontdict=fontdict)

    # Adjust the plot limits to add spacing between words
    ax.set_xlim(-0.5, 7.5 * x_spacing)
    ax.set_ylim(-9.5 * y_spacing, 0.5 * y_spacing)
    # Add title
    plt.title(title, fontsize=8, color=color, pad=8)

    # Save the plot to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Define the words in rows and columns for each plot
words_list = [
    [
        "goat", "weak", "fake", "bold", "goat", "skew", "calm", "haul", "cook", "goat",
        "tote", "gain", "deal", "fine", "haul", "hope", "cool", "fame", "dope", "blue",
        "shut", "goat", "haul", "goat", "busy", "goat", "goat", "fair", "goat", "food",
        "dice", "kind", "load", "free", "soft", "haul", "goat", "fish", "wipe", "goat",
        "goat", "fall", "love", "flag", "dust", "free", "open", "deep", "envy", "dirt",
        "flow", "seal", "seal", "haul", "goat", "fold", "exit", "goat", "goat", "edge",
        "haul", "book", "come", "goat", "goat", "find", "seal", "goat", "fear", "gain",
        "fade", "wash", "bake", "food", "gift", "glad", "gold", "goat", "cake", "haul"
    ],
    [
        "deal", "blue", "deep", "envy", "fake", "gain", "blue", "beam", "cook", "dust",
        "fair", "blue", "envy", "fold", "blue", "food", "envy", "love", "wipe", "food",
        "blue", "envy", "flow", "blue", "glad", "gift", "blue", "bold", "goat", "dust",
        "envy", "dope", "blue", "hunt", "free", "haul", "weak", "tote", "cook", "goat",
        "blue", "fish", "gain", "book", "open", "edge", "blue", "exit", "envy", "food",
        "seal", "free", "shut", "envy", "cake", "dice", "load", "seal", "wipe", "dust",
        "fear", "blue", "gold", "blue", "soft", "wipe", "blue", "cool", "envy", "dust",
        "cold", "blue", "skew", "fine", "blue", "envy", "kind", "fame", "goat", "dust"
    ],
    [
        "fall", "fold", "cold", "seal", "fine", "envy", "cook", "cool", "busy", "goat",
        "seal", "goat", "goat", "edge", "cake", "come", "fear", "deal", "flag", "goat",
        "goat", "free", "exit", "food", "goat", "load", "glad", "goat", "seal", "haul",
        "goat", "find", "fake", "love", "goat", "flow", "dust", "goat", "skew", "goat",
        "gain", "book", "wipe", "shut", "seal", "goat", "hunt", "bake", "goat", "fish",
        "wash", "goat", "seal", "bold", "fade", "dope", "goat", "open", "fair", "fame",
        "goat", "seal", "calm", "gain", "free", "dirt", "tote", "deep", "seal", "soft",
        "beam", "kind", "weak", "goat", "fast", "gift", "hope", "food", "blue", "seal"
    ],
    [
        "free", "bake", "free", "fame", "exit", "rock", "rock", "dope", "fake", "flag",
        "love", "fade", "rock", "weak", "calm", "cool", "shut", "gain", "fame", "dope",
        "fame", "cold", "flag", "fast", "deep", "rock", "blue", "skew", "rock", "fair",
        "gold", "rock", "busy", "dust", "fame", "tote", "kind", "rock", "haul", "fish",
        "hope", "cake", "edge", "rock", "bold", "fall", "fair", "rock", "fame", "fold",
        "rock", "food", "fame", "soft", "dice", "rock", "seal", "fear", "load", "fold",
        "rock", "rock", "rock", "rock", "rock", "dirt", "fold", "deal", "food", "envy",
        "flow", "fish", "fine", "gain", "wipe", "fame", "rock", "envy", "find", "deep"
    ]
]

titles = ['CIRCLE HAUL', 'CIRCLE ENVY', 'CIRCLE SEAL', 'CIRCLE FAME']
colors = ['#E5FFCC', '#E5FFCC', '#E5FFCC', '#E5FFCC']

# Create a PDF to save the plots
with PdfPages('circle_the_word_fnt_8_green.pdf') as pdf:
    for words, title, color in zip(words_list, titles, colors):
        create_plot(words, title, color, pdf)

# %%
#6
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Define a function to create and save the plots
def create_plot(words, title, color, pdf):
    # Reshape the words into a 10x8 matrix
    words_matrix = np.array(words).reshape(10, 8)

    # Set up the plot
    fig, ax = plt.subplots(figsize=(4, 4))

    # Set font properties with a monospaced font
    fontdict = {'fontsize': 6, 'color': color, 'family': 'monospace'}

    # Remove axes
    ax.axis('off')

    # Add the words to the plot with adjusted alignment and spacing
    x_spacing = 0.5  # Increase horizontal spacing
    y_spacing = 0.5# Increase vertical spacing
    for i in range(words_matrix.shape[0]):
        for j in range(words_matrix.shape[1]):
            ax.text(j * x_spacing, -i * y_spacing, words_matrix[i, j], ha='center', va='center', fontdict=fontdict)

    # Adjust the plot limits to add spacing between words
    ax.set_xlim(-0.5, 7.5 * x_spacing)
    ax.set_ylim(-9.5 * y_spacing, 0.5 * y_spacing)
    # Add title
    plt.title(title, fontsize=6, color=color, pad=6)

    # Save the plot to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Define the words in rows and columns for each plot
words_list = [
    [
        "goat", "weak", "fake", "bold", "goat", "skew", "calm", "haul", "cook", "goat",
        "tote", "gain", "deal", "fine", "haul", "hope", "cool", "fame", "dope", "blue",
        "shut", "goat", "haul", "goat", "busy", "goat", "goat", "fair", "goat", "food",
        "dice", "kind", "load", "free", "soft", "haul", "goat", "fish", "wipe", "goat",
        "goat", "fall", "love", "flag", "dust", "free", "open", "deep", "envy", "dirt",
        "flow", "seal", "seal", "haul", "goat", "fold", "exit", "goat", "goat", "edge",
        "haul", "book", "come", "goat", "goat", "find", "seal", "goat", "fear", "gain",
        "fade", "wash", "bake", "food", "gift", "glad", "gold", "goat", "cake", "haul"
    ],
    [
        "deal", "blue", "deep", "envy", "fake", "gain", "blue", "beam", "cook", "dust",
        "fair", "blue", "envy", "fold", "blue", "food", "envy", "love", "wipe", "food",
        "blue", "envy", "flow", "blue", "glad", "gift", "blue", "bold", "goat", "dust",
        "envy", "dope", "blue", "hunt", "free", "haul", "weak", "tote", "cook", "goat",
        "blue", "fish", "gain", "book", "open", "edge", "blue", "exit", "envy", "food",
        "seal", "free", "shut", "envy", "cake", "dice", "load", "seal", "wipe", "dust",
        "fear", "blue", "gold", "blue", "soft", "wipe", "blue", "cool", "envy", "dust",
        "cold", "blue", "skew", "fine", "blue", "envy", "kind", "fame", "goat", "dust"
    ],
    [
        "fall", "fold", "cold", "seal", "fine", "envy", "cook", "cool", "busy", "goat",
        "seal", "goat", "goat", "edge", "cake", "come", "fear", "deal", "flag", "goat",
        "goat", "free", "exit", "food", "goat", "load", "glad", "goat", "seal", "haul",
        "goat", "find", "fake", "love", "goat", "flow", "dust", "goat", "skew", "goat",
        "gain", "book", "wipe", "shut", "seal", "goat", "hunt", "bake", "goat", "fish",
        "wash", "goat", "seal", "bold", "fade", "dope", "goat", "open", "fair", "fame",
        "goat", "seal", "calm", "gain", "free", "dirt", "tote", "deep", "seal", "soft",
        "beam", "kind", "weak", "goat", "fast", "gift", "hope", "food", "blue", "seal"
    ],
    [
        "free", "bake", "free", "fame", "exit", "rock", "rock", "dope", "fake", "flag",
        "love", "fade", "rock", "weak", "calm", "cool", "shut", "gain", "fame", "dope",
        "fame", "cold", "flag", "fast", "deep", "rock", "blue", "skew", "rock", "fair",
        "gold", "rock", "busy", "dust", "fame", "tote", "kind", "rock", "haul", "fish",
        "hope", "cake", "edge", "rock", "bold", "fall", "fair", "rock", "fame", "fold",
        "rock", "food", "fame", "soft", "dice", "rock", "seal", "fear", "load", "fold",
        "rock", "rock", "rock", "rock", "rock", "dirt", "fold", "deal", "food", "envy",
        "flow", "fish", "fine", "gain", "wipe", "fame", "rock", "envy", "find", "deep"
    ]
]

titles = ['CIRCLE HAUL', 'CIRCLE ENVY', 'CIRCLE SEAL', 'CIRCLE FAME']
colors = ['#E5FFCC', '#E5FFCC', '#E5FFCC', '#E5FFCC']

# Create a PDF to save the plots
with PdfPages('circle_the_word_fnt_6_green.pdf') as pdf:
    for words, title, color in zip(words_list, titles, colors):
        create_plot(words, title, color, pdf)

# %%
#5
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Define a function to create and save the plots
def create_plot(words, title, color, pdf):
    # Reshape the words into a 10x8 matrix
    words_matrix = np.array(words).reshape(10, 8)

    # Set up the plot
    fig, ax = plt.subplots(figsize=(4, 4))

    # Set font properties with a monospaced font
    fontdict = {'fontsize': 5, 'color': color, 'family': 'monospace'}

    # Remove axes
    ax.axis('off')

    # Add the words to the plot with adjusted alignment and spacing
    x_spacing = 0.5  # Increase horizontal spacing
    y_spacing = 0.5# Increase vertical spacing
    for i in range(words_matrix.shape[0]):
        for j in range(words_matrix.shape[1]):
            ax.text(j * x_spacing, -i * y_spacing, words_matrix[i, j], ha='center', va='center', fontdict=fontdict)

    # Adjust the plot limits to add spacing between words
    ax.set_xlim(-0.5, 7.5 * x_spacing)
    ax.set_ylim(-9.5 * y_spacing, 0.5 * y_spacing)
    # Add title
    plt.title(title, fontsize=5, color=color, pad=5)

    # Save the plot to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Define the words in rows and columns for each plot
words_list = [
    [
        "goat", "weak", "fake", "bold", "goat", "skew", "calm", "haul", "cook", "goat",
        "tote", "gain", "deal", "fine", "haul", "hope", "cool", "fame", "dope", "blue",
        "shut", "goat", "haul", "goat", "busy", "goat", "goat", "fair", "goat", "food",
        "dice", "kind", "load", "free", "soft", "haul", "goat", "fish", "wipe", "goat",
        "goat", "fall", "love", "flag", "dust", "free", "open", "deep", "envy", "dirt",
        "flow", "seal", "seal", "haul", "goat", "fold", "exit", "goat", "goat", "edge",
        "haul", "book", "come", "goat", "goat", "find", "seal", "goat", "fear", "gain",
        "fade", "wash", "bake", "food", "gift", "glad", "gold", "goat", "cake", "haul"
    ],
    [
        "deal", "blue", "deep", "envy", "fake", "gain", "blue", "beam", "cook", "dust",
        "fair", "blue", "envy", "fold", "blue", "food", "envy", "love", "wipe", "food",
        "blue", "envy", "flow", "blue", "glad", "gift", "blue", "bold", "goat", "dust",
        "envy", "dope", "blue", "hunt", "free", "haul", "weak", "tote", "cook", "goat",
        "blue", "fish", "gain", "book", "open", "edge", "blue", "exit", "envy", "food",
        "seal", "free", "shut", "envy", "cake", "dice", "load", "seal", "wipe", "dust",
        "fear", "blue", "gold", "blue", "soft", "wipe", "blue", "cool", "envy", "dust",
        "cold", "blue", "skew", "fine", "blue", "envy", "kind", "fame", "goat", "dust"
    ],
    [
        "fall", "fold", "cold", "seal", "fine", "envy", "cook", "cool", "busy", "goat",
        "seal", "goat", "goat", "edge", "cake", "come", "fear", "deal", "flag", "goat",
        "goat", "free", "exit", "food", "goat", "load", "glad", "goat", "seal", "haul",
        "goat", "find", "fake", "love", "goat", "flow", "dust", "goat", "skew", "goat",
        "gain", "book", "wipe", "shut", "seal", "goat", "hunt", "bake", "goat", "fish",
        "wash", "goat", "seal", "bold", "fade", "dope", "goat", "open", "fair", "fame",
        "goat", "seal", "calm", "gain", "free", "dirt", "tote", "deep", "seal", "soft",
        "beam", "kind", "weak", "goat", "fast", "gift", "hope", "food", "blue", "seal"
    ],
    [
        "free", "bake", "free", "fame", "exit", "rock", "rock", "dope", "fake", "flag",
        "love", "fade", "rock", "weak", "calm", "cool", "shut", "gain", "fame", "dope",
        "fame", "cold", "flag", "fast", "deep", "rock", "blue", "skew", "rock", "fair",
        "gold", "rock", "busy", "dust", "fame", "tote", "kind", "rock", "haul", "fish",
        "hope", "cake", "edge", "rock", "bold", "fall", "fair", "rock", "fame", "fold",
        "rock", "food", "fame", "soft", "dice", "rock", "seal", "fear", "load", "fold",
        "rock", "rock", "rock", "rock", "rock", "dirt", "fold", "deal", "food", "envy",
        "flow", "fish", "fine", "gain", "wipe", "fame", "rock", "envy", "find", "deep"
    ]
]

titles = ['CIRCLE HAUL', 'CIRCLE ENVY', 'CIRCLE SEAL', 'CIRCLE FAME']
colors = ['#E5FFCC', '#E5FFCC', '#E5FFCC', '#E5FFCC']

# Create a PDF to save the plots
with PdfPages('circle_the_word_fnt_5_green.pdf') as pdf:
    for words, title, color in zip(words_list, titles, colors):
        create_plot(words, title, color, pdf)

# %%
#4
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Define a function to create and save the plots
def create_plot(words, title, color, pdf):
    # Reshape the words into a 10x8 matrix
    words_matrix = np.array(words).reshape(10, 8)

    # Set up the plot
    fig, ax = plt.subplots(figsize=(3, 3))

    # Set font properties with a monospaced font
    fontdict = {'fontsize': 4, 'color': color, 'family': 'monospace'}

    # Remove axes
    ax.axis('off')

    # Add the words to the plot with adjusted alignment and spacing
    x_spacing = 0.5  # Increase horizontal spacing
    y_spacing = 0.5# Increase vertical spacing
    for i in range(words_matrix.shape[0]):
        for j in range(words_matrix.shape[1]):
            ax.text(j * x_spacing, -i * y_spacing, words_matrix[i, j], ha='center', va='center', fontdict=fontdict)

    # Adjust the plot limits to add spacing between words
    ax.set_xlim(-0.5, 7.5 * x_spacing)
    ax.set_ylim(-9.5 * y_spacing, 0.5 * y_spacing)
    # Add title
    plt.title(title, fontsize=4, color=color, pad=4)

    # Save the plot to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Define the words in rows and columns for each plot
words_list = [
    [
        "goat", "weak", "fake", "bold", "goat", "skew", "calm", "haul", "cook", "goat",
        "tote", "gain", "deal", "fine", "haul", "hope", "cool", "fame", "dope", "blue",
        "shut", "goat", "haul", "goat", "busy", "goat", "goat", "fair", "goat", "food",
        "dice", "kind", "load", "free", "soft", "haul", "goat", "fish", "wipe", "goat",
        "goat", "fall", "love", "flag", "dust", "free", "open", "deep", "envy", "dirt",
        "flow", "seal", "seal", "haul", "goat", "fold", "exit", "goat", "goat", "edge",
        "haul", "book", "come", "goat", "goat", "find", "seal", "goat", "fear", "gain",
        "fade", "wash", "bake", "food", "gift", "glad", "gold", "goat", "cake", "haul"
    ],
    [
        "deal", "blue", "deep", "envy", "fake", "gain", "blue", "beam", "cook", "dust",
        "fair", "blue", "envy", "fold", "blue", "food", "envy", "love", "wipe", "food",
        "blue", "envy", "flow", "blue", "glad", "gift", "blue", "bold", "goat", "dust",
        "envy", "dope", "blue", "hunt", "free", "haul", "weak", "tote", "cook", "goat",
        "blue", "fish", "gain", "book", "open", "edge", "blue", "exit", "envy", "food",
        "seal", "free", "shut", "envy", "cake", "dice", "load", "seal", "wipe", "dust",
        "fear", "blue", "gold", "blue", "soft", "wipe", "blue", "cool", "envy", "dust",
        "cold", "blue", "skew", "fine", "blue", "envy", "kind", "fame", "goat", "dust"
    ],
    [
        "fall", "fold", "cold", "seal", "fine", "envy", "cook", "cool", "busy", "goat",
        "seal", "goat", "goat", "edge", "cake", "come", "fear", "deal", "flag", "goat",
        "goat", "free", "exit", "food", "goat", "load", "glad", "goat", "seal", "haul",
        "goat", "find", "fake", "love", "goat", "flow", "dust", "goat", "skew", "goat",
        "gain", "book", "wipe", "shut", "seal", "goat", "hunt", "bake", "goat", "fish",
        "wash", "goat", "seal", "bold", "fade", "dope", "goat", "open", "fair", "fame",
        "goat", "seal", "calm", "gain", "free", "dirt", "tote", "deep", "seal", "soft",
        "beam", "kind", "weak", "goat", "fast", "gift", "hope", "food", "blue", "seal"
    ],
    [
        "free", "bake", "free", "fame", "exit", "rock", "rock", "dope", "fake", "flag",
        "love", "fade", "rock", "weak", "calm", "cool", "shut", "gain", "fame", "dope",
        "fame", "cold", "flag", "fast", "deep", "rock", "blue", "skew", "rock", "fair",
        "gold", "rock", "busy", "dust", "fame", "tote", "kind", "rock", "haul", "fish",
        "hope", "cake", "edge", "rock", "bold", "fall", "fair", "rock", "fame", "fold",
        "rock", "food", "fame", "soft", "dice", "rock", "seal", "fear", "load", "fold",
        "rock", "rock", "rock", "rock", "rock", "dirt", "fold", "deal", "food", "envy",
        "flow", "fish", "fine", "gain", "wipe", "fame", "rock", "envy", "find", "deep"
    ]
]

titles = ['CIRCLE HAUL', 'CIRCLE ENVY', 'CIRCLE SEAL', 'CIRCLE FAME']
colors = ['#E5FFCC', '#E5FFCC', '#E5FFCC', '#E5FFCC']

# Create a PDF to save the plots
with PdfPages('circle_the_word_fnt_4_green.pdf') as pdf:
    for words, title, color in zip(words_list, titles, colors):
        create_plot(words, title, color, pdf)

# %% [markdown]
# #circle the letter

# %%
#33
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the letters to display for each game
games = {
    "CIRCLE THE LETTER 1": ['B', 'T', 'S', 'K', 'Y'],
    "CIRCLE THE LETTER 2": ['A', 'E', 'I', 'O', 'U'],
    "CIRCLE THE LETTER 3": ['R', 'C', 'M', 'D', 'W'],
    "CIRCLE THE LETTER 4": ['F', 'G', 'Z', 'X', 'J']
}

# Grid size
grid_size = 15

# Function to display and save the grid as an image without circling letters
def save_circle_letters_game(grid, letters_to_display, title, pdf):
    fig, ax = plt.subplots(figsize=(15, 15), dpi=300)
    ax.imshow(np.ones((grid_size, grid_size)), cmap='gray', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=33, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

    # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Set grid with the specified color
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=0.5)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the list of letters to display at the bottom
    letters_list = "Letters to find: " + ", ".join(letters_to_display)
    plt.figtext(0.5, 0.01, letters_list, ha="center", fontsize=33, color='#E5FFCC')

    # Add the title in capital letters
    plt.title(title, fontsize=33, color='#E5FFCC', pad=20)

    # Save the current figure to the PDF
    pdf.savefig(fig, bbox_inches='tight')
    plt.close(fig)

# Create a PDF file to save all "Circle the Letter" games
with PdfPages('circle_the_letter_33.pdf') as pdf:
    # Generate and save each game as a page in the PDF
    for game_title, letters_to_display in games.items():
        # Initialize empty grid with random letters
        grid = np.random.choice(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'), size=(grid_size, grid_size))
        save_circle_letters_game(grid, letters_to_display, game_title, pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the letters to display for each game
games = {
    "CIRCLE THE LETTER 1": ['B', 'T', 'S', 'K', 'Y'],
    "CIRCLE THE LETTER 2": ['A', 'E', 'I', 'O', 'U'],
    "CIRCLE THE LETTER 3": ['R', 'C', 'M', 'D', 'W'],
    "CIRCLE THE LETTER 4": ['F', 'G', 'Z', 'X', 'J']
}

# Grid size
grid_size = 15

# Function to display and save the grid as an image without circling letters
def save_circle_letters_game(grid, letters_to_display, title, pdf):
    fig, ax = plt.subplots(figsize=(12, 12), dpi=300)
    ax.imshow(np.ones((grid_size, grid_size)), cmap='gray', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=20, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

    # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Set grid with the specified color
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=0.5)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the list of letters to display at the bottom
    letters_list = "Letters to find: " + ", ".join(letters_to_display)
    plt.figtext(0.5, 0.01, letters_list, ha="center", fontsize=20, color='#E5FFCC')

    # Add the title in capital letters
    plt.title(title, fontsize=20, color='#E5FFCC', pad=20)

    # Save the current figure to the PDF
    pdf.savefig(fig, bbox_inches='tight')
    plt.close(fig)

# Create a PDF file to save all "Circle the Letter" games
with PdfPages('circle_the_letter_20.pdf') as pdf:
    # Generate and save each game as a page in the PDF
    for game_title, letters_to_display in games.items():
        # Initialize empty grid with random letters
        grid = np.random.choice(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'), size=(grid_size, grid_size))
        save_circle_letters_game(grid, letters_to_display, game_title, pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the letters to display for each game
games = {
    "CIRCLE THE LETTER 1": ['B', 'T', 'S', 'K', 'Y'],
    "CIRCLE THE LETTER 2": ['A', 'E', 'I', 'O', 'U'],
    "CIRCLE THE LETTER 3": ['R', 'C', 'M', 'D', 'W'],
    "CIRCLE THE LETTER 4": ['F', 'G', 'Z', 'X', 'J']
}

# Grid size
grid_size = 15

# Function to display and save the grid as an image without circling letters
def save_circle_letters_game(grid, letters_to_display, title, pdf):
    fig, ax = plt.subplots(figsize=(10, 10), dpi=300)
    ax.imshow(np.ones((grid_size, grid_size)), cmap='gray', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=14, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

    # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Set grid with the specified color
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=0.5)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the list of letters to display at the bottom
    letters_list = "Letters to find: " + ", ".join(letters_to_display)
    plt.figtext(0.5, 0.01, letters_list, ha="center", fontsize=14, color='#E5FFCC')

    # Add the title in capital letters
    plt.title(title, fontsize=14, color='#E5FFCC', pad=20)

    # Save the current figure to the PDF
    pdf.savefig(fig, bbox_inches='tight')
    plt.close(fig)

# Create a PDF file to save all "Circle the Letter" games
with PdfPages('circle_the_letter_14.pdf') as pdf:
    # Generate and save each game as a page in the PDF
    for game_title, letters_to_display in games.items():
        # Initialize empty grid with random letters
        grid = np.random.choice(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'), size=(grid_size, grid_size))
        save_circle_letters_game(grid, letters_to_display, game_title, pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the letters to display for each game
games = {
    "CIRCLE THE LETTER 1": ['B', 'T', 'S', 'K', 'Y'],
    "CIRCLE THE LETTER 2": ['A', 'E', 'I', 'O', 'U'],
    "CIRCLE THE LETTER 3": ['R', 'C', 'M', 'D', 'W'],
    "CIRCLE THE LETTER 4": ['F', 'G', 'Z', 'X', 'J']
}

# Grid size
grid_size = 15

# Function to display and save the grid as an image without circling letters
def save_circle_letters_game(grid, letters_to_display, title, pdf):
    fig, ax = plt.subplots(figsize=(9,9 ), dpi=300)
    ax.imshow(np.ones((grid_size, grid_size)), cmap='gray', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=10, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

    # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Set grid with the specified color
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=0.5)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the list of letters to display at the bottom
    letters_list = "Letters to find: " + ", ".join(letters_to_display)
    plt.figtext(0.5, 0.01, letters_list, ha="center", fontsize=10, color='#E5FFCC')

    # Add the title in capital letters
    plt.title(title, fontsize=10, color='#E5FFCC', pad=20)

    # Save the current figure to the PDF
    pdf.savefig(fig, bbox_inches='tight')
    plt.close(fig)

# Create a PDF file to save all "Circle the Letter" games
with PdfPages('circle_the_letter_10.pdf') as pdf:
    # Generate and save each game as a page in the PDF
    for game_title, letters_to_display in games.items():
        # Initialize empty grid with random letters
        grid = np.random.choice(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'), size=(grid_size, grid_size))
        save_circle_letters_game(grid, letters_to_display, game_title, pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the letters to display for each game
games = {
    "CIRCLE THE LETTER 1": ['B', 'T', 'S', 'K', 'Y'],
    "CIRCLE THE LETTER 2": ['A', 'E', 'I', 'O', 'U'],
    "CIRCLE THE LETTER 3": ['R', 'C', 'M', 'D', 'W'],
    "CIRCLE THE LETTER 4": ['F', 'G', 'Z', 'X', 'J']
}

# Grid size
grid_size = 15

# Function to display and save the grid as an image without circling letters
def save_circle_letters_game(grid, letters_to_display, title, pdf):
    fig, ax = plt.subplots(figsize=(8, 8), dpi=300)
    ax.imshow(np.ones((grid_size, grid_size)), cmap='gray', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=8, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

    # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Set grid with the specified color
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=0.5)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the list of letters to display at the bottom
    letters_list = "Letters to find: " + ", ".join(letters_to_display)
    plt.figtext(0.5, 0.01, letters_list, ha="center", fontsize=8, color='#E5FFCC')

    # Add the title in capital letters
    plt.title(title, fontsize=8, color='#E5FFCC', pad=20)

    # Save the current figure to the PDF
    pdf.savefig(fig, bbox_inches='tight')
    plt.close(fig)

# Create a PDF file to save all "Circle the Letter" games
with PdfPages('circle_the_letter_8.pdf') as pdf:
    # Generate and save each game as a page in the PDF
    for game_title, letters_to_display in games.items():
        # Initialize empty grid with random letters
        grid = np.random.choice(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'), size=(grid_size, grid_size))
        save_circle_letters_game(grid, letters_to_display, game_title, pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the letters to display for each game
games = {
    "CIRCLE THE LETTER 1": ['B', 'T', 'S', 'K', 'Y'],
    "CIRCLE THE LETTER 2": ['A', 'E', 'I', 'O', 'U'],
    "CIRCLE THE LETTER 3": ['R', 'C', 'M', 'D', 'W'],
    "CIRCLE THE LETTER 4": ['F', 'G', 'Z', 'X', 'J']
}

# Grid size
grid_size = 15

# Function to display and save the grid as an image without circling letters
def save_circle_letters_game(grid, letters_to_display, title, pdf):
    fig, ax = plt.subplots(figsize=(7, 7), dpi=300)
    ax.imshow(np.ones((grid_size, grid_size)), cmap='gray', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=6, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

    # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Set grid with the specified color
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=0.5)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the list of letters to display at the bottom
    letters_list = "Letters to find: " + ", ".join(letters_to_display)
    plt.figtext(0.5, 0.01, letters_list, ha="center", fontsize=6, color='#E5FFCC')

    # Add the title in capital letters
    plt.title(title, fontsize=6, color='#E5FFCC', pad=20)

    # Save the current figure to the PDF
    pdf.savefig(fig, bbox_inches='tight')
    plt.close(fig)

# Create a PDF file to save all "Circle the Letter" games
with PdfPages('circle_the_letter_6.pdf') as pdf:
    # Generate and save each game as a page in the PDF
    for game_title, letters_to_display in games.items():
        # Initialize empty grid with random letters
        grid = np.random.choice(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'), size=(grid_size, grid_size))
        save_circle_letters_game(grid, letters_to_display, game_title, pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the letters to display for each game
games = {
    "CIRCLE THE LETTER 1": ['B', 'T', 'S', 'K', 'Y'],
    "CIRCLE THE LETTER 2": ['A', 'E', 'I', 'O', 'U'],
    "CIRCLE THE LETTER 3": ['R', 'C', 'M', 'D', 'W'],
    "CIRCLE THE LETTER 4": ['F', 'G', 'Z', 'X', 'J']
}

# Grid size
grid_size = 15

# Function to display and save the grid as an image without circling letters
def save_circle_letters_game(grid, letters_to_display, title, pdf):
    fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
    ax.imshow(np.ones((grid_size, grid_size)), cmap='gray', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=5, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

    # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Set grid with the specified color
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=0.5)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the list of letters to display at the bottom
    letters_list = "Letters to find: " + ", ".join(letters_to_display)
    plt.figtext(0.5, 0.01, letters_list, ha="center", fontsize=5, color='#E5FFCC')

    # Add the title in capital letters
    plt.title(title, fontsize=5, color='#E5FFCC', pad=20)

    # Save the current figure to the PDF
    pdf.savefig(fig, bbox_inches='tight')
    plt.close(fig)

# Create a PDF file to save all "Circle the Letter" games
with PdfPages('circle_the_letter_5.pdf') as pdf:
    # Generate and save each game as a page in the PDF
    for game_title, letters_to_display in games.items():
        # Initialize empty grid with random letters
        grid = np.random.choice(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'), size=(grid_size, grid_size))
        save_circle_letters_game(grid, letters_to_display, game_title, pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the letters to display for each game
games = {
    "CIRCLE THE LETTER 1": ['B', 'T', 'S', 'K', 'Y'],
    "CIRCLE THE LETTER 2": ['A', 'E', 'I', 'O', 'U'],
    "CIRCLE THE LETTER 3": ['R', 'C', 'M', 'D', 'W'],
    "CIRCLE THE LETTER 4": ['F', 'G', 'Z', 'X', 'J']
}

# Grid size
grid_size = 15

# Function to display and save the grid as an image without circling letters
def save_circle_letters_game(grid, letters_to_display, title, pdf):
    fig, ax = plt.subplots(figsize=(4, 4), dpi=300)
    ax.imshow(np.ones((grid_size, grid_size)), cmap='gray', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=4, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

    # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Set grid with the specified color
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=0.5)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the list of letters to display at the bottom
    letters_list = "Letters to find: " + ", ".join(letters_to_display)
    plt.figtext(0.5, 0.01, letters_list, ha="center", fontsize=4, color='#E5FFCC')

    # Add the title in capital letters
    plt.title(title, fontsize=4, color='#E5FFCC', pad=20)

    # Save the current figure to the PDF
    pdf.savefig(fig, bbox_inches='tight')
    plt.close(fig)

# Create a PDF file to save all "Circle the Letter" games
with PdfPages('circle_the_letter_4.pdf') as pdf:
    # Generate and save each game as a page in the PDF
    for game_title, letters_to_display in games.items():
        # Initialize empty grid with random letters
        grid = np.random.choice(list('ABCDEFGHIJKLMNOPQRSTUVWXYZ'), size=(grid_size, grid_size))
        save_circle_letters_game(grid, letters_to_display, game_title, pdf)

# %% [markdown]
# #MAZE GREEN

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Function to create maze plot
def create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize):
    # Ensure all rows have the same length by padding with spaces if necessary
    max_length = max(len(row) for row in maze_data)
    maze_data = [row.ljust(max_length) for row in maze_data]

    # Create a 2D list from the maze data
    maze_list = []
    for row in maze_data:
        row_list = []
        for char in row:
            if (char == 'W'):
                row_list.append(1)  # Wall
            elif char == ' ':
                row_list.append(0)  # Path
            elif char == 'S':
                row_list.append(2)  # Start
            elif char == 'E':
                row_list.append(3)  # End
        maze_list.append(row_list)

    # Convert the 2D list to a numpy array
    maze_array = np.array(maze_list)

    # Create a plot with a large enough figure size
    fig, ax = plt.subplots(figsize=fig_size)
  # Draw the maze using very thin lines for the walls
    for i in range(maze_array.shape[0]):
        for j in range(maze_array.shape[1]):
            if maze_array[i, j] == 1:
                # Draw a wall with very thin lines
                ax.plot([j, j+1], [i, i], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j+1], [i+1, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j], [i, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j+1, j+1], [i, i+1], color='#D1EBB8', linewidth=0.1)


    # Adding the start and end labels
    start_pos = (maze_array.shape[0] - 1, 0)
    ax.text(start_pos[1] - 1, start_pos[0], 'START', ha='right', va='center', fontsize=4, fontweight='bold', color='#D1EBB8')

    end_pos = (0, maze_array.shape[1] - 1)
    ax.text(end_pos[1] + 1, end_pos[0], 'END', ha='left', va='center', fontsize=4, fontweight='bold', color='#D1EBB8')

    # Set plot limits
    ax.set_xlim(-1, maze_array.shape[1])
    ax.set_ylim(-1, maze_array.shape[0])

    # Turn off the axes
    ax.set_xticks([])
    ax.set_yticks([])

    # Remove the plot outline (spines)
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Set background color to white
    ax.set_facecolor('white')

    return fig


# Define maze data
new_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S       W       W                   W",
        "W WWWWW W WWWWW W WWWWWWWWWWWWWWWWWWWWW",
        "W W     W     W W W                 W W",
        "W W WWWWW W WWWWW W WWWWWWWWWWWWWWW W W",
        "W W     W W       W W           W W W W",
        "W WWWWW W WWWWWWWWW W WWWWWWWWWW W W W",
        "W       W         W W       W     W   W",
        "WWWWWWWWWWWWWWW W W WWWWWWW W WWWWWWWWW",
        "W           W   W W W       W       W W",
        "W WWWWWWWW W WWWWW W W WWWWWWWWWWWWWW W",
        "W W       W       W W       W       W W",
        "W W WWWWWWWWWWWWWWWWWWWWWW W W WWWWWWWWW",
        "W W W     W             W W W W         W",
        "W W W WWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W W               W",
        "W W WWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W   W             W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W W W W                             W W W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W",
        "W W W W                       W   W W W W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W W",
        "W W           W   W           W W W W W W",
        "W WWWWWWWWWWWWW W W WWWWWWWWW W W W W W W",
        "W                 W       W   W W W   W W",
        "W WWWWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWW W",
        "W W                     W W             W",
        "W W WWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW",
        "W W                       W             W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

new_maze_data_2 = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W         W       W         W W",
        "W WWWWW W WWWWWWW W WWW W WWWWWWWWW W W",
        "W     W W     W   W W W W         W W W",
        "WWWWWW W WWWWW WWW W W W WWWWWWWWWWW W W",
        "W     W       W W   W   W         W   W",
        "W WWWWWWWWWW W W WWW WWWWWWWWWWWWW W WWW",
        "W       W   W W     W     W     W W W W",
        "WWWWWWW W WWWWWWWWWWWWWWW W WWWWW W W W",
        "W     W W         W     W W     W W W W",
        "W WWWWW W WWWWWWW W WWWWWWW W WWWWW W W",
        "W     W W       W W   W   W W     W W W",
        "WWWWW W WWWWWWW W WWWWW W WWWWWWWWW W W",
        "W     W     W   W     W W       W   W W",
        "W WWWWWWWWW W WWWWWWW W W WWWWW W WWW W",
        "W         W W       W W W     W W     W",
        "WWWWWWWWWWWW WWWWWWW W W W WWWWWWWWWWWW",
        "W       W   W       W W W     W       W",
        "W WWWWW W WWW W WWWWW W WWWWW W W W WWW",
        "W   W   W   W W     W W       W W W   W",
        "W W WWWWWWWWW W WWWWWWWWWWWWWWW W WWWWW",
        "W W       W   W   W       W     W     W",
        "W WWW WWWWWWWWW W WWWWWWW W W WWWWWWWWW",
        "W     W       W W W     W W W W       W",
        "WWWWWWWWWWW W W W W WWWWW W W W WWWWW W",
        "W         W W W   W     W W   W     W W",
        "W WWWWWWWWW W WWWWW WWW W WWWWWWWWW W W",
        "W       W   W       W W W         W W W",
        "WWWWWWWW W WWWWWWWWWWW W WWWWWWWWW W W W",
        "W       W           W W     W     W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

different_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W     W       W           W   W",
        "W WWW W W W W W WWW W W WWWWWWWWWWWW W W",
        "W   W W W W W   W   W W       W     W W",
        "W W W W W W W W W WWWWW WWWWW W WWWWW W",
        "W W   W   W W W W   W     W W W     W W",
        "W WWW W W W W W W W WWWWWW W W WWW W W",
        "W     W W W W W W W       W     W   W W",
        "WWWWWWW WWW W W WWWWWWWWWWW WWWWWWWWWWW",
        "W       W   W W     W         W     W W",
        "W WWWWWW W W WWWWW W WWW WWWWWW W WWW W",
        "W W       W     W W W   W       W     W",
        "W W WWWWWWW WWWWW W WWWWWWWWWWWWWWWWWWW",
        "W W     W   W   W W W         W   W   W",
        "W WWW W W WWW W W W WWWWWWWWW W W W W W",
        "W     W     W W     W       W W W W   W",
        "W WWWWWWWWW W W WWWWWWWWWWWW W W WWWWW W",
        "W     W     W W W     W     W W   W   W",
        "W WWW W WWWWW W W W WWW WWW W WWW W W W",
        "W W   W     W W W W W W   W     W W W W",
        "W WWWWWWWWW W W W W W W WWWWWWWWW W W W",
        "W           W W   W W     W     W     W",
        "WWWWWWWWWWW WWWWWWW WWWWW W WWW W WWWWW",
        "W           W       W   W W W   W     W",
        "W WWWWWWWWWWW WWWWWWW W W W W WWWWWWWWW",
        "W       W     W   W   W W W W   W     W",
        "WWWWWWWW W WWWWW W WWW W W W W WWWWW W W",
        "W         W   W W W   W W W   W     W W",
        "W WWWWWWWWW W W W W WWW W WWWWW WWWWW W",
        "W W       W W W W     W     W         W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

another_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S   W   W         W             W   W",
        "W WWW W W W WWWWW W WWW WWWWWWWWWWWW W W",
        "W W   W W W     W W   W W         W   W",
        "W W W W W WWWWW W WWW W W WWWWWWWWWWWWW",
        "W W W W   W     W W   W W       W     W",
        "W W W WWW W WWWWW W WWWWW WWWWWW W WWW",
        "W   W     W       W     W       W     W",
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W     W         W     W     W       W W",
        "W WWWWWWWWWWWW W WWWWWWWWW W WWWWWWWW W",
        "W   W       W W W       W W W     W   W",
        "WWW W WWWWW W W WWWWW W W W W WWWWW WWW",
        "W   W   W   W     W   W W W   W     W W",
        "W WWWWW W WWWWWWW W WWWWW WWWWWWWWW W W",
        "W       W       W W   W     W       W W",
        "W WWWWWWWWWWWWWWW WWWWW WWWWWWWWWWWWWWW",
        "W       W       W       W         W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W WWW",
        "W     W       W       W         W W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W           W   W       W           W W",
        "WWWWWWWWWWW W W WWWWW W W WWWWWWWWWW W",
        "W           W W       W W         W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W",
        "W     W             W         W     W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W",
        "W   W     W       W       W         W W",
        "WWW W W WWWWWWWW WWWWWWW W WWWWWWWWWWWW",
        "W     W         W       W     W       W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

mazes = [
    (new_maze_data, (5, 5), 33, 33, 33),
    (new_maze_data_2, (5, 5), 33, 33, 33),
    (different_maze_data, (5, 5), 33, 33, 33),
    (another_maze_data, (5, 5), 33, 33, 33)  # Add another maze data
]

# Creating a PDF with the maze plots
pdf_filename = "mazes_FNT_4_GREEN.pdf"
with PdfPages(pdf_filename) as pdf:
    for maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize in mazes:
        fig = create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize)
        pdf.savefig(fig)
        plt.close(fig)

# Output PDF filename for download
pdf_filename
# Out:
# 'mazes_FNT_4_GREEN.pdf'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Function to create maze plot
def create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize):
    # Ensure all rows have the same length by padding with spaces if necessary
    max_length = max(len(row) for row in maze_data)
    maze_data = [row.ljust(max_length) for row in maze_data]

    # Create a 2D list from the maze data
    maze_list = []
    for row in maze_data:
        row_list = []
        for char in row:
            if (char == 'W'):
                row_list.append(1)  # Wall
            elif char == ' ':
                row_list.append(0)  # Path
            elif char == 'S':
                row_list.append(2)  # Start
            elif char == 'E':
                row_list.append(3)  # End
        maze_list.append(row_list)

    # Convert the 2D list to a numpy array
    maze_array = np.array(maze_list)

    # Create a plot with a large enough figure size
    fig, ax = plt.subplots(figsize=fig_size)
  # Draw the maze using very thin lines for the walls
    for i in range(maze_array.shape[0]):
        for j in range(maze_array.shape[1]):
            if maze_array[i, j] == 1:
                # Draw a wall with very thin lines
                ax.plot([j, j+1], [i, i], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j+1], [i+1, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j], [i, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j+1, j+1], [i, i+1], color='#D1EBB8', linewidth=0.1)


    # Adding the start and end labels
    start_pos = (maze_array.shape[0] - 1, 0)
    ax.text(start_pos[1] - 1, start_pos[0], 'START', ha='right', va='center', fontsize=5, fontweight='bold', color='#D1EBB8')

    end_pos = (0, maze_array.shape[1] - 1)
    ax.text(end_pos[1] + 1, end_pos[0], 'END', ha='left', va='center', fontsize=5, fontweight='bold', color='#D1EBB8')

    # Set plot limits
    ax.set_xlim(-1, maze_array.shape[1])
    ax.set_ylim(-1, maze_array.shape[0])

    # Turn off the axes
    ax.set_xticks([])
    ax.set_yticks([])

    # Remove the plot outline (spines)
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Set background color to white
    ax.set_facecolor('white')

    return fig


# Define maze data
new_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S       W       W                   W",
        "W WWWWW W WWWWW W WWWWWWWWWWWWWWWWWWWWW",
        "W W     W     W W W                 W W",
        "W W WWWWW W WWWWW W WWWWWWWWWWWWWWW W W",
        "W W     W W       W W           W W W W",
        "W WWWWW W WWWWWWWWW W WWWWWWWWWW W W W",
        "W       W         W W       W     W   W",
        "WWWWWWWWWWWWWWW W W WWWWWWW W WWWWWWWWW",
        "W           W   W W W       W       W W",
        "W WWWWWWWW W WWWWW W W WWWWWWWWWWWWWW W",
        "W W       W       W W       W       W W",
        "W W WWWWWWWWWWWWWWWWWWWWWW W W WWWWWWWWW",
        "W W W     W             W W W W         W",
        "W W W WWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W W               W",
        "W W WWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W   W             W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W W W W                             W W W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W",
        "W W W W                       W   W W W W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W W",
        "W W           W   W           W W W W W W",
        "W WWWWWWWWWWWWW W W WWWWWWWWW W W W W W W",
        "W                 W       W   W W W   W W",
        "W WWWWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWW W",
        "W W                     W W             W",
        "W W WWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW",
        "W W                       W             W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

new_maze_data_2 = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W         W       W         W W",
        "W WWWWW W WWWWWWW W WWW W WWWWWWWWW W W",
        "W     W W     W   W W W W         W W W",
        "WWWWWW W WWWWW WWW W W W WWWWWWWWWWW W W",
        "W     W       W W   W   W         W   W",
        "W WWWWWWWWWW W W WWW WWWWWWWWWWWWW W WWW",
        "W       W   W W     W     W     W W W W",
        "WWWWWWW W WWWWWWWWWWWWWWW W WWWWW W W W",
        "W     W W         W     W W     W W W W",
        "W WWWWW W WWWWWWW W WWWWWWW W WWWWW W W",
        "W     W W       W W   W   W W     W W W",
        "WWWWW W WWWWWWW W WWWWW W WWWWWWWWW W W",
        "W     W     W   W     W W       W   W W",
        "W WWWWWWWWW W WWWWWWW W W WWWWW W WWW W",
        "W         W W       W W W     W W     W",
        "WWWWWWWWWWWW WWWWWWW W W W WWWWWWWWWWWW",
        "W       W   W       W W W     W       W",
        "W WWWWW W WWW W WWWWW W WWWWW W W W WWW",
        "W   W   W   W W     W W       W W W   W",
        "W W WWWWWWWWW W WWWWWWWWWWWWWWW W WWWWW",
        "W W       W   W   W       W     W     W",
        "W WWW WWWWWWWWW W WWWWWWW W W WWWWWWWWW",
        "W     W       W W W     W W W W       W",
        "WWWWWWWWWWW W W W W WWWWW W W W WWWWW W",
        "W         W W W   W     W W   W     W W",
        "W WWWWWWWWW W WWWWW WWW W WWWWWWWWW W W",
        "W       W   W       W W W         W W W",
        "WWWWWWWW W WWWWWWWWWWW W WWWWWWWWW W W W",
        "W       W           W W     W     W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

different_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W     W       W           W   W",
        "W WWW W W W W W WWW W W WWWWWWWWWWWW W W",
        "W   W W W W W   W   W W       W     W W",
        "W W W W W W W W W WWWWW WWWWW W WWWWW W",
        "W W   W   W W W W   W     W W W     W W",
        "W WWW W W W W W W W WWWWWW W W WWW W W",
        "W     W W W W W W W       W     W   W W",
        "WWWWWWW WWW W W WWWWWWWWWWW WWWWWWWWWWW",
        "W       W   W W     W         W     W W",
        "W WWWWWW W W WWWWW W WWW WWWWWW W WWW W",
        "W W       W     W W W   W       W     W",
        "W W WWWWWWW WWWWW W WWWWWWWWWWWWWWWWWWW",
        "W W     W   W   W W W         W   W   W",
        "W WWW W W WWW W W W WWWWWWWWW W W W W W",
        "W     W     W W     W       W W W W   W",
        "W WWWWWWWWW W W WWWWWWWWWWWW W W WWWWW W",
        "W     W     W W W     W     W W   W   W",
        "W WWW W WWWWW W W W WWW WWW W WWW W W W",
        "W W   W     W W W W W W   W     W W W W",
        "W WWWWWWWWW W W W W W W WWWWWWWWW W W W",
        "W           W W   W W     W     W     W",
        "WWWWWWWWWWW WWWWWWW WWWWW W WWW W WWWWW",
        "W           W       W   W W W   W     W",
        "W WWWWWWWWWWW WWWWWWW W W W W WWWWWWWWW",
        "W       W     W   W   W W W W   W     W",
        "WWWWWWWW W WWWWW W WWW W W W W WWWWW W W",
        "W         W   W W W   W W W   W     W W",
        "W WWWWWWWWW W W W W WWW W WWWWW WWWWW W",
        "W W       W W W W     W     W         W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

another_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S   W   W         W             W   W",
        "W WWW W W W WWWWW W WWW WWWWWWWWWWWW W W",
        "W W   W W W     W W   W W         W   W",
        "W W W W W WWWWW W WWW W W WWWWWWWWWWWWW",
        "W W W W   W     W W   W W       W     W",
        "W W W WWW W WWWWW W WWWWW WWWWWW W WWW",
        "W   W     W       W     W       W     W",
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W     W         W     W     W       W W",
        "W WWWWWWWWWWWW W WWWWWWWWW W WWWWWWWW W",
        "W   W       W W W       W W W     W   W",
        "WWW W WWWWW W W WWWWW W W W W WWWWW WWW",
        "W   W   W   W     W   W W W   W     W W",
        "W WWWWW W WWWWWWW W WWWWW WWWWWWWWW W W",
        "W       W       W W   W     W       W W",
        "W WWWWWWWWWWWWWWW WWWWW WWWWWWWWWWWWWWW",
        "W       W       W       W         W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W WWW",
        "W     W       W       W         W W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W           W   W       W           W W",
        "WWWWWWWWWWW W W WWWWW W W WWWWWWWWWW W",
        "W           W W       W W         W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W",
        "W     W             W         W     W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W",
        "W   W     W       W       W         W W",
        "WWW W W WWWWWWWW WWWWWWW W WWWWWWWWWWWW",
        "W     W         W       W     W       W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

mazes = [
    (new_maze_data, (6, 6), 33, 33, 33),
    (new_maze_data_2, (6, 6), 33, 33, 33),
    (different_maze_data, (6, 6), 33, 33, 33),
    (another_maze_data, (6, 6), 33, 33, 33)  # Add another maze data
]

# Creating a PDF with the maze plots
pdf_filename = "mazes_FNT_5_GREEN.pdf"
with PdfPages(pdf_filename) as pdf:
    for maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize in mazes:
        fig = create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize)
        pdf.savefig(fig)
        plt.close(fig)

# Output PDF filename for download
pdf_filename
# Out:
# 'mazes_FNT_5_GREEN.pdf'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Function to create maze plot
def create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize):
    # Ensure all rows have the same length by padding with spaces if necessary
    max_length = max(len(row) for row in maze_data)
    maze_data = [row.ljust(max_length) for row in maze_data]

    # Create a 2D list from the maze data
    maze_list = []
    for row in maze_data:
        row_list = []
        for char in row:
            if (char == 'W'):
                row_list.append(1)  # Wall
            elif char == ' ':
                row_list.append(0)  # Path
            elif char == 'S':
                row_list.append(2)  # Start
            elif char == 'E':
                row_list.append(3)  # End
        maze_list.append(row_list)

    # Convert the 2D list to a numpy array
    maze_array = np.array(maze_list)

    # Create a plot with a large enough figure size
    fig, ax = plt.subplots(figsize=fig_size)
  # Draw the maze using very thin lines for the walls
    for i in range(maze_array.shape[0]):
        for j in range(maze_array.shape[1]):
            if maze_array[i, j] == 1:
                # Draw a wall with very thin lines
                ax.plot([j, j+1], [i, i], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j+1], [i+1, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j], [i, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j+1, j+1], [i, i+1], color='#D1EBB8', linewidth=0.1)


    # Adding the start and end labels
    start_pos = (maze_array.shape[0] - 1, 0)
    ax.text(start_pos[1] - 1, start_pos[0], 'START', ha='right', va='center', fontsize=6, fontweight='bold', color='#D1EBB8')

    end_pos = (0, maze_array.shape[1] - 1)
    ax.text(end_pos[1] + 1, end_pos[0], 'END', ha='left', va='center', fontsize=6, fontweight='bold', color='#D1EBB8')

    # Set plot limits
    ax.set_xlim(-1, maze_array.shape[1])
    ax.set_ylim(-1, maze_array.shape[0])

    # Turn off the axes
    ax.set_xticks([])
    ax.set_yticks([])

    # Remove the plot outline (spines)
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Set background color to white
    ax.set_facecolor('white')

    return fig


# Define maze data
new_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S       W       W                   W",
        "W WWWWW W WWWWW W WWWWWWWWWWWWWWWWWWWWW",
        "W W     W     W W W                 W W",
        "W W WWWWW W WWWWW W WWWWWWWWWWWWWWW W W",
        "W W     W W       W W           W W W W",
        "W WWWWW W WWWWWWWWW W WWWWWWWWWW W W W",
        "W       W         W W       W     W   W",
        "WWWWWWWWWWWWWWW W W WWWWWWW W WWWWWWWWW",
        "W           W   W W W       W       W W",
        "W WWWWWWWW W WWWWW W W WWWWWWWWWWWWWW W",
        "W W       W       W W       W       W W",
        "W W WWWWWWWWWWWWWWWWWWWWWW W W WWWWWWWWW",
        "W W W     W             W W W W         W",
        "W W W WWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W W               W",
        "W W WWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W   W             W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W W W W                             W W W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W",
        "W W W W                       W   W W W W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W W",
        "W W           W   W           W W W W W W",
        "W WWWWWWWWWWWWW W W WWWWWWWWW W W W W W W",
        "W                 W       W   W W W   W W",
        "W WWWWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWW W",
        "W W                     W W             W",
        "W W WWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW",
        "W W                       W             W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

new_maze_data_2 = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W         W       W         W W",
        "W WWWWW W WWWWWWW W WWW W WWWWWWWWW W W",
        "W     W W     W   W W W W         W W W",
        "WWWWWW W WWWWW WWW W W W WWWWWWWWWWW W W",
        "W     W       W W   W   W         W   W",
        "W WWWWWWWWWW W W WWW WWWWWWWWWWWWW W WWW",
        "W       W   W W     W     W     W W W W",
        "WWWWWWW W WWWWWWWWWWWWWWW W WWWWW W W W",
        "W     W W         W     W W     W W W W",
        "W WWWWW W WWWWWWW W WWWWWWW W WWWWW W W",
        "W     W W       W W   W   W W     W W W",
        "WWWWW W WWWWWWW W WWWWW W WWWWWWWWW W W",
        "W     W     W   W     W W       W   W W",
        "W WWWWWWWWW W WWWWWWW W W WWWWW W WWW W",
        "W         W W       W W W     W W     W",
        "WWWWWWWWWWWW WWWWWWW W W W WWWWWWWWWWWW",
        "W       W   W       W W W     W       W",
        "W WWWWW W WWW W WWWWW W WWWWW W W W WWW",
        "W   W   W   W W     W W       W W W   W",
        "W W WWWWWWWWW W WWWWWWWWWWWWWWW W WWWWW",
        "W W       W   W   W       W     W     W",
        "W WWW WWWWWWWWW W WWWWWWW W W WWWWWWWWW",
        "W     W       W W W     W W W W       W",
        "WWWWWWWWWWW W W W W WWWWW W W W WWWWW W",
        "W         W W W   W     W W   W     W W",
        "W WWWWWWWWW W WWWWW WWW W WWWWWWWWW W W",
        "W       W   W       W W W         W W W",
        "WWWWWWWW W WWWWWWWWWWW W WWWWWWWWW W W W",
        "W       W           W W     W     W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

different_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W     W       W           W   W",
        "W WWW W W W W W WWW W W WWWWWWWWWWWW W W",
        "W   W W W W W   W   W W       W     W W",
        "W W W W W W W W W WWWWW WWWWW W WWWWW W",
        "W W   W   W W W W   W     W W W     W W",
        "W WWW W W W W W W W WWWWWW W W WWW W W",
        "W     W W W W W W W       W     W   W W",
        "WWWWWWW WWW W W WWWWWWWWWWW WWWWWWWWWWW",
        "W       W   W W     W         W     W W",
        "W WWWWWW W W WWWWW W WWW WWWWWW W WWW W",
        "W W       W     W W W   W       W     W",
        "W W WWWWWWW WWWWW W WWWWWWWWWWWWWWWWWWW",
        "W W     W   W   W W W         W   W   W",
        "W WWW W W WWW W W W WWWWWWWWW W W W W W",
        "W     W     W W     W       W W W W   W",
        "W WWWWWWWWW W W WWWWWWWWWWWW W W WWWWW W",
        "W     W     W W W     W     W W   W   W",
        "W WWW W WWWWW W W W WWW WWW W WWW W W W",
        "W W   W     W W W W W W   W     W W W W",
        "W WWWWWWWWW W W W W W W WWWWWWWWW W W W",
        "W           W W   W W     W     W     W",
        "WWWWWWWWWWW WWWWWWW WWWWW W WWW W WWWWW",
        "W           W       W   W W W   W     W",
        "W WWWWWWWWWWW WWWWWWW W W W W WWWWWWWWW",
        "W       W     W   W   W W W W   W     W",
        "WWWWWWWW W WWWWW W WWW W W W W WWWWW W W",
        "W         W   W W W   W W W   W     W W",
        "W WWWWWWWWW W W W W WWW W WWWWW WWWWW W",
        "W W       W W W W     W     W         W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

another_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S   W   W         W             W   W",
        "W WWW W W W WWWWW W WWW WWWWWWWWWWWW W W",
        "W W   W W W     W W   W W         W   W",
        "W W W W W WWWWW W WWW W W WWWWWWWWWWWWW",
        "W W W W   W     W W   W W       W     W",
        "W W W WWW W WWWWW W WWWWW WWWWWW W WWW",
        "W   W     W       W     W       W     W",
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W     W         W     W     W       W W",
        "W WWWWWWWWWWWW W WWWWWWWWW W WWWWWWWW W",
        "W   W       W W W       W W W     W   W",
        "WWW W WWWWW W W WWWWW W W W W WWWWW WWW",
        "W   W   W   W     W   W W W   W     W W",
        "W WWWWW W WWWWWWW W WWWWW WWWWWWWWW W W",
        "W       W       W W   W     W       W W",
        "W WWWWWWWWWWWWWWW WWWWW WWWWWWWWWWWWWWW",
        "W       W       W       W         W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W WWW",
        "W     W       W       W         W W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W           W   W       W           W W",
        "WWWWWWWWWWW W W WWWWW W W WWWWWWWWWW W",
        "W           W W       W W         W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W",
        "W     W             W         W     W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W",
        "W   W     W       W       W         W W",
        "WWW W W WWWWWWWW WWWWWWW W WWWWWWWWWWWW",
        "W     W         W       W     W       W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

mazes = [
    (new_maze_data, (7, 7), 33, 33, 33),
    (new_maze_data_2, (7, 7), 33, 33, 33),
    (different_maze_data, (7, 7), 33, 33, 33),
    (another_maze_data, (7, 7), 33, 33, 33)  # Add another maze data
]

# Creating a PDF with the maze plots
pdf_filename = "mazes_FNT_6_GREEN.pdf"
with PdfPages(pdf_filename) as pdf:
    for maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize in mazes:
        fig = create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize)
        pdf.savefig(fig)
        plt.close(fig)

# Output PDF filename for download
pdf_filename
# Out:
# 'mazes_FNT_6_GREEN.pdf'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Function to create maze plot
def create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize):
    # Ensure all rows have the same length by padding with spaces if necessary
    max_length = max(len(row) for row in maze_data)
    maze_data = [row.ljust(max_length) for row in maze_data]

    # Create a 2D list from the maze data
    maze_list = []
    for row in maze_data:
        row_list = []
        for char in row:
            if (char == 'W'):
                row_list.append(1)  # Wall
            elif char == ' ':
                row_list.append(0)  # Path
            elif char == 'S':
                row_list.append(2)  # Start
            elif char == 'E':
                row_list.append(3)  # End
        maze_list.append(row_list)

    # Convert the 2D list to a numpy array
    maze_array = np.array(maze_list)

    # Create a plot with a large enough figure size
    fig, ax = plt.subplots(figsize=fig_size)
  # Draw the maze using very thin lines for the walls
    for i in range(maze_array.shape[0]):
        for j in range(maze_array.shape[1]):
            if maze_array[i, j] == 1:
                # Draw a wall with very thin lines
                ax.plot([j, j+1], [i, i], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j+1], [i+1, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j], [i, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j+1, j+1], [i, i+1], color='#D1EBB8', linewidth=0.1)


    # Adding the start and end labels
    start_pos = (maze_array.shape[0] - 1, 0)
    ax.text(start_pos[1] - 1, start_pos[0], 'START', ha='right', va='center', fontsize=8, fontweight='bold', color='#D1EBB8')

    end_pos = (0, maze_array.shape[1] - 1)
    ax.text(end_pos[1] + 1, end_pos[0], 'END', ha='left', va='center', fontsize=8, fontweight='bold', color='#D1EBB8')

    # Set plot limits
    ax.set_xlim(-1, maze_array.shape[1])
    ax.set_ylim(-1, maze_array.shape[0])

    # Turn off the axes
    ax.set_xticks([])
    ax.set_yticks([])

    # Remove the plot outline (spines)
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Set background color to white
    ax.set_facecolor('white')

    return fig


# Define maze data
new_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S       W       W                   W",
        "W WWWWW W WWWWW W WWWWWWWWWWWWWWWWWWWWW",
        "W W     W     W W W                 W W",
        "W W WWWWW W WWWWW W WWWWWWWWWWWWWWW W W",
        "W W     W W       W W           W W W W",
        "W WWWWW W WWWWWWWWW W WWWWWWWWWW W W W",
        "W       W         W W       W     W   W",
        "WWWWWWWWWWWWWWW W W WWWWWWW W WWWWWWWWW",
        "W           W   W W W       W       W W",
        "W WWWWWWWW W WWWWW W W WWWWWWWWWWWWWW W",
        "W W       W       W W       W       W W",
        "W W WWWWWWWWWWWWWWWWWWWWWW W W WWWWWWWWW",
        "W W W     W             W W W W         W",
        "W W W WWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W W               W",
        "W W WWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W   W             W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W W W W                             W W W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W",
        "W W W W                       W   W W W W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W W",
        "W W           W   W           W W W W W W",
        "W WWWWWWWWWWWWW W W WWWWWWWWW W W W W W W",
        "W                 W       W   W W W   W W",
        "W WWWWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWW W",
        "W W                     W W             W",
        "W W WWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW",
        "W W                       W             W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

new_maze_data_2 = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W         W       W         W W",
        "W WWWWW W WWWWWWW W WWW W WWWWWWWWW W W",
        "W     W W     W   W W W W         W W W",
        "WWWWWW W WWWWW WWW W W W WWWWWWWWWWW W W",
        "W     W       W W   W   W         W   W",
        "W WWWWWWWWWW W W WWW WWWWWWWWWWWWW W WWW",
        "W       W   W W     W     W     W W W W",
        "WWWWWWW W WWWWWWWWWWWWWWW W WWWWW W W W",
        "W     W W         W     W W     W W W W",
        "W WWWWW W WWWWWWW W WWWWWWW W WWWWW W W",
        "W     W W       W W   W   W W     W W W",
        "WWWWW W WWWWWWW W WWWWW W WWWWWWWWW W W",
        "W     W     W   W     W W       W   W W",
        "W WWWWWWWWW W WWWWWWW W W WWWWW W WWW W",
        "W         W W       W W W     W W     W",
        "WWWWWWWWWWWW WWWWWWW W W W WWWWWWWWWWWW",
        "W       W   W       W W W     W       W",
        "W WWWWW W WWW W WWWWW W WWWWW W W W WWW",
        "W   W   W   W W     W W       W W W   W",
        "W W WWWWWWWWW W WWWWWWWWWWWWWWW W WWWWW",
        "W W       W   W   W       W     W     W",
        "W WWW WWWWWWWWW W WWWWWWW W W WWWWWWWWW",
        "W     W       W W W     W W W W       W",
        "WWWWWWWWWWW W W W W WWWWW W W W WWWWW W",
        "W         W W W   W     W W   W     W W",
        "W WWWWWWWWW W WWWWW WWW W WWWWWWWWW W W",
        "W       W   W       W W W         W W W",
        "WWWWWWWW W WWWWWWWWWWW W WWWWWWWWW W W W",
        "W       W           W W     W     W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

different_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W     W       W           W   W",
        "W WWW W W W W W WWW W W WWWWWWWWWWWW W W",
        "W   W W W W W   W   W W       W     W W",
        "W W W W W W W W W WWWWW WWWWW W WWWWW W",
        "W W   W   W W W W   W     W W W     W W",
        "W WWW W W W W W W W WWWWWW W W WWW W W",
        "W     W W W W W W W       W     W   W W",
        "WWWWWWW WWW W W WWWWWWWWWWW WWWWWWWWWWW",
        "W       W   W W     W         W     W W",
        "W WWWWWW W W WWWWW W WWW WWWWWW W WWW W",
        "W W       W     W W W   W       W     W",
        "W W WWWWWWW WWWWW W WWWWWWWWWWWWWWWWWWW",
        "W W     W   W   W W W         W   W   W",
        "W WWW W W WWW W W W WWWWWWWWW W W W W W",
        "W     W     W W     W       W W W W   W",
        "W WWWWWWWWW W W WWWWWWWWWWWW W W WWWWW W",
        "W     W     W W W     W     W W   W   W",
        "W WWW W WWWWW W W W WWW WWW W WWW W W W",
        "W W   W     W W W W W W   W     W W W W",
        "W WWWWWWWWW W W W W W W WWWWWWWWW W W W",
        "W           W W   W W     W     W     W",
        "WWWWWWWWWWW WWWWWWW WWWWW W WWW W WWWWW",
        "W           W       W   W W W   W     W",
        "W WWWWWWWWWWW WWWWWWW W W W W WWWWWWWWW",
        "W       W     W   W   W W W W   W     W",
        "WWWWWWWW W WWWWW W WWW W W W W WWWWW W W",
        "W         W   W W W   W W W   W     W W",
        "W WWWWWWWWW W W W W WWW W WWWWW WWWWW W",
        "W W       W W W W     W     W         W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

another_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S   W   W         W             W   W",
        "W WWW W W W WWWWW W WWW WWWWWWWWWWWW W W",
        "W W   W W W     W W   W W         W   W",
        "W W W W W WWWWW W WWW W W WWWWWWWWWWWWW",
        "W W W W   W     W W   W W       W     W",
        "W W W WWW W WWWWW W WWWWW WWWWWW W WWW",
        "W   W     W       W     W       W     W",
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W     W         W     W     W       W W",
        "W WWWWWWWWWWWW W WWWWWWWWW W WWWWWWWW W",
        "W   W       W W W       W W W     W   W",
        "WWW W WWWWW W W WWWWW W W W W WWWWW WWW",
        "W   W   W   W     W   W W W   W     W W",
        "W WWWWW W WWWWWWW W WWWWW WWWWWWWWW W W",
        "W       W       W W   W     W       W W",
        "W WWWWWWWWWWWWWWW WWWWW WWWWWWWWWWWWWWW",
        "W       W       W       W         W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W WWW",
        "W     W       W       W         W W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W           W   W       W           W W",
        "WWWWWWWWWWW W W WWWWW W W WWWWWWWWWW W",
        "W           W W       W W         W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W",
        "W     W             W         W     W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W",
        "W   W     W       W       W         W W",
        "WWW W W WWWWWWWW WWWWWWW W WWWWWWWWWWWW",
        "W     W         W       W     W       W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

mazes = [
    (new_maze_data, (10, 10), 33, 33, 33),
    (new_maze_data_2, (10, 10), 33, 33, 33),
    (different_maze_data, (10, 10), 33, 33, 33),
    (another_maze_data, (10, 10), 33, 33, 33)  # Add another maze data
]

# Creating a PDF with the maze plots
pdf_filename = "mazes_FNT_8_GREEN.pdf"
with PdfPages(pdf_filename) as pdf:
    for maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize in mazes:
        fig = create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize)
        pdf.savefig(fig)
        plt.close(fig)

# Output PDF filename for download
pdf_filename
# Out:
# 'mazes_FNT_8_GREEN.pdf'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Function to create maze plot
def create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize):
    # Ensure all rows have the same length by padding with spaces if necessary
    max_length = max(len(row) for row in maze_data)
    maze_data = [row.ljust(max_length) for row in maze_data]

    # Create a 2D list from the maze data
    maze_list = []
    for row in maze_data:
        row_list = []
        for char in row:
            if (char == 'W'):
                row_list.append(1)  # Wall
            elif char == ' ':
                row_list.append(0)  # Path
            elif char == 'S':
                row_list.append(2)  # Start
            elif char == 'E':
                row_list.append(3)  # End
        maze_list.append(row_list)

    # Convert the 2D list to a numpy array
    maze_array = np.array(maze_list)

    # Create a plot with a large enough figure size
    fig, ax = plt.subplots(figsize=fig_size)
  # Draw the maze using very thin lines for the walls
    for i in range(maze_array.shape[0]):
        for j in range(maze_array.shape[1]):
            if maze_array[i, j] == 1:
                # Draw a wall with very thin lines
                ax.plot([j, j+1], [i, i], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j+1], [i+1, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j], [i, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j+1, j+1], [i, i+1], color='#D1EBB8', linewidth=0.1)


    # Adding the start and end labels
    start_pos = (maze_array.shape[0] - 1, 0)
    ax.text(start_pos[1] - 1, start_pos[0], 'START', ha='right', va='center', fontsize=10, fontweight='bold', color='#D1EBB8')

    end_pos = (0, maze_array.shape[1] - 1)
    ax.text(end_pos[1] + 1, end_pos[0], 'END', ha='left', va='center', fontsize=10, fontweight='bold', color='#D1EBB8')

    # Set plot limits
    ax.set_xlim(-1, maze_array.shape[1])
    ax.set_ylim(-1, maze_array.shape[0])

    # Turn off the axes
    ax.set_xticks([])
    ax.set_yticks([])

    # Remove the plot outline (spines)
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Set background color to white
    ax.set_facecolor('white')

    return fig


# Define maze data
new_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S       W       W                   W",
        "W WWWWW W WWWWW W WWWWWWWWWWWWWWWWWWWWW",
        "W W     W     W W W                 W W",
        "W W WWWWW W WWWWW W WWWWWWWWWWWWWWW W W",
        "W W     W W       W W           W W W W",
        "W WWWWW W WWWWWWWWW W WWWWWWWWWW W W W",
        "W       W         W W       W     W   W",
        "WWWWWWWWWWWWWWW W W WWWWWWW W WWWWWWWWW",
        "W           W   W W W       W       W W",
        "W WWWWWWWW W WWWWW W W WWWWWWWWWWWWWW W",
        "W W       W       W W       W       W W",
        "W W WWWWWWWWWWWWWWWWWWWWWW W W WWWWWWWWW",
        "W W W     W             W W W W         W",
        "W W W WWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W W               W",
        "W W WWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W   W             W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W W W W                             W W W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W",
        "W W W W                       W   W W W W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W W",
        "W W           W   W           W W W W W W",
        "W WWWWWWWWWWWWW W W WWWWWWWWW W W W W W W",
        "W                 W       W   W W W   W W",
        "W WWWWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWW W",
        "W W                     W W             W",
        "W W WWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW",
        "W W                       W             W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

new_maze_data_2 = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W         W       W         W W",
        "W WWWWW W WWWWWWW W WWW W WWWWWWWWW W W",
        "W     W W     W   W W W W         W W W",
        "WWWWWW W WWWWW WWW W W W WWWWWWWWWWW W W",
        "W     W       W W   W   W         W   W",
        "W WWWWWWWWWW W W WWW WWWWWWWWWWWWW W WWW",
        "W       W   W W     W     W     W W W W",
        "WWWWWWW W WWWWWWWWWWWWWWW W WWWWW W W W",
        "W     W W         W     W W     W W W W",
        "W WWWWW W WWWWWWW W WWWWWWW W WWWWW W W",
        "W     W W       W W   W   W W     W W W",
        "WWWWW W WWWWWWW W WWWWW W WWWWWWWWW W W",
        "W     W     W   W     W W       W   W W",
        "W WWWWWWWWW W WWWWWWW W W WWWWW W WWW W",
        "W         W W       W W W     W W     W",
        "WWWWWWWWWWWW WWWWWWW W W W WWWWWWWWWWWW",
        "W       W   W       W W W     W       W",
        "W WWWWW W WWW W WWWWW W WWWWW W W W WWW",
        "W   W   W   W W     W W       W W W   W",
        "W W WWWWWWWWW W WWWWWWWWWWWWWWW W WWWWW",
        "W W       W   W   W       W     W     W",
        "W WWW WWWWWWWWW W WWWWWWW W W WWWWWWWWW",
        "W     W       W W W     W W W W       W",
        "WWWWWWWWWWW W W W W WWWWW W W W WWWWW W",
        "W         W W W   W     W W   W     W W",
        "W WWWWWWWWW W WWWWW WWW W WWWWWWWWW W W",
        "W       W   W       W W W         W W W",
        "WWWWWWWW W WWWWWWWWWWW W WWWWWWWWW W W W",
        "W       W           W W     W     W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

different_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W     W       W           W   W",
        "W WWW W W W W W WWW W W WWWWWWWWWWWW W W",
        "W   W W W W W   W   W W       W     W W",
        "W W W W W W W W W WWWWW WWWWW W WWWWW W",
        "W W   W   W W W W   W     W W W     W W",
        "W WWW W W W W W W W WWWWWW W W WWW W W",
        "W     W W W W W W W       W     W   W W",
        "WWWWWWW WWW W W WWWWWWWWWWW WWWWWWWWWWW",
        "W       W   W W     W         W     W W",
        "W WWWWWW W W WWWWW W WWW WWWWWW W WWW W",
        "W W       W     W W W   W       W     W",
        "W W WWWWWWW WWWWW W WWWWWWWWWWWWWWWWWWW",
        "W W     W   W   W W W         W   W   W",
        "W WWW W W WWW W W W WWWWWWWWW W W W W W",
        "W     W     W W     W       W W W W   W",
        "W WWWWWWWWW W W WWWWWWWWWWWW W W WWWWW W",
        "W     W     W W W     W     W W   W   W",
        "W WWW W WWWWW W W W WWW WWW W WWW W W W",
        "W W   W     W W W W W W   W     W W W W",
        "W WWWWWWWWW W W W W W W WWWWWWWWW W W W",
        "W           W W   W W     W     W     W",
        "WWWWWWWWWWW WWWWWWW WWWWW W WWW W WWWWW",
        "W           W       W   W W W   W     W",
        "W WWWWWWWWWWW WWWWWWW W W W W WWWWWWWWW",
        "W       W     W   W   W W W W   W     W",
        "WWWWWWWW W WWWWW W WWW W W W W WWWWW W W",
        "W         W   W W W   W W W   W     W W",
        "W WWWWWWWWW W W W W WWW W WWWWW WWWWW W",
        "W W       W W W W     W     W         W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

another_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S   W   W         W             W   W",
        "W WWW W W W WWWWW W WWW WWWWWWWWWWWW W W",
        "W W   W W W     W W   W W         W   W",
        "W W W W W WWWWW W WWW W W WWWWWWWWWWWWW",
        "W W W W   W     W W   W W       W     W",
        "W W W WWW W WWWWW W WWWWW WWWWWW W WWW",
        "W   W     W       W     W       W     W",
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W     W         W     W     W       W W",
        "W WWWWWWWWWWWW W WWWWWWWWW W WWWWWWWW W",
        "W   W       W W W       W W W     W   W",
        "WWW W WWWWW W W WWWWW W W W W WWWWW WWW",
        "W   W   W   W     W   W W W   W     W W",
        "W WWWWW W WWWWWWW W WWWWW WWWWWWWWW W W",
        "W       W       W W   W     W       W W",
        "W WWWWWWWWWWWWWWW WWWWW WWWWWWWWWWWWWWW",
        "W       W       W       W         W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W WWW",
        "W     W       W       W         W W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W           W   W       W           W W",
        "WWWWWWWWWWW W W WWWWW W W WWWWWWWWWW W",
        "W           W W       W W         W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W",
        "W     W             W         W     W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W",
        "W   W     W       W       W         W W",
        "WWW W W WWWWWWWW WWWWWWW W WWWWWWWWWWWW",
        "W     W         W       W     W       W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

mazes = [
    (new_maze_data, (11, 11), 33, 33, 33),
    (new_maze_data_2, (11, 11), 33, 33, 33),
    (different_maze_data, (11, 11), 33, 33, 33),
    (another_maze_data, (11, 11), 33, 33, 33)  # Add another maze data
]

# Creating a PDF with the maze plots
pdf_filename = "mazes_FNT_10_GREEN.pdf"
with PdfPages(pdf_filename) as pdf:
    for maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize in mazes:
        fig = create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize)
        pdf.savefig(fig)
        plt.close(fig)

# Output PDF filename for download
pdf_filename
# Out:
# 'mazes_FNT_10_GREEN.pdf'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Function to create maze plot
def create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize):
    # Ensure all rows have the same length by padding with spaces if necessary
    max_length = max(len(row) for row in maze_data)
    maze_data = [row.ljust(max_length) for row in maze_data]

    # Create a 2D list from the maze data
    maze_list = []
    for row in maze_data:
        row_list = []
        for char in row:
            if (char == 'W'):
                row_list.append(1)  # Wall
            elif char == ' ':
                row_list.append(0)  # Path
            elif char == 'S':
                row_list.append(2)  # Start
            elif char == 'E':
                row_list.append(3)  # End
        maze_list.append(row_list)

    # Convert the 2D list to a numpy array
    maze_array = np.array(maze_list)

    # Create a plot with a large enough figure size
    fig, ax = plt.subplots(figsize=fig_size)
  # Draw the maze using very thin lines for the walls
    for i in range(maze_array.shape[0]):
        for j in range(maze_array.shape[1]):
            if maze_array[i, j] == 1:
                # Draw a wall with very thin lines
                ax.plot([j, j+1], [i, i], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j+1], [i+1, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j], [i, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j+1, j+1], [i, i+1], color='#D1EBB8', linewidth=0.1)


    # Adding the start and end labels
    start_pos = (maze_array.shape[0] - 1, 0)
    ax.text(start_pos[1] - 1, start_pos[0], 'START', ha='right', va='center', fontsize=14, fontweight='bold', color='#D1EBB8')

    end_pos = (0, maze_array.shape[1] - 1)
    ax.text(end_pos[1] + 1, end_pos[0], 'END', ha='left', va='center', fontsize=14, fontweight='bold', color='#D1EBB8')

    # Set plot limits
    ax.set_xlim(-1, maze_array.shape[1])
    ax.set_ylim(-1, maze_array.shape[0])

    # Turn off the axes
    ax.set_xticks([])
    ax.set_yticks([])

    # Remove the plot outline (spines)
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Set background color to white
    ax.set_facecolor('white')

    return fig


# Define maze data
new_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S       W       W                   W",
        "W WWWWW W WWWWW W WWWWWWWWWWWWWWWWWWWWW",
        "W W     W     W W W                 W W",
        "W W WWWWW W WWWWW W WWWWWWWWWWWWWWW W W",
        "W W     W W       W W           W W W W",
        "W WWWWW W WWWWWWWWW W WWWWWWWWWW W W W",
        "W       W         W W       W     W   W",
        "WWWWWWWWWWWWWWW W W WWWWWWW W WWWWWWWWW",
        "W           W   W W W       W       W W",
        "W WWWWWWWW W WWWWW W W WWWWWWWWWWWWWW W",
        "W W       W       W W       W       W W",
        "W W WWWWWWWWWWWWWWWWWWWWWW W W WWWWWWWWW",
        "W W W     W             W W W W         W",
        "W W W WWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W W               W",
        "W W WWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W   W             W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W W W W                             W W W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W",
        "W W W W                       W   W W W W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W W",
        "W W           W   W           W W W W W W",
        "W WWWWWWWWWWWWW W W WWWWWWWWW W W W W W W",
        "W                 W       W   W W W   W W",
        "W WWWWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWW W",
        "W W                     W W             W",
        "W W WWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW",
        "W W                       W             W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

new_maze_data_2 = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W         W       W         W W",
        "W WWWWW W WWWWWWW W WWW W WWWWWWWWW W W",
        "W     W W     W   W W W W         W W W",
        "WWWWWW W WWWWW WWW W W W WWWWWWWWWWW W W",
        "W     W       W W   W   W         W   W",
        "W WWWWWWWWWW W W WWW WWWWWWWWWWWWW W WWW",
        "W       W   W W     W     W     W W W W",
        "WWWWWWW W WWWWWWWWWWWWWWW W WWWWW W W W",
        "W     W W         W     W W     W W W W",
        "W WWWWW W WWWWWWW W WWWWWWW W WWWWW W W",
        "W     W W       W W   W   W W     W W W",
        "WWWWW W WWWWWWW W WWWWW W WWWWWWWWW W W",
        "W     W     W   W     W W       W   W W",
        "W WWWWWWWWW W WWWWWWW W W WWWWW W WWW W",
        "W         W W       W W W     W W     W",
        "WWWWWWWWWWWW WWWWWWW W W W WWWWWWWWWWWW",
        "W       W   W       W W W     W       W",
        "W WWWWW W WWW W WWWWW W WWWWW W W W WWW",
        "W   W   W   W W     W W       W W W   W",
        "W W WWWWWWWWW W WWWWWWWWWWWWWWW W WWWWW",
        "W W       W   W   W       W     W     W",
        "W WWW WWWWWWWWW W WWWWWWW W W WWWWWWWWW",
        "W     W       W W W     W W W W       W",
        "WWWWWWWWWWW W W W W WWWWW W W W WWWWW W",
        "W         W W W   W     W W   W     W W",
        "W WWWWWWWWW W WWWWW WWW W WWWWWWWWW W W",
        "W       W   W       W W W         W W W",
        "WWWWWWWW W WWWWWWWWWWW W WWWWWWWWW W W W",
        "W       W           W W     W     W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

different_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W     W       W           W   W",
        "W WWW W W W W W WWW W W WWWWWWWWWWWW W W",
        "W   W W W W W   W   W W       W     W W",
        "W W W W W W W W W WWWWW WWWWW W WWWWW W",
        "W W   W   W W W W   W     W W W     W W",
        "W WWW W W W W W W W WWWWWW W W WWW W W",
        "W     W W W W W W W       W     W   W W",
        "WWWWWWW WWW W W WWWWWWWWWWW WWWWWWWWWWW",
        "W       W   W W     W         W     W W",
        "W WWWWWW W W WWWWW W WWW WWWWWW W WWW W",
        "W W       W     W W W   W       W     W",
        "W W WWWWWWW WWWWW W WWWWWWWWWWWWWWWWWWW",
        "W W     W   W   W W W         W   W   W",
        "W WWW W W WWW W W W WWWWWWWWW W W W W W",
        "W     W     W W     W       W W W W   W",
        "W WWWWWWWWW W W WWWWWWWWWWWW W W WWWWW W",
        "W     W     W W W     W     W W   W   W",
        "W WWW W WWWWW W W W WWW WWW W WWW W W W",
        "W W   W     W W W W W W   W     W W W W",
        "W WWWWWWWWW W W W W W W WWWWWWWWW W W W",
        "W           W W   W W     W     W     W",
        "WWWWWWWWWWW WWWWWWW WWWWW W WWW W WWWWW",
        "W           W       W   W W W   W     W",
        "W WWWWWWWWWWW WWWWWWW W W W W WWWWWWWWW",
        "W       W     W   W   W W W W   W     W",
        "WWWWWWWW W WWWWW W WWW W W W W WWWWW W W",
        "W         W   W W W   W W W   W     W W",
        "W WWWWWWWWW W W W W WWW W WWWWW WWWWW W",
        "W W       W W W W     W     W         W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

another_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S   W   W         W             W   W",
        "W WWW W W W WWWWW W WWW WWWWWWWWWWWW W W",
        "W W   W W W     W W   W W         W   W",
        "W W W W W WWWWW W WWW W W WWWWWWWWWWWWW",
        "W W W W   W     W W   W W       W     W",
        "W W W WWW W WWWWW W WWWWW WWWWWW W WWW",
        "W   W     W       W     W       W     W",
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W     W         W     W     W       W W",
        "W WWWWWWWWWWWW W WWWWWWWWW W WWWWWWWW W",
        "W   W       W W W       W W W     W   W",
        "WWW W WWWWW W W WWWWW W W W W WWWWW WWW",
        "W   W   W   W     W   W W W   W     W W",
        "W WWWWW W WWWWWWW W WWWWW WWWWWWWWW W W",
        "W       W       W W   W     W       W W",
        "W WWWWWWWWWWWWWWW WWWWW WWWWWWWWWWWWWWW",
        "W       W       W       W         W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W WWW",
        "W     W       W       W         W W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W           W   W       W           W W",
        "WWWWWWWWWWW W W WWWWW W W WWWWWWWWWW W",
        "W           W W       W W         W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W",
        "W     W             W         W     W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W",
        "W   W     W       W       W         W W",
        "WWW W W WWWWWWWW WWWWWWW W WWWWWWWWWWWW",
        "W     W         W       W     W       W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

mazes = [
    (new_maze_data, (12, 12), 33, 33, 33),
    (new_maze_data_2, (12, 12), 33, 33, 33),
    (different_maze_data, (12, 12), 33, 33, 33),
    (another_maze_data, (12, 12), 33, 33, 33)  # Add another maze data
]

# Creating a PDF with the maze plots
pdf_filename = "mazes_FNT_14_GREEN.pdf"
with PdfPages(pdf_filename) as pdf:
    for maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize in mazes:
        fig = create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize)
        pdf.savefig(fig)
        plt.close(fig)

# Output PDF filename for download
pdf_filename
# Out:
# 'mazes_FNT_14_GREEN.pdf'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Function to create maze plot
def create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize):
    # Ensure all rows have the same length by padding with spaces if necessary
    max_length = max(len(row) for row in maze_data)
    maze_data = [row.ljust(max_length) for row in maze_data]

    # Create a 2D list from the maze data
    maze_list = []
    for row in maze_data:
        row_list = []
        for char in row:
            if (char == 'W'):
                row_list.append(1)  # Wall
            elif char == ' ':
                row_list.append(0)  # Path
            elif char == 'S':
                row_list.append(2)  # Start
            elif char == 'E':
                row_list.append(3)  # End
        maze_list.append(row_list)

    # Convert the 2D list to a numpy array
    maze_array = np.array(maze_list)

    # Create a plot with a large enough figure size
    fig, ax = plt.subplots(figsize=fig_size)
  # Draw the maze using very thin lines for the walls
    for i in range(maze_array.shape[0]):
        for j in range(maze_array.shape[1]):
            if maze_array[i, j] == 1:
                # Draw a wall with very thin lines
                ax.plot([j, j+1], [i, i], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j+1], [i+1, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j], [i, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j+1, j+1], [i, i+1], color='#D1EBB8', linewidth=0.1)


    # Adding the start and end labels
    start_pos = (maze_array.shape[0] - 1, 0)
    ax.text(start_pos[1] - 1, start_pos[0], 'START', ha='right', va='center', fontsize=20, fontweight='bold', color='#D1EBB8')

    end_pos = (0, maze_array.shape[1] - 1)
    ax.text(end_pos[1] + 1, end_pos[0], 'END', ha='left', va='center', fontsize=20, fontweight='bold', color='#D1EBB8')

    # Set plot limits
    ax.set_xlim(-1, maze_array.shape[1])
    ax.set_ylim(-1, maze_array.shape[0])

    # Turn off the axes
    ax.set_xticks([])
    ax.set_yticks([])

    # Remove the plot outline (spines)
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Set background color to white
    ax.set_facecolor('white')

    return fig


# Define maze data
new_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S       W       W                   W",
        "W WWWWW W WWWWW W WWWWWWWWWWWWWWWWWWWWW",
        "W W     W     W W W                 W W",
        "W W WWWWW W WWWWW W WWWWWWWWWWWWWWW W W",
        "W W     W W       W W           W W W W",
        "W WWWWW W WWWWWWWWW W WWWWWWWWWW W W W",
        "W       W         W W       W     W   W",
        "WWWWWWWWWWWWWWW W W WWWWWWW W WWWWWWWWW",
        "W           W   W W W       W       W W",
        "W WWWWWWWW W WWWWW W W WWWWWWWWWWWWWW W",
        "W W       W       W W       W       W W",
        "W W WWWWWWWWWWWWWWWWWWWWWW W W WWWWWWWWW",
        "W W W     W             W W W W         W",
        "W W W WWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W W               W",
        "W W WWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W   W             W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W W W W                             W W W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W",
        "W W W W                       W   W W W W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W W",
        "W W           W   W           W W W W W W",
        "W WWWWWWWWWWWWW W W WWWWWWWWW W W W W W W",
        "W                 W       W   W W W   W W",
        "W WWWWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWW W",
        "W W                     W W             W",
        "W W WWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW",
        "W W                       W             W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

new_maze_data_2 = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W         W       W         W W",
        "W WWWWW W WWWWWWW W WWW W WWWWWWWWW W W",
        "W     W W     W   W W W W         W W W",
        "WWWWWW W WWWWW WWW W W W WWWWWWWWWWW W W",
        "W     W       W W   W   W         W   W",
        "W WWWWWWWWWW W W WWW WWWWWWWWWWWWW W WWW",
        "W       W   W W     W     W     W W W W",
        "WWWWWWW W WWWWWWWWWWWWWWW W WWWWW W W W",
        "W     W W         W     W W     W W W W",
        "W WWWWW W WWWWWWW W WWWWWWW W WWWWW W W",
        "W     W W       W W   W   W W     W W W",
        "WWWWW W WWWWWWW W WWWWW W WWWWWWWWW W W",
        "W     W     W   W     W W       W   W W",
        "W WWWWWWWWW W WWWWWWW W W WWWWW W WWW W",
        "W         W W       W W W     W W     W",
        "WWWWWWWWWWWW WWWWWWW W W W WWWWWWWWWWWW",
        "W       W   W       W W W     W       W",
        "W WWWWW W WWW W WWWWW W WWWWW W W W WWW",
        "W   W   W   W W     W W       W W W   W",
        "W W WWWWWWWWW W WWWWWWWWWWWWWWW W WWWWW",
        "W W       W   W   W       W     W     W",
        "W WWW WWWWWWWWW W WWWWWWW W W WWWWWWWWW",
        "W     W       W W W     W W W W       W",
        "WWWWWWWWWWW W W W W WWWWW W W W WWWWW W",
        "W         W W W   W     W W   W     W W",
        "W WWWWWWWWW W WWWWW WWW W WWWWWWWWW W W",
        "W       W   W       W W W         W W W",
        "WWWWWWWW W WWWWWWWWWWW W WWWWWWWWW W W W",
        "W       W           W W     W     W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

different_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W     W       W           W   W",
        "W WWW W W W W W WWW W W WWWWWWWWWWWW W W",
        "W   W W W W W   W   W W       W     W W",
        "W W W W W W W W W WWWWW WWWWW W WWWWW W",
        "W W   W   W W W W   W     W W W     W W",
        "W WWW W W W W W W W WWWWWW W W WWW W W",
        "W     W W W W W W W       W     W   W W",
        "WWWWWWW WWW W W WWWWWWWWWWW WWWWWWWWWWW",
        "W       W   W W     W         W     W W",
        "W WWWWWW W W WWWWW W WWW WWWWWW W WWW W",
        "W W       W     W W W   W       W     W",
        "W W WWWWWWW WWWWW W WWWWWWWWWWWWWWWWWWW",
        "W W     W   W   W W W         W   W   W",
        "W WWW W W WWW W W W WWWWWWWWW W W W W W",
        "W     W     W W     W       W W W W   W",
        "W WWWWWWWWW W W WWWWWWWWWWWW W W WWWWW W",
        "W     W     W W W     W     W W   W   W",
        "W WWW W WWWWW W W W WWW WWW W WWW W W W",
        "W W   W     W W W W W W   W     W W W W",
        "W WWWWWWWWW W W W W W W WWWWWWWWW W W W",
        "W           W W   W W     W     W     W",
        "WWWWWWWWWWW WWWWWWW WWWWW W WWW W WWWWW",
        "W           W       W   W W W   W     W",
        "W WWWWWWWWWWW WWWWWWW W W W W WWWWWWWWW",
        "W       W     W   W   W W W W   W     W",
        "WWWWWWWW W WWWWW W WWW W W W W WWWWW W W",
        "W         W   W W W   W W W   W     W W",
        "W WWWWWWWWW W W W W WWW W WWWWW WWWWW W",
        "W W       W W W W     W     W         W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

another_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S   W   W         W             W   W",
        "W WWW W W W WWWWW W WWW WWWWWWWWWWWW W W",
        "W W   W W W     W W   W W         W   W",
        "W W W W W WWWWW W WWW W W WWWWWWWWWWWWW",
        "W W W W   W     W W   W W       W     W",
        "W W W WWW W WWWWW W WWWWW WWWWWW W WWW",
        "W   W     W       W     W       W     W",
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W     W         W     W     W       W W",
        "W WWWWWWWWWWWW W WWWWWWWWW W WWWWWWWW W",
        "W   W       W W W       W W W     W   W",
        "WWW W WWWWW W W WWWWW W W W W WWWWW WWW",
        "W   W   W   W     W   W W W   W     W W",
        "W WWWWW W WWWWWWW W WWWWW WWWWWWWWW W W",
        "W       W       W W   W     W       W W",
        "W WWWWWWWWWWWWWWW WWWWW WWWWWWWWWWWWWWW",
        "W       W       W       W         W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W WWW",
        "W     W       W       W         W W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W           W   W       W           W W",
        "WWWWWWWWWWW W W WWWWW W W WWWWWWWWWW W",
        "W           W W       W W         W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W",
        "W     W             W         W     W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W",
        "W   W     W       W       W         W W",
        "WWW W W WWWWWWWW WWWWWWW W WWWWWWWWWWWW",
        "W     W         W       W     W       W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

mazes = [
    (new_maze_data, (15, 15), 33, 33, 33),
    (new_maze_data_2, (15, 15), 33, 33, 33),
    (different_maze_data, (15, 15), 33, 33, 33),
    (another_maze_data, (15, 15), 33, 33, 33)  # Add another maze data
]

# Creating a PDF with the maze plots
pdf_filename = "mazes_FNT_20_GREEN.pdf"
with PdfPages(pdf_filename) as pdf:
    for maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize in mazes:
        fig = create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize)
        pdf.savefig(fig)
        plt.close(fig)

# Output PDF filename for download
pdf_filename
# Out:
# 'mazes_FNT_20_GREEN.pdf'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# Function to create maze plot
def create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize):
    # Ensure all rows have the same length by padding with spaces if necessary
    max_length = max(len(row) for row in maze_data)
    maze_data = [row.ljust(max_length) for row in maze_data]

    # Create a 2D list from the maze data
    maze_list = []
    for row in maze_data:
        row_list = []
        for char in row:
            if (char == 'W'):
                row_list.append(1)  # Wall
            elif char == ' ':
                row_list.append(0)  # Path
            elif char == 'S':
                row_list.append(2)  # Start
            elif char == 'E':
                row_list.append(3)  # End
        maze_list.append(row_list)

    # Convert the 2D list to a numpy array
    maze_array = np.array(maze_list)

    # Create a plot with a large enough figure size
    fig, ax = plt.subplots(figsize=fig_size)
  # Draw the maze using very thin lines for the walls
    for i in range(maze_array.shape[0]):
        for j in range(maze_array.shape[1]):
            if maze_array[i, j] == 1:
                # Draw a wall with very thin lines
                ax.plot([j, j+1], [i, i], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j+1], [i+1, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j, j], [i, i+1], color='#D1EBB8', linewidth=0.1)
                ax.plot([j+1, j+1], [i, i+1], color='#D1EBB8', linewidth=0.1)


    # Adding the start and end labels
    start_pos = (maze_array.shape[0] - 1, 0)
    ax.text(start_pos[1] - 1, start_pos[0], 'START', ha='right', va='center', fontsize=33, fontweight='bold', color='#D1EBB8')

    end_pos = (0, maze_array.shape[1] - 1)
    ax.text(end_pos[1] + 1, end_pos[0], 'END', ha='left', va='center', fontsize=33, fontweight='bold', color='#D1EBB8')

    # Set plot limits
    ax.set_xlim(-1, maze_array.shape[1])
    ax.set_ylim(-1, maze_array.shape[0])

    # Turn off the axes
    ax.set_xticks([])
    ax.set_yticks([])

    # Remove the plot outline (spines)
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Set background color to white
    ax.set_facecolor('white')

    return fig


# Define maze data
new_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S       W       W                   W",
        "W WWWWW W WWWWW W WWWWWWWWWWWWWWWWWWWWW",
        "W W     W     W W W                 W W",
        "W W WWWWW W WWWWW W WWWWWWWWWWWWWWW W W",
        "W W     W W       W W           W W W W",
        "W WWWWW W WWWWWWWWW W WWWWWWWWWW W W W",
        "W       W         W W       W     W   W",
        "WWWWWWWWWWWWWWW W W WWWWWWW W WWWWWWWWW",
        "W           W   W W W       W       W W",
        "W WWWWWWWW W WWWWW W W WWWWWWWWWWWWWW W",
        "W W       W       W W       W       W W",
        "W W WWWWWWWWWWWWWWWWWWWWWW W W WWWWWWWWW",
        "W W W     W             W W W W         W",
        "W W W WWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W W               W",
        "W W WWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW W",
        "W W W                 W   W             W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W W W W                             W W W",
        "W W W WWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W",
        "W W W W                       W   W W W W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W W W",
        "W W           W   W           W W W W W W",
        "W WWWWWWWWWWWWW W W WWWWWWWWW W W W W W W",
        "W                 W       W   W W W   W W",
        "W WWWWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWW W",
        "W W                     W W             W",
        "W W WWWWWWWWWWWWWWWWWWWWW W WWWWWWWWWWWWW",
        "W W                       W             W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

new_maze_data_2 = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W         W       W         W W",
        "W WWWWW W WWWWWWW W WWW W WWWWWWWWW W W",
        "W     W W     W   W W W W         W W W",
        "WWWWWW W WWWWW WWW W W W WWWWWWWWWWW W W",
        "W     W       W W   W   W         W   W",
        "W WWWWWWWWWW W W WWW WWWWWWWWWWWWW W WWW",
        "W       W   W W     W     W     W W W W",
        "WWWWWWW W WWWWWWWWWWWWWWW W WWWWW W W W",
        "W     W W         W     W W     W W W W",
        "W WWWWW W WWWWWWW W WWWWWWW W WWWWW W W",
        "W     W W       W W   W   W W     W W W",
        "WWWWW W WWWWWWW W WWWWW W WWWWWWWWW W W",
        "W     W     W   W     W W       W   W W",
        "W WWWWWWWWW W WWWWWWW W W WWWWW W WWW W",
        "W         W W       W W W     W W     W",
        "WWWWWWWWWWWW WWWWWWW W W W WWWWWWWWWWWW",
        "W       W   W       W W W     W       W",
        "W WWWWW W WWW W WWWWW W WWWWW W W W WWW",
        "W   W   W   W W     W W       W W W   W",
        "W W WWWWWWWWW W WWWWWWWWWWWWWWW W WWWWW",
        "W W       W   W   W       W     W     W",
        "W WWW WWWWWWWWW W WWWWWWW W W WWWWWWWWW",
        "W     W       W W W     W W W W       W",
        "WWWWWWWWWWW W W W W WWWWW W W W WWWWW W",
        "W         W W W   W     W W   W     W W",
        "W WWWWWWWWW W WWWWW WWW W WWWWWWWWW W W",
        "W       W   W       W W W         W W W",
        "WWWWWWWW W WWWWWWWWWWW W WWWWWWWWW W W W",
        "W       W           W W     W     W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

different_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S     W     W       W           W   W",
        "W WWW W W W W W WWW W W WWWWWWWWWWWW W W",
        "W   W W W W W   W   W W       W     W W",
        "W W W W W W W W W WWWWW WWWWW W WWWWW W",
        "W W   W   W W W W   W     W W W     W W",
        "W WWW W W W W W W W WWWWWW W W WWW W W",
        "W     W W W W W W W       W     W   W W",
        "WWWWWWW WWW W W WWWWWWWWWWW WWWWWWWWWWW",
        "W       W   W W     W         W     W W",
        "W WWWWWW W W WWWWW W WWW WWWWWW W WWW W",
        "W W       W     W W W   W       W     W",
        "W W WWWWWWW WWWWW W WWWWWWWWWWWWWWWWWWW",
        "W W     W   W   W W W         W   W   W",
        "W WWW W W WWW W W W WWWWWWWWW W W W W W",
        "W     W     W W     W       W W W W   W",
        "W WWWWWWWWW W W WWWWWWWWWWWW W W WWWWW W",
        "W     W     W W W     W     W W   W   W",
        "W WWW W WWWWW W W W WWW WWW W WWW W W W",
        "W W   W     W W W W W W   W     W W W W",
        "W WWWWWWWWW W W W W W W WWWWWWWWW W W W",
        "W           W W   W W     W     W     W",
        "WWWWWWWWWWW WWWWWWW WWWWW W WWW W WWWWW",
        "W           W       W   W W W   W     W",
        "W WWWWWWWWWWW WWWWWWW W W W W WWWWWWWWW",
        "W       W     W   W   W W W W   W     W",
        "WWWWWWWW W WWWWW W WWW W W W W WWWWW W W",
        "W         W   W W W   W W W   W     W W",
        "W WWWWWWWWW W W W W WWW W WWWWW WWWWW W",
        "W W       W W W W     W     W         W",
        "W W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

another_maze_data = [
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W S   W   W         W             W   W",
        "W WWW W W W WWWWW W WWW WWWWWWWWWWWW W W",
        "W W   W W W     W W   W W         W   W",
        "W W W W W WWWWW W WWW W W WWWWWWWWWWWWW",
        "W W W W   W     W W   W W       W     W",
        "W W W WWW W WWWWW W WWWWW WWWWWW W WWW",
        "W   W     W       W     W       W     W",
        "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W     W         W     W     W       W W",
        "W WWWWWWWWWWWW W WWWWWWWWW W WWWWWWWW W",
        "W   W       W W W       W W W     W   W",
        "WWW W WWWWW W W WWWWW W W W W WWWWW WWW",
        "W   W   W   W     W   W W W   W     W W",
        "W WWWWW W WWWWWWW W WWWWW WWWWWWWWW W W",
        "W       W       W W   W     W       W W",
        "W WWWWWWWWWWWWWWW WWWWW WWWWWWWWWWWWWWW",
        "W       W       W       W         W   W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W WWW",
        "W     W       W       W         W W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
        "W           W   W       W           W W",
        "WWWWWWWWWWW W W WWWWW W W WWWWWWWWWW W",
        "W           W W       W W         W W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W W",
        "W     W             W         W     W W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW W",
        "W   W     W       W       W         W W",
        "WWW W W WWWWWWWW WWWWWWW W WWWWWWWWWWWW",
        "W     W         W       W     W       W",
        "W WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWWE",
]

mazes = [
    (new_maze_data, (18, 18), 33, 33, 33),
    (new_maze_data_2, (18, 18), 33, 33, 33),
    (different_maze_data, (18, 18), 33, 33, 33),
    (another_maze_data, (18, 18), 33, 33, 33)  # Add another maze data
]

# Creating a PDF with the maze plots
pdf_filename = "mazes_FNT_33_GREEN.pdf"
with PdfPages(pdf_filename) as pdf:
    for maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize in mazes:
        fig = create_maze_plot(maze_data, fig_size, wall_thickness, start_label_fontsize, end_label_fontsize)
        pdf.savefig(fig)
        plt.close(fig)

# Output PDF filename for download
pdf_filename
# Out:
# 'mazes_FNT_33_GREEN.pdf'

# %% [markdown]
# #Crossword

# %%
#33
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the categories and their words with positions and directions
categories = {
    "Fruits": [
        ("BANANA", (1, 1), 'H'),
        ("APPLE", (0, 1), 'V'),
        ("GRAPE", (3, 5), 'H'),
        ("ORANGE", (6, 6), 'V'),
        ("MANGO", (10, 2), 'H'),
        ("PEACH", (8, 8), 'V'),
        ("PEAR", (12, 3), 'H')
    ],
    "Vegetables": [
        ("CARROT", (1, 1), 'H'),
        ("POTATO", (0, 1), 'V'),
        ("TOMATO", (3, 5), 'H'),
        ("BROCCOLI", (6, 6), 'V'),
        ("SPINACH", (10, 2), 'H'),
        ("LETTUCE", (8, 8), 'V'),
        ("CUCUMBER", (12, 3), 'H')
    ],
    "Space Objects": [
        ("PLANET", (1, 1), 'H'),
        ("STAR", (0, 1), 'V'),
        ("COMET", (3, 5), 'H'),
        ("ASTEROID", (6, 6), 'V'),
        ("GALAXY", (10, 2), 'H'),
        ("NEBULA", (8, 8), 'V'),
        ("MOON", (12, 3), 'H')
    ],
    "Musical Instruments": [
        ("PIANO", (1, 1), 'H'),
        ("GUITAR", (0, 1), 'V'),
        ("DRUMS", (3, 5), 'H'),
        ("VIOLIN", (6, 6), 'V'),
        ("FLUTE", (10, 2), 'H'),
        ("TRUMPET", (8, 8), 'V'),
        ("SAXOPHONE", (12, 3), 'H')
    ]
}

# Grid size
grid_size = 15

# Function to place words
def place_word(word, start_pos, direction, grid):
    x, y = start_pos
    for letter in word:
        grid[x, y] = letter
        if direction == 'H':
            y += 1
        elif direction == 'V':
            x += 1

# Function to display and save the grid as an image without highlighted answers
def save_crossword_as_image(grid, words_info, category, pdf):
    fig, ax = plt.subplots(figsize=(18, 18))
    ax.imshow(np.zeros((grid_size, grid_size)), cmap='Greys', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=33, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=2)

    # Remove the default black border
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')

    plt.gca().invert_yaxis()
    # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the title
    plt.title(f'CROSSWORD PUZZLE - {category.upper()}', fontsize=33, color='#E5FFCC', pad=20)

    # Add the list of words to the bottom of the image
    words_list = "Words to find: " + ", ".join([word for word, _, _ in words_info])
    plt.figtext(0.5, 0.01, words_list, ha="center", fontsize=33, color='#E5FFCC')

    # Save the current figure to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Function to generate and save crossword puzzle for a category
def generate_crossword(category, words_info, pdf):
    # Initialize empty grid
    grid = np.full((grid_size, grid_size), ' ')

    # Place words in the grid
    for word, start_pos, direction in words_info:
        place_word(word, start_pos, direction, grid)

    # Fill empty spaces with random letters
    for i in range(grid_size):
        for j in range(grid_size):
            if grid[i, j] == ' ':
                grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

    # Save the crossword puzzle as a page in the PDF
    save_crossword_as_image(grid, words_info, category, pdf)

# Create a PDF file to save all crossword puzzles
with PdfPages('crossword_puzzles_33_GREEN_NEW.pdf') as pdf:
    # Generate crossword puzzles for each category
    for category, words_info in categories.items():
        generate_crossword(category, words_info, pdf)

# %%
#20
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the categories and their words with positions and directions
categories = {
    "Fruits": [
        ("BANANA", (1, 1), 'H'),
        ("APPLE", (0, 1), 'V'),
        ("GRAPE", (3, 5), 'H'),
        ("ORANGE", (6, 6), 'V'),
        ("MANGO", (10, 2), 'H'),
        ("PEACH", (8, 8), 'V'),
        ("PEAR", (12, 3), 'H')
    ],
    "Vegetables": [
        ("CARROT", (1, 1), 'H'),
        ("POTATO", (0, 1), 'V'),
        ("TOMATO", (3, 5), 'H'),
        ("BROCCOLI", (6, 6), 'V'),
        ("SPINACH", (10, 2), 'H'),
        ("LETTUCE", (8, 8), 'V'),
        ("CUCUMBER", (12, 3), 'H')
    ],
    "Space Objects": [
        ("PLANET", (1, 1), 'H'),
        ("STAR", (0, 1), 'V'),
        ("COMET", (3, 5), 'H'),
        ("ASTEROID", (6, 6), 'V'),
        ("GALAXY", (10, 2), 'H'),
        ("NEBULA", (8, 8), 'V'),
        ("MOON", (12, 3), 'H')
    ],
    "Musical Instruments": [
        ("PIANO", (1, 1), 'H'),
        ("GUITAR", (0, 1), 'V'),
        ("DRUMS", (3, 5), 'H'),
        ("VIOLIN", (6, 6), 'V'),
        ("FLUTE", (10, 2), 'H'),
        ("TRUMPET", (8, 8), 'V'),
        ("SAXOPHONE", (12, 3), 'H')
    ]
}

# Grid size
grid_size = 15

# Function to place words
def place_word(word, start_pos, direction, grid):
    x, y = start_pos
    for letter in word:
        grid[x, y] = letter
        if direction == 'H':
            y += 1
        elif direction == 'V':
            x += 1

# Function to display and save the grid as an image without highlighted answers
def save_crossword_as_image(grid, words_info, category, pdf):
    fig, ax = plt.subplots(figsize=(16, 16))
    ax.imshow(np.zeros((grid_size, grid_size)), cmap='Greys', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=20, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=2)

    # Remove the default black border
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')

    plt.gca().invert_yaxis()
     # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the title
    plt.title(f'CROSSWORD PUZZLE - {category.upper()}', fontsize=20, color='#E5FFCC', pad=20)

    # Add the list of words to the bottom of the image
    words_list = "Words to find: " + ", ".join([word for word, _, _ in words_info])
    plt.figtext(0.5, 0.01, words_list, ha="center", fontsize=20, color='#E5FFCC')

    # Save the current figure to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Function to generate and save crossword puzzle for a category
def generate_crossword(category, words_info, pdf):
    # Initialize empty grid
    grid = np.full((grid_size, grid_size), ' ')

    # Place words in the grid
    for word, start_pos, direction in words_info:
        place_word(word, start_pos, direction, grid)

    # Fill empty spaces with random letters
    for i in range(grid_size):
        for j in range(grid_size):
            if grid[i, j] == ' ':
                grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

    # Save the crossword puzzle as a page in the PDF
    save_crossword_as_image(grid, words_info, category, pdf)

# Create a PDF file to save all crossword puzzles
with PdfPages('crossword_puzzles_20_GREEN_NEW.pdf') as pdf:
    # Generate crossword puzzles for each category
    for category, words_info in categories.items():
        generate_crossword(category, words_info, pdf)

# %%
#14
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the categories and their words with positions and directions
categories = {
    "Fruits": [
        ("BANANA", (1, 1), 'H'),
        ("APPLE", (0, 1), 'V'),
        ("GRAPE", (3, 5), 'H'),
        ("ORANGE", (6, 6), 'V'),
        ("MANGO", (10, 2), 'H'),
        ("PEACH", (8, 8), 'V'),
        ("PEAR", (12, 3), 'H')
    ],
    "Vegetables": [
        ("CARROT", (1, 1), 'H'),
        ("POTATO", (0, 1), 'V'),
        ("TOMATO", (3, 5), 'H'),
        ("BROCCOLI", (6, 6), 'V'),
        ("SPINACH", (10, 2), 'H'),
        ("LETTUCE", (8, 8), 'V'),
        ("CUCUMBER", (12, 3), 'H')
    ],
    "Space Objects": [
        ("PLANET", (1, 1), 'H'),
        ("STAR", (0, 1), 'V'),
        ("COMET", (3, 5), 'H'),
        ("ASTEROID", (6, 6), 'V'),
        ("GALAXY", (10, 2), 'H'),
        ("NEBULA", (8, 8), 'V'),
        ("MOON", (12, 3), 'H')
    ],
    "Musical Instruments": [
        ("PIANO", (1, 1), 'H'),
        ("GUITAR", (0, 1), 'V'),
        ("DRUMS", (3, 5), 'H'),
        ("VIOLIN", (6, 6), 'V'),
        ("FLUTE", (10, 2), 'H'),
        ("TRUMPET", (8, 8), 'V'),
        ("SAXOPHONE", (12, 3), 'H')
    ]
}

# Grid size
grid_size = 15

# Function to place words
def place_word(word, start_pos, direction, grid):
    x, y = start_pos
    for letter in word:
        grid[x, y] = letter
        if direction == 'H':
            y += 1
        elif direction == 'V':
            x += 1

# Function to display and save the grid as an image without highlighted answers
def save_crossword_as_image(grid, words_info, category, pdf):
    fig, ax = plt.subplots(figsize=(15, 15))
    ax.imshow(np.zeros((grid_size, grid_size)), cmap='Greys', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=14, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=2)

    # Remove the default black border
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')

    plt.gca().invert_yaxis()
     # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False) # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the title
    plt.title(f'CROSSWORD PUZZLE - {category.upper()}', fontsize=14, color='#E5FFCC', pad=20)

    # Add the list of words to the bottom of the image
    words_list = "Words to find: " + ", ".join([word for word, _, _ in words_info])
    plt.figtext(0.5, 0.01, words_list, ha="center", fontsize=14, color='#E5FFCC')

    # Save the current figure to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Function to generate and save crossword puzzle for a category
def generate_crossword(category, words_info, pdf):
    # Initialize empty grid
    grid = np.full((grid_size, grid_size), ' ')

    # Place words in the grid
    for word, start_pos, direction in words_info:
        place_word(word, start_pos, direction, grid)

    # Fill empty spaces with random letters
    for i in range(grid_size):
        for j in range(grid_size):
            if grid[i, j] == ' ':
                grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

    # Save the crossword puzzle as a page in the PDF
    save_crossword_as_image(grid, words_info, category, pdf)

# Create a PDF file to save all crossword puzzles
with PdfPages('crossword_puzzles_14_GREEN_NEW.pdf') as pdf:
    # Generate crossword puzzles for each category
    for category, words_info in categories.items():
        generate_crossword(category, words_info, pdf)

# %%
#10
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the categories and their words with positions and directions
categories = {
    "Fruits": [
        ("BANANA", (1, 1), 'H'),
        ("APPLE", (0, 1), 'V'),
        ("GRAPE", (3, 5), 'H'),
        ("ORANGE", (6, 6), 'V'),
        ("MANGO", (10, 2), 'H'),
        ("PEACH", (8, 8), 'V'),
        ("PEAR", (12, 3), 'H')
    ],
    "Vegetables": [
        ("CARROT", (1, 1), 'H'),
        ("POTATO", (0, 1), 'V'),
        ("TOMATO", (3, 5), 'H'),
        ("BROCCOLI", (6, 6), 'V'),
        ("SPINACH", (10, 2), 'H'),
        ("LETTUCE", (8, 8), 'V'),
        ("CUCUMBER", (12, 3), 'H')
    ],
    "Space Objects": [
        ("PLANET", (1, 1), 'H'),
        ("STAR", (0, 1), 'V'),
        ("COMET", (3, 5), 'H'),
        ("ASTEROID", (6, 6), 'V'),
        ("GALAXY", (10, 2), 'H'),
        ("NEBULA", (8, 8), 'V'),
        ("MOON", (12, 3), 'H')
    ],
    "Musical Instruments": [
        ("PIANO", (1, 1), 'H'),
        ("GUITAR", (0, 1), 'V'),
        ("DRUMS", (3, 5), 'H'),
        ("VIOLIN", (6, 6), 'V'),
        ("FLUTE", (10, 2), 'H'),
        ("TRUMPET", (8, 8), 'V'),
        ("SAXOPHONE", (12, 3), 'H')
    ]
}

# Grid size
grid_size = 15

# Function to place words
def place_word(word, start_pos, direction, grid):
    x, y = start_pos
    for letter in word:
        grid[x, y] = letter
        if direction == 'H':
            y += 1
        elif direction == 'V':
            x += 1

# Function to display and save the grid as an image without highlighted answers
def save_crossword_as_image(grid, words_info, category, pdf):
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.imshow(np.zeros((grid_size, grid_size)), cmap='Greys', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=10, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=2)

    # Remove the default black border
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')

    plt.gca().invert_yaxis()
     # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the title
    plt.title(f'CROSSWORD PUZZLE - {category.upper()}', fontsize=10, color='#E5FFCC', pad=20)

    # Add the list of words to the bottom of the image
    words_list = "Words to find: " + ", ".join([word for word, _, _ in words_info])
    plt.figtext(0.5, 0.01, words_list, ha="center", fontsize=10, color='#E5FFCC')

    # Save the current figure to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Function to generate and save crossword puzzle for a category
def generate_crossword(category, words_info, pdf):
    # Initialize empty grid
    grid = np.full((grid_size, grid_size), ' ')

    # Place words in the grid
    for word, start_pos, direction in words_info:
        place_word(word, start_pos, direction, grid)

    # Fill empty spaces with random letters
    for i in range(grid_size):
        for j in range(grid_size):
            if grid[i, j] == ' ':
                grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

    # Save the crossword puzzle as a page in the PDF
    save_crossword_as_image(grid, words_info, category, pdf)

# Create a PDF file to save all crossword puzzles
with PdfPages('crossword_puzzles_10_GREEN_NEW.pdf') as pdf:
    # Generate crossword puzzles for each category
    for category, words_info in categories.items():
        generate_crossword(category, words_info, pdf)

# %%
#8
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the categories and their words with positions and directions
categories = {
    "Fruits": [
        ("BANANA", (1, 1), 'H'),
        ("APPLE", (0, 1), 'V'),
        ("GRAPE", (3, 5), 'H'),
        ("ORANGE", (6, 6), 'V'),
        ("MANGO", (10, 2), 'H'),
        ("PEACH", (8, 8), 'V'),
        ("PEAR", (12, 3), 'H')
    ],
    "Vegetables": [
        ("CARROT", (1, 1), 'H'),
        ("POTATO", (0, 1), 'V'),
        ("TOMATO", (3, 5), 'H'),
        ("BROCCOLI", (6, 6), 'V'),
        ("SPINACH", (10, 2), 'H'),
        ("LETTUCE", (8, 8), 'V'),
        ("CUCUMBER", (12, 3), 'H')
    ],
    "Space Objects": [
        ("PLANET", (1, 1), 'H'),
        ("STAR", (0, 1), 'V'),
        ("COMET", (3, 5), 'H'),
        ("ASTEROID", (6, 6), 'V'),
        ("GALAXY", (10, 2), 'H'),
        ("NEBULA", (8, 8), 'V'),
        ("MOON", (12, 3), 'H')
    ],
    "Musical Instruments": [
        ("PIANO", (1, 1), 'H'),
        ("GUITAR", (0, 1), 'V'),
        ("DRUMS", (3, 5), 'H'),
        ("VIOLIN", (6, 6), 'V'),
        ("FLUTE", (10, 2), 'H'),
        ("TRUMPET", (8, 8), 'V'),
        ("SAXOPHONE", (12, 3), 'H')
    ]
}

# Grid size
grid_size = 15

# Function to place words
def place_word(word, start_pos, direction, grid):
    x, y = start_pos
    for letter in word:
        grid[x, y] = letter
        if direction == 'H':
            y += 1
        elif direction == 'V':
            x += 1

# Function to display and save the grid as an image without highlighted answers
def save_crossword_as_image(grid, words_info, category, pdf):
    fig, ax = plt.subplots(figsize=(9, 9))
    ax.imshow(np.zeros((grid_size, grid_size)), cmap='Greys', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=8, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=2)

    # Remove the default black border
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')

    plt.gca().invert_yaxis()
     # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the title
    plt.title(f'CROSSWORD PUZZLE - {category.upper()}', fontsize=8, color='#E5FFCC', pad=20)

    # Add the list of words to the bottom of the image
    words_list = "Words to find: " + ", ".join([word for word, _, _ in words_info])
    plt.figtext(0.5, 0.01, words_list, ha="center", fontsize=8, color='#E5FFCC')

    # Save the current figure to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Function to generate and save crossword puzzle for a category
def generate_crossword(category, words_info, pdf):
    # Initialize empty grid
    grid = np.full((grid_size, grid_size), ' ')

    # Place words in the grid
    for word, start_pos, direction in words_info:
        place_word(word, start_pos, direction, grid)

    # Fill empty spaces with random letters
    for i in range(grid_size):
        for j in range(grid_size):
            if grid[i, j] == ' ':
                grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

    # Save the crossword puzzle as a page in the PDF
    save_crossword_as_image(grid, words_info, category, pdf)

# Create a PDF file to save all crossword puzzles
with PdfPages('crossword_puzzles_8_GREEN_NEW.pdf') as pdf:
    # Generate crossword puzzles for each category
    for category, words_info in categories.items():
        generate_crossword(category, words_info, pdf)

# %%
#6
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the categories and their words with positions and directions
categories = {
    "Fruits": [
        ("BANANA", (1, 1), 'H'),
        ("APPLE", (0, 1), 'V'),
        ("GRAPE", (3, 5), 'H'),
        ("ORANGE", (6, 6), 'V'),
        ("MANGO", (10, 2), 'H'),
        ("PEACH", (8, 8), 'V'),
        ("PEAR", (12, 3), 'H')
    ],
    "Vegetables": [
        ("CARROT", (1, 1), 'H'),
        ("POTATO", (0, 1), 'V'),
        ("TOMATO", (3, 5), 'H'),
        ("BROCCOLI", (6, 6), 'V'),
        ("SPINACH", (10, 2), 'H'),
        ("LETTUCE", (8, 8), 'V'),
        ("CUCUMBER", (12, 3), 'H')
    ],
    "Space Objects": [
        ("PLANET", (1, 1), 'H'),
        ("STAR", (0, 1), 'V'),
        ("COMET", (3, 5), 'H'),
        ("ASTEROID", (6, 6), 'V'),
        ("GALAXY", (10, 2), 'H'),
        ("NEBULA", (8, 8), 'V'),
        ("MOON", (12, 3), 'H')
    ],
    "Musical Instruments": [
        ("PIANO", (1, 1), 'H'),
        ("GUITAR", (0, 1), 'V'),
        ("DRUMS", (3, 5), 'H'),
        ("VIOLIN", (6, 6), 'V'),
        ("FLUTE", (10, 2), 'H'),
        ("TRUMPET", (8, 8), 'V'),
        ("SAXOPHONE", (12, 3), 'H')
    ]
}

# Grid size
grid_size = 15

# Function to place words
def place_word(word, start_pos, direction, grid):
    x, y = start_pos
    for letter in word:
        grid[x, y] = letter
        if direction == 'H':
            y += 1
        elif direction == 'V':
            x += 1

# Function to display and save the grid as an image without highlighted answers
def save_crossword_as_image(grid, words_info, category, pdf):
    fig, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(np.zeros((grid_size, grid_size)), cmap='Greys', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=6, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=2)

    # Remove the default black border
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')

    plt.gca().invert_yaxis()
     # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the title
    plt.title(f'CROSSWORD PUZZLE - {category.upper()}', fontsize=6, color='#E5FFCC', pad=20)

    # Add the list of words to the bottom of the image
    words_list = "Words to find: " + ", ".join([word for word, _, _ in words_info])
    plt.figtext(0.5, 0.01, words_list, ha="center", fontsize=6, color='#E5FFCC')

    # Save the current figure to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Function to generate and save crossword puzzle for a category
def generate_crossword(category, words_info, pdf):
    # Initialize empty grid
    grid = np.full((grid_size, grid_size), ' ')

    # Place words in the grid
    for word, start_pos, direction in words_info:
        place_word(word, start_pos, direction, grid)

    # Fill empty spaces with random letters
    for i in range(grid_size):
        for j in range(grid_size):
            if grid[i, j] == ' ':
                grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

    # Save the crossword puzzle as a page in the PDF
    save_crossword_as_image(grid, words_info, category, pdf)

# Create a PDF file to save all crossword puzzles
with PdfPages('crossword_puzzles_6_GREEN_NEW.pdf') as pdf:
    # Generate crossword puzzles for each category
    for category, words_info in categories.items():
        generate_crossword(category, words_info, pdf)

# %%
#5
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the categories and their words with positions and directions
categories = {
    "Fruits": [
        ("BANANA", (1, 1), 'H'),
        ("APPLE", (0, 1), 'V'),
        ("GRAPE", (3, 5), 'H'),
        ("ORANGE", (6, 6), 'V'),
        ("MANGO", (10, 2), 'H'),
        ("PEACH", (8, 8), 'V'),
        ("PEAR", (12, 3), 'H')
    ],
    "Vegetables": [
        ("CARROT", (1, 1), 'H'),
        ("POTATO", (0, 1), 'V'),
        ("TOMATO", (3, 5), 'H'),
        ("BROCCOLI", (6, 6), 'V'),
        ("SPINACH", (10, 2), 'H'),
        ("LETTUCE", (8, 8), 'V'),
        ("CUCUMBER", (12, 3), 'H')
    ],
    "Space Objects": [
        ("PLANET", (1, 1), 'H'),
        ("STAR", (0, 1), 'V'),
        ("COMET", (3, 5), 'H'),
        ("ASTEROID", (6, 6), 'V'),
        ("GALAXY", (10, 2), 'H'),
        ("NEBULA", (8, 8), 'V'),
        ("MOON", (12, 3), 'H')
    ],
    "Musical Instruments": [
        ("PIANO", (1, 1), 'H'),
        ("GUITAR", (0, 1), 'V'),
        ("DRUMS", (3, 5), 'H'),
        ("VIOLIN", (6, 6), 'V'),
        ("FLUTE", (10, 2), 'H'),
        ("TRUMPET", (8, 8), 'V'),
        ("SAXOPHONE", (12, 3), 'H')
    ]
}

# Grid size
grid_size = 15

# Function to place words
def place_word(word, start_pos, direction, grid):
    x, y = start_pos
    for letter in word:
        grid[x, y] = letter
        if direction == 'H':
            y += 1
        elif direction == 'V':
            x += 1

# Function to display and save the grid as an image without highlighted answers
def save_crossword_as_image(grid, words_info, category, pdf):
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.imshow(np.zeros((grid_size, grid_size)), cmap='Greys', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=5, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=2)

    # Remove the default black border
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')

    plt.gca().invert_yaxis()
     # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the title
    plt.title(f'CROSSWORD PUZZLE - {category.upper()}', fontsize=5, color='#E5FFCC', pad=20)

    # Add the list of words to the bottom of the image
    words_list = "Words to find: " + ", ".join([word for word, _, _ in words_info])
    plt.figtext(0.5, 0.01, words_list, ha="center", fontsize=5, color='#E5FFCC')

    # Save the current figure to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Function to generate and save crossword puzzle for a category
def generate_crossword(category, words_info, pdf):
    # Initialize empty grid
    grid = np.full((grid_size, grid_size), ' ')

    # Place words in the grid
    for word, start_pos, direction in words_info:
        place_word(word, start_pos, direction, grid)

    # Fill empty spaces with random letters
    for i in range(grid_size):
        for j in range(grid_size):
            if grid[i, j] == ' ':
                grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

    # Save the crossword puzzle as a page in the PDF
    save_crossword_as_image(grid, words_info, category, pdf)

# Create a PDF file to save all crossword puzzles
with PdfPages('crossword_puzzles_5_GREEN_NEW.pdf') as pdf:
    # Generate crossword puzzles for each category
    for category, words_info in categories.items():
        generate_crossword(category, words_info, pdf)

# %%
#4
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define the categories and their words with positions and directions
categories = {
    "Fruits": [
        ("BANANA", (1, 1), 'H'),
        ("APPLE", (0, 1), 'V'),
        ("GRAPE", (3, 5), 'H'),
        ("ORANGE", (6, 6), 'V'),
        ("MANGO", (10, 2), 'H'),
        ("PEACH", (8, 8), 'V'),
        ("PEAR", (12, 3), 'H')
    ],
    "Vegetables": [
        ("CARROT", (1, 1), 'H'),
        ("POTATO", (0, 1), 'V'),
        ("TOMATO", (3, 5), 'H'),
        ("BROCCOLI", (6, 6), 'V'),
        ("SPINACH", (10, 2), 'H'),
        ("LETTUCE", (8, 8), 'V'),
        ("CUCUMBER", (12, 3), 'H')
    ],
    "Space Objects": [
        ("PLANET", (1, 1), 'H'),
        ("STAR", (0, 1), 'V'),
        ("COMET", (3, 5), 'H'),
        ("ASTEROID", (6, 6), 'V'),
        ("GALAXY", (10, 2), 'H'),
        ("NEBULA", (8, 8), 'V'),
        ("MOON", (12, 3), 'H')
    ],
    "Musical Instruments": [
        ("PIANO", (1, 1), 'H'),
        ("GUITAR", (0, 1), 'V'),
        ("DRUMS", (3, 5), 'H'),
        ("VIOLIN", (6, 6), 'V'),
        ("FLUTE", (10, 2), 'H'),
        ("TRUMPET", (8, 8), 'V'),
        ("SAXOPHONE", (12, 3), 'H')
    ]
}

# Grid size
grid_size = 15

# Function to place words
def place_word(word, start_pos, direction, grid):
    x, y = start_pos
    for letter in word:
        grid[x, y] = letter
        if direction == 'H':
            y += 1
        elif direction == 'V':
            x += 1

# Function to display and save the grid as an image without highlighted answers
def save_crossword_as_image(grid, words_info, category, pdf):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.imshow(np.zeros((grid_size, grid_size)), cmap='Greys', vmin=0, vmax=1)

    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j, i, grid[i, j], ha='center', va='center', fontsize=4, fontweight='bold', color='#E5FFCC')

    ax.set_xticks(np.arange(-.5, grid_size, 1))
    ax.set_yticks(np.arange(-.5, grid_size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(color='#E5FFCC', linestyle='-', linewidth=2)

    # Remove the default black border
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.spines['right'].set_color('none')

    plt.gca().invert_yaxis()
     # Remove the black lines along the axes by hiding the ticks and labels
    ax.tick_params(left=False, bottom=False)

    # Ensure the grid is behind the text
    ax.set_axisbelow(True)

    # Remove the default black border and the grid border lines
    for spine in ax.spines.values():
        spine.set_visible(False)

    # Add the title
    plt.title(f'CROSSWORD PUZZLE - {category.upper()}', fontsize=4, color='#E5FFCC', pad=20)

    # Add the list of words to the bottom of the image
    words_list = "Words to find: " + ", ".join([word for word, _, _ in words_info])
    plt.figtext(0.5, 0.01, words_list, ha="center", fontsize=4, color='#E5FFCC')

    # Save the current figure to the PDF
    pdf.savefig(fig)
    plt.close(fig)

# Function to generate and save crossword puzzle for a category
def generate_crossword(category, words_info, pdf):
    # Initialize empty grid
    grid = np.full((grid_size, grid_size), ' ')

    # Place words in the grid
    for word, start_pos, direction in words_info:
        place_word(word, start_pos, direction, grid)

    # Fill empty spaces with random letters
    for i in range(grid_size):
        for j in range(grid_size):
            if grid[i, j] == ' ':
                grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

    # Save the crossword puzzle as a page in the PDF
    save_crossword_as_image(grid, words_info, category, pdf)

# Create a PDF file to save all crossword puzzles
with PdfPages('crossword_puzzles_4_GREEN_NEW.pdf') as pdf:
    # Generate crossword puzzles for each category
    for category, words_info in categories.items():
        generate_crossword(category, words_info, pdf)

# %% [markdown]
# #CRYPTIC CROSSWORD

# %%
#33
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Function to place words in the grid (improved for better handling)
def place_word(grid, word, start_pos, direction):
    x, y = start_pos
    if direction == 'H':
        if len(word) + start_pos[1] > grid.shape[1]:
            raise ValueError(f"Word '{word}' doesn't fit horizontally at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            y += 1
    elif direction == 'V':
        if len(word) + start_pos[0] > grid.shape[0]:
            raise ValueError(f"Word '{word}' doesn't fit vertically at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            x += 1

# Function to display and save the crossword as an image with highlighted answers
def save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC'):
    grid_size = grid.shape[0]

    # Display grid with letters
    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j + 0.5, grid_size - i - 0.5, grid[i, j], ha='center', va='center', fontsize=33, color=title_color)
            ax.plot([j, j+1], [grid_size-i, grid_size-i], color=title_color)  # Horizontal grid lines
            ax.plot([j, j], [grid_size-i-1, grid_size-i], color=title_color)  # Vertical grid lines

    # Add the bottom and right borders
    ax.plot([grid_size, grid_size], [0, grid_size], color=title_color)  # Right border
    ax.plot([0, grid_size], [0, 0], color=title_color)  # Bottom border

    # Display title above the grid
    ax.text(0.5, 1.02, 'CRYPTIC CROSSWORD', transform=ax.transAxes, fontsize=33, color=title_color, ha='center', va='center')

    # Display cryptic clues in a separate area below the grid
    ax.text(0.5, -0.1, 'CRYPTIC CROSSWORD CLUES', transform=ax.transAxes, fontsize=33, color=title_color, ha='center', va='center')
    ax.text(0.5, -0.15, '______________________', transform=ax.transAxes, fontsize=33, color=title_color, ha='center', va='center')

    for i, (clue_number, clue_text) in enumerate(clues.items()):
        y_offset = -0.2 - i * 0.05
        ax.text(0.5, y_offset, f"{clue_number}: {clue_text}", transform=ax.transAxes, fontsize=33, color=title_color, ha='center', va='center')

    # Adjust plot settings
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.tight_layout()

# Combined function to generate crossword and save to PDF
def generate_crossword_pdfs():
    sets = [
        {
            "clues": {
                "1 ACROSS": "Man-eater with a sweet tooth (5)",
                "5 DOWN": "Runs away after a fight (5)",
                "8 ACROSS": "What birds do after a long flight? (5)",
                "10 DOWN": "Something to write on, held in your hand (5)",
                "13 ACROSS": "Something you wear on your feet (5)"
            },
            "words": ["SHARK", "FLEE", "LAND", "PEN", "SHOE"]
        },
        {
            "clues": {
                "2 DOWN": "Opposite of happy (5)",
                "3 DOWN": "Something you see in the sky at night (5)",
                "6 ACROSS": "Something you use to cook food (4)",
                "7 DOWN": "Something you drink (4)",
                "9 DOWN": "A large body of water (4)"
            },
            "words": ["SAD", "STAR", "PAN", "TEA", "SEA"]
        },
        {
            "clues": {
                "1 ACROSS": "Strong wind (4)",
                "5 ACROSS": "Largest planet in our solar system (5)",
                "7 DOWN": "Artificial satellite (3)",
                "8 ACROSS": "Largest desert in the world (5)",
                "9 DOWN": "Type of rock (3)"
            },
            "words": ["GUST", "JUPITER", "SAT", "SAHARA", "ORE"]
        }
    ]

    grid_size = 15

    with PdfPages('CRYPTIC_crossword_33_GREEN.pdf') as pdf:
        for crossword_set in sets:
            clues = crossword_set["clues"]
            words = crossword_set["words"]

            # Initialize empty grid
            grid = np.full((grid_size, grid_size), ' ')

            # Place words in the grid based on their corresponding clue numbers
            for clue_number, word in zip(clues.keys(), words):
                row, direction = clue_number.split()
                row = int(row) - 1  # Adjust for zero-based indexing
                col = 0 if direction == "ACROSS" else grid_size - 1

                try:
                    # Attempt to place the word based on direction and starting position
                    place_word(grid, word, (row, col), direction)
                except ValueError as e:
                    print(f"Error placing word '{word}': {e}")

            # Fill empty spaces with random letters
            for i in range(grid_size):
                for j in range(grid_size):
                    if grid[i, j] == ' ':
                        grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

            # Create a plot and save the crossword to the PDF
            fig, ax = plt.subplots(figsize=(18, 18))
            save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC')
            pdf.savefig(fig)
            plt.close()

# Generate the combined PDF
generate_crossword_pdfs()

# %%
#20
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Function to place words in the grid (improved for better handling)
def place_word(grid, word, start_pos, direction):
    x, y = start_pos
    if direction == 'H':
        if len(word) + start_pos[1] > grid.shape[1]:
            raise ValueError(f"Word '{word}' doesn't fit horizontally at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            y += 1
    elif direction == 'V':
        if len(word) + start_pos[0] > grid.shape[0]:
            raise ValueError(f"Word '{word}' doesn't fit vertically at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            x += 1

# Function to display and save the crossword as an image with highlighted answers
def save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC'):
    grid_size = grid.shape[0]

    # Display grid with letters
    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j + 0.5, grid_size - i - 0.5, grid[i, j], ha='center', va='center', fontsize=20, color=title_color)
            ax.plot([j, j+1], [grid_size-i, grid_size-i], color=title_color)  # Horizontal grid lines
            ax.plot([j, j], [grid_size-i-1, grid_size-i], color=title_color)  # Vertical grid lines

    # Add the bottom and right borders
    ax.plot([grid_size, grid_size], [0, grid_size], color=title_color)  # Right border
    ax.plot([0, grid_size], [0, 0], color=title_color)  # Bottom border

    # Display title above the grid
    ax.text(0.5, 1.02, 'CRYPTIC CROSSWORD', transform=ax.transAxes, fontsize=20, color=title_color, ha='center', va='center')

    # Display cryptic clues in a separate area below the grid
    ax.text(0.5, -0.1, 'CRYPTIC CROSSWORD CLUES', transform=ax.transAxes, fontsize=20, color=title_color, ha='center', va='center')
    ax.text(0.5, -0.15, '______________________', transform=ax.transAxes, fontsize=20, color=title_color, ha='center', va='center')

    for i, (clue_number, clue_text) in enumerate(clues.items()):
        y_offset = -0.2 - i * 0.05
        ax.text(0.5, y_offset, f"{clue_number}: {clue_text}", transform=ax.transAxes, fontsize=20, color=title_color, ha='center', va='center')

    # Adjust plot settings
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.tight_layout()

# Combined function to generate crossword and save to PDF
def generate_crossword_pdfs():
    sets = [
        {
            "clues": {
                "1 ACROSS": "Man-eater with a sweet tooth (5)",
                "5 DOWN": "Runs away after a fight (5)",
                "8 ACROSS": "What birds do after a long flight? (5)",
                "10 DOWN": "Something to write on, held in your hand (5)",
                "13 ACROSS": "Something you wear on your feet (5)"
            },
            "words": ["SHARK", "FLEE", "LAND", "PEN", "SHOE"]
        },
        {
            "clues": {
                "2 DOWN": "Opposite of happy (5)",
                "3 DOWN": "Something you see in the sky at night (5)",
                "6 ACROSS": "Something you use to cook food (4)",
                "7 DOWN": "Something you drink (4)",
                "9 DOWN": "A large body of water (4)"
            },
            "words": ["SAD", "STAR", "PAN", "TEA", "SEA"]
        },
        {
            "clues": {
                "1 ACROSS": "Strong wind (4)",
                "5 ACROSS": "Largest planet in our solar system (5)",
                "7 DOWN": "Artificial satellite (3)",
                "8 ACROSS": "Largest desert in the world (5)",
                "9 DOWN": "Type of rock (3)"
            },
            "words": ["GUST", "JUPITER", "SAT", "SAHARA", "ORE"]
        }
    ]

    grid_size = 15

    with PdfPages('CRYPTIC_crossword_20_GREEN.pdf') as pdf:
        for crossword_set in sets:
            clues = crossword_set["clues"]
            words = crossword_set["words"]

            # Initialize empty grid
            grid = np.full((grid_size, grid_size), ' ')

            # Place words in the grid based on their corresponding clue numbers
            for clue_number, word in zip(clues.keys(), words):
                row, direction = clue_number.split()
                row = int(row) - 1  # Adjust for zero-based indexing
                col = 0 if direction == "ACROSS" else grid_size - 1

                try:
                    # Attempt to place the word based on direction and starting position
                    place_word(grid, word, (row, col), direction)
                except ValueError as e:
                    print(f"Error placing word '{word}': {e}")

            # Fill empty spaces with random letters
            for i in range(grid_size):
                for j in range(grid_size):
                    if grid[i, j] == ' ':
                        grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

            # Create a plot and save the crossword to the PDF
            fig, ax = plt.subplots(figsize=(16, 16))
            save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC')
            pdf.savefig(fig)
            plt.close()

# Generate the combined PDF
generate_crossword_pdfs()

# %%
#14
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Function to place words in the grid (improved for better handling)
def place_word(grid, word, start_pos, direction):
    x, y = start_pos
    if direction == 'H':
        if len(word) + start_pos[1] > grid.shape[1]:
            raise ValueError(f"Word '{word}' doesn't fit horizontally at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            y += 1
    elif direction == 'V':
        if len(word) + start_pos[0] > grid.shape[0]:
            raise ValueError(f"Word '{word}' doesn't fit vertically at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            x += 1

# Function to display and save the crossword as an image with highlighted answers
def save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC'):
    grid_size = grid.shape[0]

    # Display grid with letters
    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j + 0.5, grid_size - i - 0.5, grid[i, j], ha='center', va='center', fontsize=14, color=title_color)
            ax.plot([j, j+1], [grid_size-i, grid_size-i], color=title_color)  # Horizontal grid lines
            ax.plot([j, j], [grid_size-i-1, grid_size-i], color=title_color)  # Vertical grid lines

    # Add the bottom and right borders
    ax.plot([grid_size, grid_size], [0, grid_size], color=title_color)  # Right border
    ax.plot([0, grid_size], [0, 0], color=title_color)  # Bottom border

    # Display title above the grid
    ax.text(0.5, 1.02, 'CRYPTIC CROSSWORD', transform=ax.transAxes, fontsize=14, color=title_color, ha='center', va='center')

    # Display cryptic clues in a separate area below the grid
    ax.text(0.5, -0.1, 'CRYPTIC CROSSWORD CLUES', transform=ax.transAxes, fontsize=14, color=title_color, ha='center', va='center')
    ax.text(0.5, -0.15, '______________________', transform=ax.transAxes, fontsize=14, color=title_color, ha='center', va='center')

    for i, (clue_number, clue_text) in enumerate(clues.items()):
        y_offset = -0.2 - i * 0.05
        ax.text(0.5, y_offset, f"{clue_number}: {clue_text}", transform=ax.transAxes, fontsize=14, color=title_color, ha='center', va='center')

    # Adjust plot settings
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.tight_layout()

# Combined function to generate crossword and save to PDF
def generate_crossword_pdfs():
    sets = [
        {
            "clues": {
                "1 ACROSS": "Man-eater with a sweet tooth (5)",
                "5 DOWN": "Runs away after a fight (5)",
                "8 ACROSS": "What birds do after a long flight? (5)",
                "10 DOWN": "Something to write on, held in your hand (5)",
                "13 ACROSS": "Something you wear on your feet (5)"
            },
            "words": ["SHARK", "FLEE", "LAND", "PEN", "SHOE"]
        },
        {
            "clues": {
                "2 DOWN": "Opposite of happy (5)",
                "3 DOWN": "Something you see in the sky at night (5)",
                "6 ACROSS": "Something you use to cook food (4)",
                "7 DOWN": "Something you drink (4)",
                "9 DOWN": "A large body of water (4)"
            },
            "words": ["SAD", "STAR", "PAN", "TEA", "SEA"]
        },
        {
            "clues": {
                "1 ACROSS": "Strong wind (4)",
                "5 ACROSS": "Largest planet in our solar system (5)",
                "7 DOWN": "Artificial satellite (3)",
                "8 ACROSS": "Largest desert in the world (5)",
                "9 DOWN": "Type of rock (3)"
            },
            "words": ["GUST", "JUPITER", "SAT", "SAHARA", "ORE"]
        }
    ]

    grid_size = 15

    with PdfPages('CRYPTIC_crossword_14_GREEN.pdf') as pdf:
        for crossword_set in sets:
            clues = crossword_set["clues"]
            words = crossword_set["words"]

            # Initialize empty grid
            grid = np.full((grid_size, grid_size), ' ')

            # Place words in the grid based on their corresponding clue numbers
            for clue_number, word in zip(clues.keys(), words):
                row, direction = clue_number.split()
                row = int(row) - 1  # Adjust for zero-based indexing
                col = 0 if direction == "ACROSS" else grid_size - 1

                try:
                    # Attempt to place the word based on direction and starting position
                    place_word(grid, word, (row, col), direction)
                except ValueError as e:
                    print(f"Error placing word '{word}': {e}")

            # Fill empty spaces with random letters
            for i in range(grid_size):
                for j in range(grid_size):
                    if grid[i, j] == ' ':
                        grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

            # Create a plot and save the crossword to the PDF
            fig, ax = plt.subplots(figsize=(15, 15))
            save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC')
            pdf.savefig(fig)
            plt.close()

# Generate the combined PDF
generate_crossword_pdfs()

# %%
#10
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Function to place words in the grid (improved for better handling)
def place_word(grid, word, start_pos, direction):
    x, y = start_pos
    if direction == 'H':
        if len(word) + start_pos[1] > grid.shape[1]:
            raise ValueError(f"Word '{word}' doesn't fit horizontally at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            y += 1
    elif direction == 'V':
        if len(word) + start_pos[0] > grid.shape[0]:
            raise ValueError(f"Word '{word}' doesn't fit vertically at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            x += 1

# Function to display and save the crossword as an image with highlighted answers
def save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC'):
    grid_size = grid.shape[0]

    # Display grid with letters
    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j + 0.5, grid_size - i - 0.5, grid[i, j], ha='center', va='center', fontsize=10, color=title_color)
            ax.plot([j, j+1], [grid_size-i, grid_size-i], color=title_color)  # Horizontal grid lines
            ax.plot([j, j], [grid_size-i-1, grid_size-i], color=title_color)  # Vertical grid lines

    # Add the bottom and right borders
    ax.plot([grid_size, grid_size], [0, grid_size], color=title_color)  # Right border
    ax.plot([0, grid_size], [0, 0], color=title_color)  # Bottom border

    # Display title above the grid
    ax.text(0.5, 1.02, 'CRYPTIC CROSSWORD', transform=ax.transAxes, fontsize=10, color=title_color, ha='center', va='center')

    # Display cryptic clues in a separate area below the grid
    ax.text(0.5, -0.1, 'CRYPTIC CROSSWORD CLUES', transform=ax.transAxes, fontsize=10, color=title_color, ha='center', va='center')
    ax.text(0.5, -0.15, '______________________', transform=ax.transAxes, fontsize=10, color=title_color, ha='center', va='center')

    for i, (clue_number, clue_text) in enumerate(clues.items()):
        y_offset = -0.2 - i * 0.05
        ax.text(0.5, y_offset, f"{clue_number}: {clue_text}", transform=ax.transAxes, fontsize=10, color=title_color, ha='center', va='center')

    # Adjust plot settings
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.tight_layout()

# Combined function to generate crossword and save to PDF
def generate_crossword_pdfs():
    sets = [
        {
            "clues": {
                "1 ACROSS": "Man-eater with a sweet tooth (5)",
                "5 DOWN": "Runs away after a fight (5)",
                "8 ACROSS": "What birds do after a long flight? (5)",
                "10 DOWN": "Something to write on, held in your hand (5)",
                "13 ACROSS": "Something you wear on your feet (5)"
            },
            "words": ["SHARK", "FLEE", "LAND", "PEN", "SHOE"]
        },
        {
            "clues": {
                "2 DOWN": "Opposite of happy (5)",
                "3 DOWN": "Something you see in the sky at night (5)",
                "6 ACROSS": "Something you use to cook food (4)",
                "7 DOWN": "Something you drink (4)",
                "9 DOWN": "A large body of water (4)"
            },
            "words": ["SAD", "STAR", "PAN", "TEA", "SEA"]
        },
        {
            "clues": {
                "1 ACROSS": "Strong wind (4)",
                "5 ACROSS": "Largest planet in our solar system (5)",
                "7 DOWN": "Artificial satellite (3)",
                "8 ACROSS": "Largest desert in the world (5)",
                "9 DOWN": "Type of rock (3)"
            },
            "words": ["GUST", "JUPITER", "SAT", "SAHARA", "ORE"]
        }
    ]

    grid_size = 15

    with PdfPages('CRYPTIC_crossword_10_GREEN.pdf') as pdf:
        for crossword_set in sets:
            clues = crossword_set["clues"]
            words = crossword_set["words"]

            # Initialize empty grid
            grid = np.full((grid_size, grid_size), ' ')

            # Place words in the grid based on their corresponding clue numbers
            for clue_number, word in zip(clues.keys(), words):
                row, direction = clue_number.split()
                row = int(row) - 1  # Adjust for zero-based indexing
                col = 0 if direction == "ACROSS" else grid_size - 1

                try:
                    # Attempt to place the word based on direction and starting position
                    place_word(grid, word, (row, col), direction)
                except ValueError as e:
                    print(f"Error placing word '{word}': {e}")

            # Fill empty spaces with random letters
            for i in range(grid_size):
                for j in range(grid_size):
                    if grid[i, j] == ' ':
                        grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

            # Create a plot and save the crossword to the PDF
            fig, ax = plt.subplots(figsize=(12, 12))
            save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC')
            pdf.savefig(fig)
            plt.close()

# Generate the combined PDF
generate_crossword_pdfs()

# %%
#8
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Function to place words in the grid (improved for better handling)
def place_word(grid, word, start_pos, direction):
    x, y = start_pos
    if direction == 'H':
        if len(word) + start_pos[1] > grid.shape[1]:
            raise ValueError(f"Word '{word}' doesn't fit horizontally at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            y += 1
    elif direction == 'V':
        if len(word) + start_pos[0] > grid.shape[0]:
            raise ValueError(f"Word '{word}' doesn't fit vertically at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            x += 1

# Function to display and save the crossword as an image with highlighted answers
def save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC'):
    grid_size = grid.shape[0]

    # Display grid with letters
    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j + 0.5, grid_size - i - 0.5, grid[i, j], ha='center', va='center', fontsize=8, color=title_color)
            ax.plot([j, j+1], [grid_size-i, grid_size-i], color=title_color)  # Horizontal grid lines
            ax.plot([j, j], [grid_size-i-1, grid_size-i], color=title_color)  # Vertical grid lines

    # Add the bottom and right borders
    ax.plot([grid_size, grid_size], [0, grid_size], color=title_color)  # Right border
    ax.plot([0, grid_size], [0, 0], color=title_color)  # Bottom border

    # Display title above the grid
    ax.text(0.5, 1.02, 'CRYPTIC CROSSWORD', transform=ax.transAxes, fontsize=8, color=title_color, ha='center', va='center')

    # Display cryptic clues in a separate area below the grid
    ax.text(0.5, -0.1, 'CRYPTIC CROSSWORD CLUES', transform=ax.transAxes, fontsize=8, color=title_color, ha='center', va='center')
    ax.text(0.5, -0.15, '______________________', transform=ax.transAxes, fontsize=8, color=title_color, ha='center', va='center')

    for i, (clue_number, clue_text) in enumerate(clues.items()):
        y_offset = -0.2 - i * 0.05
        ax.text(0.5, y_offset, f"{clue_number}: {clue_text}", transform=ax.transAxes, fontsize=8, color=title_color, ha='center', va='center')

    # Adjust plot settings
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.tight_layout()

# Combined function to generate crossword and save to PDF
def generate_crossword_pdfs():
    sets = [
        {
            "clues": {
                "1 ACROSS": "Man-eater with a sweet tooth (5)",
                "5 DOWN": "Runs away after a fight (5)",
                "8 ACROSS": "What birds do after a long flight? (5)",
                "10 DOWN": "Something to write on, held in your hand (5)",
                "13 ACROSS": "Something you wear on your feet (5)"
            },
            "words": ["SHARK", "FLEE", "LAND", "PEN", "SHOE"]
        },
        {
            "clues": {
                "2 DOWN": "Opposite of happy (5)",
                "3 DOWN": "Something you see in the sky at night (5)",
                "6 ACROSS": "Something you use to cook food (4)",
                "7 DOWN": "Something you drink (4)",
                "9 DOWN": "A large body of water (4)"
            },
            "words": ["SAD", "STAR", "PAN", "TEA", "SEA"]
        },
        {
            "clues": {
                "1 ACROSS": "Strong wind (4)",
                "5 ACROSS": "Largest planet in our solar system (5)",
                "7 DOWN": "Artificial satellite (3)",
                "8 ACROSS": "Largest desert in the world (5)",
                "9 DOWN": "Type of rock (3)"
            },
            "words": ["GUST", "JUPITER", "SAT", "SAHARA", "ORE"]
        }
    ]

    grid_size = 15

    with PdfPages('CRYPTIC_crossword_8_GREEN.pdf') as pdf:
        for crossword_set in sets:
            clues = crossword_set["clues"]
            words = crossword_set["words"]

            # Initialize empty grid
            grid = np.full((grid_size, grid_size), ' ')

            # Place words in the grid based on their corresponding clue numbers
            for clue_number, word in zip(clues.keys(), words):
                row, direction = clue_number.split()
                row = int(row) - 1  # Adjust for zero-based indexing
                col = 0 if direction == "ACROSS" else grid_size - 1

                try:
                    # Attempt to place the word based on direction and starting position
                    place_word(grid, word, (row, col), direction)
                except ValueError as e:
                    print(f"Error placing word '{word}': {e}")

            # Fill empty spaces with random letters
            for i in range(grid_size):
                for j in range(grid_size):
                    if grid[i, j] == ' ':
                        grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

            # Create a plot and save the crossword to the PDF
            fig, ax = plt.subplots(figsize=(10, 10))
            save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC')
            pdf.savefig(fig)
            plt.close()

# Generate the combined PDF
generate_crossword_pdfs()

# %%
#6
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Function to place words in the grid (improved for better handling)
def place_word(grid, word, start_pos, direction):
    x, y = start_pos
    if direction == 'H':
        if len(word) + start_pos[1] > grid.shape[1]:
            raise ValueError(f"Word '{word}' doesn't fit horizontally at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            y += 1
    elif direction == 'V':
        if len(word) + start_pos[0] > grid.shape[0]:
            raise ValueError(f"Word '{word}' doesn't fit vertically at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            x += 1

# Function to display and save the crossword as an image with highlighted answers
def save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC'):
    grid_size = grid.shape[0]

    # Display grid with letters
    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j + 0.5, grid_size - i - 0.5, grid[i, j], ha='center', va='center', fontsize=6, color=title_color)
            ax.plot([j, j+1], [grid_size-i, grid_size-i], color=title_color)  # Horizontal grid lines
            ax.plot([j, j], [grid_size-i-1, grid_size-i], color=title_color)  # Vertical grid lines

    # Add the bottom and right borders
    ax.plot([grid_size, grid_size], [0, grid_size], color=title_color)  # Right border
    ax.plot([0, grid_size], [0, 0], color=title_color)  # Bottom border

    # Display title above the grid
    ax.text(0.5, 1.02, 'CRYPTIC CROSSWORD', transform=ax.transAxes, fontsize=6, color=title_color, ha='center', va='center')

    # Display cryptic clues in a separate area below the grid
    ax.text(0.5, -0.1, 'CRYPTIC CROSSWORD CLUES', transform=ax.transAxes, fontsize=6, color=title_color, ha='center', va='center')
    ax.text(0.5, -0.15, '______________________', transform=ax.transAxes, fontsize=6, color=title_color, ha='center', va='center')

    for i, (clue_number, clue_text) in enumerate(clues.items()):
        y_offset = -0.2 - i * 0.05
        ax.text(0.5, y_offset, f"{clue_number}: {clue_text}", transform=ax.transAxes, fontsize=6, color=title_color, ha='center', va='center')

    # Adjust plot settings
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.tight_layout()

# Combined function to generate crossword and save to PDF
def generate_crossword_pdfs():
    sets = [
        {
            "clues": {
                "1 ACROSS": "Man-eater with a sweet tooth (5)",
                "5 DOWN": "Runs away after a fight (5)",
                "8 ACROSS": "What birds do after a long flight? (5)",
                "10 DOWN": "Something to write on, held in your hand (5)",
                "13 ACROSS": "Something you wear on your feet (5)"
            },
            "words": ["SHARK", "FLEE", "LAND", "PEN", "SHOE"]
        },
        {
            "clues": {
                "2 DOWN": "Opposite of happy (5)",
                "3 DOWN": "Something you see in the sky at night (5)",
                "6 ACROSS": "Something you use to cook food (4)",
                "7 DOWN": "Something you drink (4)",
                "9 DOWN": "A large body of water (4)"
            },
            "words": ["SAD", "STAR", "PAN", "TEA", "SEA"]
        },
        {
            "clues": {
                "1 ACROSS": "Strong wind (4)",
                "5 ACROSS": "Largest planet in our solar system (5)",
                "7 DOWN": "Artificial satellite (3)",
                "8 ACROSS": "Largest desert in the world (5)",
                "9 DOWN": "Type of rock (3)"
            },
            "words": ["GUST", "JUPITER", "SAT", "SAHARA", "ORE"]
        }
    ]

    grid_size = 15

    with PdfPages('CRYPTIC_crossword_6_GREEN.pdf') as pdf:
        for crossword_set in sets:
            clues = crossword_set["clues"]
            words = crossword_set["words"]

            # Initialize empty grid
            grid = np.full((grid_size, grid_size), ' ')

            # Place words in the grid based on their corresponding clue numbers
            for clue_number, word in zip(clues.keys(), words):
                row, direction = clue_number.split()
                row = int(row) - 1  # Adjust for zero-based indexing
                col = 0 if direction == "ACROSS" else grid_size - 1

                try:
                    # Attempt to place the word based on direction and starting position
                    place_word(grid, word, (row, col), direction)
                except ValueError as e:
                    print(f"Error placing word '{word}': {e}")

            # Fill empty spaces with random letters
            for i in range(grid_size):
                for j in range(grid_size):
                    if grid[i, j] == ' ':
                        grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

            # Create a plot and save the crossword to the PDF
            fig, ax = plt.subplots(figsize=(8, 8))
            save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC')
            pdf.savefig(fig)
            plt.close()

# Generate the combined PDF
generate_crossword_pdfs()

# %%
#5
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Function to place words in the grid (improved for better handling)
def place_word(grid, word, start_pos, direction):
    x, y = start_pos
    if direction == 'H':
        if len(word) + start_pos[1] > grid.shape[1]:
            raise ValueError(f"Word '{word}' doesn't fit horizontally at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            y += 1
    elif direction == 'V':
        if len(word) + start_pos[0] > grid.shape[0]:
            raise ValueError(f"Word '{word}' doesn't fit vertically at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            x += 1

# Function to display and save the crossword as an image with highlighted answers
def save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC'):
    grid_size = grid.shape[0]

    # Display grid with letters
    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j + 0.5, grid_size - i - 0.5, grid[i, j], ha='center', va='center', fontsize=5, color=title_color)
            ax.plot([j, j+1], [grid_size-i, grid_size-i], color=title_color)  # Horizontal grid lines
            ax.plot([j, j], [grid_size-i-1, grid_size-i], color=title_color)  # Vertical grid lines

    # Add the bottom and right borders
    ax.plot([grid_size, grid_size], [0, grid_size], color=title_color)  # Right border
    ax.plot([0, grid_size], [0, 0], color=title_color)  # Bottom border

    # Display title above the grid
    ax.text(0.5, 1.02, 'CRYPTIC CROSSWORD', transform=ax.transAxes, fontsize=5, color=title_color, ha='center', va='center')

    # Display cryptic clues in a separate area below the grid
    ax.text(0.5, -0.1, 'CRYPTIC CROSSWORD CLUES', transform=ax.transAxes, fontsize=5, color=title_color, ha='center', va='center')
    ax.text(0.5, -0.15, '______________________', transform=ax.transAxes, fontsize=5, color=title_color, ha='center', va='center')

    for i, (clue_number, clue_text) in enumerate(clues.items()):
        y_offset = -0.2 - i * 0.05
        ax.text(0.5, y_offset, f"{clue_number}: {clue_text}", transform=ax.transAxes, fontsize=5, color=title_color, ha='center', va='center')

    # Adjust plot settings
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.tight_layout()

# Combined function to generate crossword and save to PDF
def generate_crossword_pdfs():
    sets = [
        {
            "clues": {
                "1 ACROSS": "Man-eater with a sweet tooth (5)",
                "5 DOWN": "Runs away after a fight (5)",
                "8 ACROSS": "What birds do after a long flight? (5)",
                "10 DOWN": "Something to write on, held in your hand (5)",
                "13 ACROSS": "Something you wear on your feet (5)"
            },
            "words": ["SHARK", "FLEE", "LAND", "PEN", "SHOE"]
        },
        {
            "clues": {
                "2 DOWN": "Opposite of happy (5)",
                "3 DOWN": "Something you see in the sky at night (5)",
                "6 ACROSS": "Something you use to cook food (4)",
                "7 DOWN": "Something you drink (4)",
                "9 DOWN": "A large body of water (4)"
            },
            "words": ["SAD", "STAR", "PAN", "TEA", "SEA"]
        },
        {
            "clues": {
                "1 ACROSS": "Strong wind (4)",
                "5 ACROSS": "Largest planet in our solar system (5)",
                "7 DOWN": "Artificial satellite (3)",
                "8 ACROSS": "Largest desert in the world (5)",
                "9 DOWN": "Type of rock (3)"
            },
            "words": ["GUST", "JUPITER", "SAT", "SAHARA", "ORE"]
        }
    ]

    grid_size = 15

    with PdfPages('CRYPTIC_crossword_5_GREEN.pdf') as pdf:
        for crossword_set in sets:
            clues = crossword_set["clues"]
            words = crossword_set["words"]

            # Initialize empty grid
            grid = np.full((grid_size, grid_size), ' ')

            # Place words in the grid based on their corresponding clue numbers
            for clue_number, word in zip(clues.keys(), words):
                row, direction = clue_number.split()
                row = int(row) - 1  # Adjust for zero-based indexing
                col = 0 if direction == "ACROSS" else grid_size - 1

                try:
                    # Attempt to place the word based on direction and starting position
                    place_word(grid, word, (row, col), direction)
                except ValueError as e:
                    print(f"Error placing word '{word}': {e}")

            # Fill empty spaces with random letters
            for i in range(grid_size):
                for j in range(grid_size):
                    if grid[i, j] == ' ':
                        grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

            # Create a plot and save the crossword to the PDF
            fig, ax = plt.subplots(figsize=(6, 6))
            save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC')
            pdf.savefig(fig)
            plt.close()

# Generate the combined PDF
generate_crossword_pdfs()

# %%
#4
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Function to place words in the grid (improved for better handling)
def place_word(grid, word, start_pos, direction):
    x, y = start_pos
    if direction == 'H':
        if len(word) + start_pos[1] > grid.shape[1]:
            raise ValueError(f"Word '{word}' doesn't fit horizontally at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            y += 1
    elif direction == 'V':
        if len(word) + start_pos[0] > grid.shape[0]:
            raise ValueError(f"Word '{word}' doesn't fit vertically at {start_pos}")
        for letter in word:
            grid[x, y] = letter
            x += 1

# Function to display and save the crossword as an image with highlighted answers
def save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC'):
    grid_size = grid.shape[0]

    # Display grid with letters
    for i in range(grid_size):
        for j in range(grid_size):
            ax.text(j + 0.5, grid_size - i - 0.5, grid[i, j], ha='center', va='center', fontsize=4, color=title_color)
            ax.plot([j, j+1], [grid_size-i, grid_size-i], color=title_color)  # Horizontal grid lines
            ax.plot([j, j], [grid_size-i-1, grid_size-i], color=title_color)  # Vertical grid lines

    # Add the bottom and right borders
    ax.plot([grid_size, grid_size], [0, grid_size], color=title_color)  # Right border
    ax.plot([0, grid_size], [0, 0], color=title_color)  # Bottom border

    # Display title above the grid
    ax.text(0.5, 1.02, 'CRYPTIC CROSSWORD', transform=ax.transAxes, fontsize=4, color=title_color, ha='center', va='center')

    # Display cryptic clues in a separate area below the grid
    ax.text(0.5, -0.1, 'CRYPTIC CROSSWORD CLUES', transform=ax.transAxes, fontsize=4, color=title_color, ha='center', va='center')
    ax.text(0.5, -0.15, '______________________', transform=ax.transAxes, fontsize=4, color=title_color, ha='center', va='center')

    for i, (clue_number, clue_text) in enumerate(clues.items()):
        y_offset = -0.2 - i * 0.05
        ax.text(0.5, y_offset, f"{clue_number}: {clue_text}", transform=ax.transAxes, fontsize=4, color=title_color, ha='center', va='center')

    # Adjust plot settings
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
    plt.tight_layout()

# Combined function to generate crossword and save to PDF
def generate_crossword_pdfs():
    sets = [
        {
            "clues": {
                "1 ACROSS": "Man-eater with a sweet tooth (5)",
                "5 DOWN": "Runs away after a fight (5)",
                "8 ACROSS": "What birds do after a long flight? (5)",
                "10 DOWN": "Something to write on, held in your hand (5)",
                "13 ACROSS": "Something you wear on your feet (5)"
            },
            "words": ["SHARK", "FLEE", "LAND", "PEN", "SHOE"]
        },
        {
            "clues": {
                "2 DOWN": "Opposite of happy (5)",
                "3 DOWN": "Something you see in the sky at night (5)",
                "6 ACROSS": "Something you use to cook food (4)",
                "7 DOWN": "Something you drink (4)",
                "9 DOWN": "A large body of water (4)"
            },
            "words": ["SAD", "STAR", "PAN", "TEA", "SEA"]
        },
        {
            "clues": {
                "1 ACROSS": "Strong wind (4)",
                "5 ACROSS": "Largest planet in our solar system (5)",
                "7 DOWN": "Artificial satellite (3)",
                "8 ACROSS": "Largest desert in the world (5)",
                "9 DOWN": "Type of rock (3)"
            },
            "words": ["GUST", "JUPITER", "SAT", "SAHARA", "ORE"]
        }
    ]

    grid_size = 15

    with PdfPages('CRYPTIC_crossword_4_GREEN.pdf') as pdf:
        for crossword_set in sets:
            clues = crossword_set["clues"]
            words = crossword_set["words"]

            # Initialize empty grid
            grid = np.full((grid_size, grid_size), ' ')

            # Place words in the grid based on their corresponding clue numbers
            for clue_number, word in zip(clues.keys(), words):
                row, direction = clue_number.split()
                row = int(row) - 1  # Adjust for zero-based indexing
                col = 0 if direction == "ACROSS" else grid_size - 1

                try:
                    # Attempt to place the word based on direction and starting position
                    place_word(grid, word, (row, col), direction)
                except ValueError as e:
                    print(f"Error placing word '{word}': {e}")

            # Fill empty spaces with random letters
            for i in range(grid_size):
                for j in range(grid_size):
                    if grid[i, j] == ' ':
                        grid[i, j] = chr(np.random.randint(65, 91))  # Random capital letter

            # Create a plot and save the crossword to the PDF
            fig, ax = plt.subplots(figsize=(5, 5))
            save_crossword_as_image(grid, clues, ax, title_color='#E5FFCC')
            pdf.savefig(fig)
            plt.close()

# Generate the combined PDF
generate_crossword_pdfs()

# %% [markdown]
# #SUDUKO

# %%
# !pip install reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 23.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# #QUESTIONS_SUDUKO

# %%
#33
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [0, 2, 0, 6, 0, 8, 0, 0, 0],
        [5, 8, 0, 0, 0, 9, 7, 0, 0],
        [0, 0, 0, 0, 4, 0, 0, 0, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 0, 0, 0, 0, 0, 0, 0, 4],
        [0, 0, 8, 0, 0, 0, 0, 1, 3],
        [0, 0, 0, 0, 2, 0, 0, 0, 0],
        [0, 0, 9, 8, 0, 0, 0, 3, 6],
        [0, 0, 0, 3, 0, 6, 0, 9, 0],
    ],
    [
        [0, 0, 0, 6, 0, 0, 4, 0, 0],
        [7, 0, 0, 0, 0, 3, 6, 0, 0],
        [0, 0, 0, 0, 9, 1, 0, 8, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 5, 0, 1, 8, 0, 0, 0, 3],
        [0, 0, 0, 3, 0, 6, 0, 4, 5],
        [0, 4, 0, 2, 0, 0, 0, 6, 0],
        [9, 0, 3, 0, 0, 0, 0, 0, 0],
        [0, 2, 0, 0, 0, 0, 1, 0, 0],
    ],
    [
        [5, 0, 0, 9, 0, 3, 0, 6, 7],
        [3, 0, 4, 9, 0, 0, 2, 8, 6],
        [0, 1, 7, 0, 0, 0, 0, 4, 5],
        [0, 0, 6, 7, 0, 0, 0, 0, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 1],
        [0, 0, 0, 0, 0, 5, 7, 3, 0],
        [6, 5, 0, 0, 0, 8, 0, 0, 0],
        [9, 7, 0, 0, 2, 1, 0, 0, 0],
        [0, 4, 0, 6, 5, 0, 0, 0, 0],
    ],
    [
        [0, 0, 3, 0, 2, 0, 6, 0, 0],
        [9, 0, 0, 3, 0, 5, 0, 0, 1],
        [0, 0, 1, 8, 0, 6, 4, 0, 0],
        [0, 0, 8, 1, 0, 2, 9, 0, 0],
        [7, 0, 0, 0, 0, 0, 0, 0, 8],
        [0, 0, 6, 7, 0, 8, 2, 0, 0],
        [0, 0, 2, 6, 0, 9, 5, 0, 0],
        [8, 0, 0, 2, 0, 3, 0, 0, 9],
        [0, 0, 5, 0, 1, 0, 3, 0, 0],
    ],
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(18, 18))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=33, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=33, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "QNS_sudoku_images_33_FNT_AGILA_IMG.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file 'QNS_sudoku_images_33_FNT_AGILA_IMG.pdf' has been created successfully with all Sudoku puzzles.

# %%
#20
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [0, 2, 0, 6, 0, 8, 0, 0, 0],
        [5, 8, 0, 0, 0, 9, 7, 0, 0],
        [0, 0, 0, 0, 4, 0, 0, 0, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 0, 0, 0, 0, 0, 0, 0, 4],
        [0, 0, 8, 0, 0, 0, 0, 1, 3],
        [0, 0, 0, 0, 2, 0, 0, 0, 0],
        [0, 0, 9, 8, 0, 0, 0, 3, 6],
        [0, 0, 0, 3, 0, 6, 0, 9, 0],
    ],
    [
        [0, 0, 0, 6, 0, 0, 4, 0, 0],
        [7, 0, 0, 0, 0, 3, 6, 0, 0],
        [0, 0, 0, 0, 9, 1, 0, 8, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 5, 0, 1, 8, 0, 0, 0, 3],
        [0, 0, 0, 3, 0, 6, 0, 4, 5],
        [0, 4, 0, 2, 0, 0, 0, 6, 0],
        [9, 0, 3, 0, 0, 0, 0, 0, 0],
        [0, 2, 0, 0, 0, 0, 1, 0, 0],
    ],
    [
        [5, 0, 0, 9, 0, 3, 0, 6, 7],
        [3, 0, 4, 9, 0, 0, 2, 8, 6],
        [0, 1, 7, 0, 0, 0, 0, 4, 5],
        [0, 0, 6, 7, 0, 0, 0, 0, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 1],
        [0, 0, 0, 0, 0, 5, 7, 3, 0],
        [6, 5, 0, 0, 0, 8, 0, 0, 0],
        [9, 7, 0, 0, 2, 1, 0, 0, 0],
        [0, 4, 0, 6, 5, 0, 0, 0, 0],
    ],
    [
        [0, 0, 3, 0, 2, 0, 6, 0, 0],
        [9, 0, 0, 3, 0, 5, 0, 0, 1],
        [0, 0, 1, 8, 0, 6, 4, 0, 0],
        [0, 0, 8, 1, 0, 2, 9, 0, 0],
        [7, 0, 0, 0, 0, 0, 0, 0, 8],
        [0, 0, 6, 7, 0, 8, 2, 0, 0],
        [0, 0, 2, 6, 0, 9, 5, 0, 0],
        [8, 0, 0, 2, 0, 3, 0, 0, 9],
        [0, 0, 5, 0, 1, 0, 3, 0, 0],
    ],
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(16, 16))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=20, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=20, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "QNS_sudoku_images_20_FNT_AGILA_IMG.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file 'QNS_sudoku_images_20_FNT_AGILA_IMG.pdf' has been created successfully with all Sudoku puzzles.

# %%
#14
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [0, 2, 0, 6, 0, 8, 0, 0, 0],
        [5, 8, 0, 0, 0, 9, 7, 0, 0],
        [0, 0, 0, 0, 4, 0, 0, 0, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 0, 0, 0, 0, 0, 0, 0, 4],
        [0, 0, 8, 0, 0, 0, 0, 1, 3],
        [0, 0, 0, 0, 2, 0, 0, 0, 0],
        [0, 0, 9, 8, 0, 0, 0, 3, 6],
        [0, 0, 0, 3, 0, 6, 0, 9, 0],
    ],
    [
        [0, 0, 0, 6, 0, 0, 4, 0, 0],
        [7, 0, 0, 0, 0, 3, 6, 0, 0],
        [0, 0, 0, 0, 9, 1, 0, 8, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 5, 0, 1, 8, 0, 0, 0, 3],
        [0, 0, 0, 3, 0, 6, 0, 4, 5],
        [0, 4, 0, 2, 0, 0, 0, 6, 0],
        [9, 0, 3, 0, 0, 0, 0, 0, 0],
        [0, 2, 0, 0, 0, 0, 1, 0, 0],
    ],
    [
        [5, 0, 0, 9, 0, 3, 0, 6, 7],
        [3, 0, 4, 9, 0, 0, 2, 8, 6],
        [0, 1, 7, 0, 0, 0, 0, 4, 5],
        [0, 0, 6, 7, 0, 0, 0, 0, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 1],
        [0, 0, 0, 0, 0, 5, 7, 3, 0],
        [6, 5, 0, 0, 0, 8, 0, 0, 0],
        [9, 7, 0, 0, 2, 1, 0, 0, 0],
        [0, 4, 0, 6, 5, 0, 0, 0, 0],
    ],
    [
        [0, 0, 3, 0, 2, 0, 6, 0, 0],
        [9, 0, 0, 3, 0, 5, 0, 0, 1],
        [0, 0, 1, 8, 0, 6, 4, 0, 0],
        [0, 0, 8, 1, 0, 2, 9, 0, 0],
        [7, 0, 0, 0, 0, 0, 0, 0, 8],
        [0, 0, 6, 7, 0, 8, 2, 0, 0],
        [0, 0, 2, 6, 0, 9, 5, 0, 0],
        [8, 0, 0, 2, 0, 3, 0, 0, 9],
        [0, 0, 5, 0, 1, 0, 3, 0, 0],
    ],
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(15, 15))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=14, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=14, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "QNS_sudoku_images_14_FNT_AGILA_IMG.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file 'QNS_sudoku_images_14_FNT_AGILA_IMG.pdf' has been created successfully with all Sudoku puzzles.

# %%
#10
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [0, 2, 0, 6, 0, 8, 0, 0, 0],
        [5, 8, 0, 0, 0, 9, 7, 0, 0],
        [0, 0, 0, 0, 4, 0, 0, 0, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 0, 0, 0, 0, 0, 0, 0, 4],
        [0, 0, 8, 0, 0, 0, 0, 1, 3],
        [0, 0, 0, 0, 2, 0, 0, 0, 0],
        [0, 0, 9, 8, 0, 0, 0, 3, 6],
        [0, 0, 0, 3, 0, 6, 0, 9, 0],
    ],
    [
        [0, 0, 0, 6, 0, 0, 4, 0, 0],
        [7, 0, 0, 0, 0, 3, 6, 0, 0],
        [0, 0, 0, 0, 9, 1, 0, 8, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 5, 0, 1, 8, 0, 0, 0, 3],
        [0, 0, 0, 3, 0, 6, 0, 4, 5],
        [0, 4, 0, 2, 0, 0, 0, 6, 0],
        [9, 0, 3, 0, 0, 0, 0, 0, 0],
        [0, 2, 0, 0, 0, 0, 1, 0, 0],
    ],
    [
        [5, 0, 0, 9, 0, 3, 0, 6, 7],
        [3, 0, 4, 9, 0, 0, 2, 8, 6],
        [0, 1, 7, 0, 0, 0, 0, 4, 5],
        [0, 0, 6, 7, 0, 0, 0, 0, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 1],
        [0, 0, 0, 0, 0, 5, 7, 3, 0],
        [6, 5, 0, 0, 0, 8, 0, 0, 0],
        [9, 7, 0, 0, 2, 1, 0, 0, 0],
        [0, 4, 0, 6, 5, 0, 0, 0, 0],
    ],
    [
        [0, 0, 3, 0, 2, 0, 6, 0, 0],
        [9, 0, 0, 3, 0, 5, 0, 0, 1],
        [0, 0, 1, 8, 0, 6, 4, 0, 0],
        [0, 0, 8, 1, 0, 2, 9, 0, 0],
        [7, 0, 0, 0, 0, 0, 0, 0, 8],
        [0, 0, 6, 7, 0, 8, 2, 0, 0],
        [0, 0, 2, 6, 0, 9, 5, 0, 0],
        [8, 0, 0, 2, 0, 3, 0, 0, 9],
        [0, 0, 5, 0, 1, 0, 3, 0, 0],
    ],
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=10, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=10, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "QNS_sudoku_images_10_FNT_AGILA_IMG.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file 'QNS_sudoku_images_10_FNT_AGILA_IMG.pdf' has been created successfully with all Sudoku puzzles.

# %%
#10
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [0, 2, 0, 6, 0, 8, 0, 0, 0],
        [5, 8, 0, 0, 0, 9, 7, 0, 0],
        [0, 0, 0, 0, 4, 0, 0, 0, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 0, 0, 0, 0, 0, 0, 0, 4],
        [0, 0, 8, 0, 0, 0, 0, 1, 3],
        [0, 0, 0, 0, 2, 0, 0, 0, 0],
        [0, 0, 9, 8, 0, 0, 0, 3, 6],
        [0, 0, 0, 3, 0, 6, 0, 9, 0],
    ],
    [
        [0, 0, 0, 6, 0, 0, 4, 0, 0],
        [7, 0, 0, 0, 0, 3, 6, 0, 0],
        [0, 0, 0, 0, 9, 1, 0, 8, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 5, 0, 1, 8, 0, 0, 0, 3],
        [0, 0, 0, 3, 0, 6, 0, 4, 5],
        [0, 4, 0, 2, 0, 0, 0, 6, 0],
        [9, 0, 3, 0, 0, 0, 0, 0, 0],
        [0, 2, 0, 0, 0, 0, 1, 0, 0],
    ],
    [
        [5, 0, 0, 9, 0, 3, 0, 6, 7],
        [3, 0, 4, 9, 0, 0, 2, 8, 6],
        [0, 1, 7, 0, 0, 0, 0, 4, 5],
        [0, 0, 6, 7, 0, 0, 0, 0, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 1],
        [0, 0, 0, 0, 0, 5, 7, 3, 0],
        [6, 5, 0, 0, 0, 8, 0, 0, 0],
        [9, 7, 0, 0, 2, 1, 0, 0, 0],
        [0, 4, 0, 6, 5, 0, 0, 0, 0],
    ],
    [
        [0, 0, 3, 0, 2, 0, 6, 0, 0],
        [9, 0, 0, 3, 0, 5, 0, 0, 1],
        [0, 0, 1, 8, 0, 6, 4, 0, 0],
        [0, 0, 8, 1, 0, 2, 9, 0, 0],
        [7, 0, 0, 0, 0, 0, 0, 0, 8],
        [0, 0, 6, 7, 0, 8, 2, 0, 0],
        [0, 0, 2, 6, 0, 9, 5, 0, 0],
        [8, 0, 0, 2, 0, 3, 0, 0, 9],
        [0, 0, 5, 0, 1, 0, 3, 0, 0],
    ],
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=8, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=8, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "QNS_sudoku_images_8_FNT_AGILA_IMG.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file 'QNS_sudoku_images_8_FNT_AGILA_IMG.pdf' has been created successfully with all Sudoku puzzles.

# %%
#10
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [0, 2, 0, 6, 0, 8, 0, 0, 0],
        [5, 8, 0, 0, 0, 9, 7, 0, 0],
        [0, 0, 0, 0, 4, 0, 0, 0, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 0, 0, 0, 0, 0, 0, 0, 4],
        [0, 0, 8, 0, 0, 0, 0, 1, 3],
        [0, 0, 0, 0, 2, 0, 0, 0, 0],
        [0, 0, 9, 8, 0, 0, 0, 3, 6],
        [0, 0, 0, 3, 0, 6, 0, 9, 0],
    ],
    [
        [0, 0, 0, 6, 0, 0, 4, 0, 0],
        [7, 0, 0, 0, 0, 3, 6, 0, 0],
        [0, 0, 0, 0, 9, 1, 0, 8, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 5, 0, 1, 8, 0, 0, 0, 3],
        [0, 0, 0, 3, 0, 6, 0, 4, 5],
        [0, 4, 0, 2, 0, 0, 0, 6, 0],
        [9, 0, 3, 0, 0, 0, 0, 0, 0],
        [0, 2, 0, 0, 0, 0, 1, 0, 0],
    ],
    [
        [5, 0, 0, 9, 0, 3, 0, 6, 7],
        [3, 0, 4, 9, 0, 0, 2, 8, 6],
        [0, 1, 7, 0, 0, 0, 0, 4, 5],
        [0, 0, 6, 7, 0, 0, 0, 0, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 1],
        [0, 0, 0, 0, 0, 5, 7, 3, 0],
        [6, 5, 0, 0, 0, 8, 0, 0, 0],
        [9, 7, 0, 0, 2, 1, 0, 0, 0],
        [0, 4, 0, 6, 5, 0, 0, 0, 0],
    ],
    [
        [0, 0, 3, 0, 2, 0, 6, 0, 0],
        [9, 0, 0, 3, 0, 5, 0, 0, 1],
        [0, 0, 1, 8, 0, 6, 4, 0, 0],
        [0, 0, 8, 1, 0, 2, 9, 0, 0],
        [7, 0, 0, 0, 0, 0, 0, 0, 8],
        [0, 0, 6, 7, 0, 8, 2, 0, 0],
        [0, 0, 2, 6, 0, 9, 5, 0, 0],
        [8, 0, 0, 2, 0, 3, 0, 0, 9],
        [0, 0, 5, 0, 1, 0, 3, 0, 0],
    ],
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=6, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=6, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "QNS_sudoku_images_6_FNT_AGILA_IMG.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file 'QNS_sudoku_images_6_FNT_AGILA_IMG.pdf' has been created successfully with all Sudoku puzzles.

# %%
#10
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [0, 2, 0, 6, 0, 8, 0, 0, 0],
        [5, 8, 0, 0, 0, 9, 7, 0, 0],
        [0, 0, 0, 0, 4, 0, 0, 0, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 0, 0, 0, 0, 0, 0, 0, 4],
        [0, 0, 8, 0, 0, 0, 0, 1, 3],
        [0, 0, 0, 0, 2, 0, 0, 0, 0],
        [0, 0, 9, 8, 0, 0, 0, 3, 6],
        [0, 0, 0, 3, 0, 6, 0, 9, 0],
    ],
    [
        [0, 0, 0, 6, 0, 0, 4, 0, 0],
        [7, 0, 0, 0, 0, 3, 6, 0, 0],
        [0, 0, 0, 0, 9, 1, 0, 8, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 5, 0, 1, 8, 0, 0, 0, 3],
        [0, 0, 0, 3, 0, 6, 0, 4, 5],
        [0, 4, 0, 2, 0, 0, 0, 6, 0],
        [9, 0, 3, 0, 0, 0, 0, 0, 0],
        [0, 2, 0, 0, 0, 0, 1, 0, 0],
    ],
    [
        [5, 0, 0, 9, 0, 3, 0, 6, 7],
        [3, 0, 4, 9, 0, 0, 2, 8, 6],
        [0, 1, 7, 0, 0, 0, 0, 4, 5],
        [0, 0, 6, 7, 0, 0, 0, 0, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 1],
        [0, 0, 0, 0, 0, 5, 7, 3, 0],
        [6, 5, 0, 0, 0, 8, 0, 0, 0],
        [9, 7, 0, 0, 2, 1, 0, 0, 0],
        [0, 4, 0, 6, 5, 0, 0, 0, 0],
    ],
    [
        [0, 0, 3, 0, 2, 0, 6, 0, 0],
        [9, 0, 0, 3, 0, 5, 0, 0, 1],
        [0, 0, 1, 8, 0, 6, 4, 0, 0],
        [0, 0, 8, 1, 0, 2, 9, 0, 0],
        [7, 0, 0, 0, 0, 0, 0, 0, 8],
        [0, 0, 6, 7, 0, 8, 2, 0, 0],
        [0, 0, 2, 6, 0, 9, 5, 0, 0],
        [8, 0, 0, 2, 0, 3, 0, 0, 9],
        [0, 0, 5, 0, 1, 0, 3, 0, 0],
    ],
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=5, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=5, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "QNS_sudoku_images_5_FNT_AGILA_IMG.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file 'QNS_sudoku_images_5_FNT_AGILA_IMG.pdf' has been created successfully with all Sudoku puzzles.

# %%
#10
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [0, 2, 0, 6, 0, 8, 0, 0, 0],
        [5, 8, 0, 0, 0, 9, 7, 0, 0],
        [0, 0, 0, 0, 4, 0, 0, 0, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 0, 0, 0, 0, 0, 0, 0, 4],
        [0, 0, 8, 0, 0, 0, 0, 1, 3],
        [0, 0, 0, 0, 2, 0, 0, 0, 0],
        [0, 0, 9, 8, 0, 0, 0, 3, 6],
        [0, 0, 0, 3, 0, 6, 0, 9, 0],
    ],
    [
        [0, 0, 0, 6, 0, 0, 4, 0, 0],
        [7, 0, 0, 0, 0, 3, 6, 0, 0],
        [0, 0, 0, 0, 9, 1, 0, 8, 0],
        [3, 7, 0, 0, 0, 0, 5, 0, 0],
        [6, 5, 0, 1, 8, 0, 0, 0, 3],
        [0, 0, 0, 3, 0, 6, 0, 4, 5],
        [0, 4, 0, 2, 0, 0, 0, 6, 0],
        [9, 0, 3, 0, 0, 0, 0, 0, 0],
        [0, 2, 0, 0, 0, 0, 1, 0, 0],
    ],
    [
        [5, 0, 0, 9, 0, 3, 0, 6, 7],
        [3, 0, 4, 9, 0, 0, 2, 8, 6],
        [0, 1, 7, 0, 0, 0, 0, 4, 5],
        [0, 0, 6, 7, 0, 0, 0, 0, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 1],
        [0, 0, 0, 0, 0, 5, 7, 3, 0],
        [6, 5, 0, 0, 0, 8, 0, 0, 0],
        [9, 7, 0, 0, 2, 1, 0, 0, 0],
        [0, 4, 0, 6, 5, 0, 0, 0, 0],
    ],
    [
        [0, 0, 3, 0, 2, 0, 6, 0, 0],
        [9, 0, 0, 3, 0, 5, 0, 0, 1],
        [0, 0, 1, 8, 0, 6, 4, 0, 0],
        [0, 0, 8, 1, 0, 2, 9, 0, 0],
        [7, 0, 0, 0, 0, 0, 0, 0, 8],
        [0, 0, 6, 7, 0, 8, 2, 0, 0],
        [0, 0, 2, 6, 0, 9, 5, 0, 0],
        [8, 0, 0, 2, 0, 3, 0, 0, 9],
        [0, 0, 5, 0, 1, 0, 3, 0, 0],
    ],
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=4, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=4, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "QNS_sudoku_images_4_FNT_AGILA_IMG.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file 'QNS_sudoku_images_4_FNT_AGILA_IMG.pdf' has been created successfully with all Sudoku puzzles.

# %% [markdown]
# #ANSWERS_SUDUKO

# %%
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [5, 8, 2, 9, 1, 3, 4, 6, 7],
        [3, 6, 4, 9, 7, 5, 2, 8, 6],
        [9, 1, 7, 2, 8, 6, 3, 4, 5],
        [4, 2, 6, 7, 3, 1, 8, 5, 9],
        [8, 5, 3, 4, 6, 9, 7, 2, 1],
        [1, 7, 9, 8, 2, 5, 6, 3, 4],
        [6, 5, 8, 3, 9, 4, 1, 7, 2],
        [9, 7, 1, 5, 2, 8, 3, 4, 6],
        [2, 4, 3, 6, 5, 7, 9, 1, 8]
    ],
    [
        [4, 8, 3, 9, 2, 1, 6, 5, 7],
        [9, 6, 7, 3, 4, 5, 8, 2, 1],
        [2, 5, 1, 8, 7, 6, 4, 9, 3],
        [5, 4, 8, 1, 3, 2, 9, 7, 6],
        [7, 2, 9, 5, 6, 4, 1, 3, 8],
        [1, 3, 6, 7, 9, 8, 2, 4, 5],
        [3, 7, 2, 6, 8, 9, 5, 1, 4],
        [8, 1, 4, 2, 5, 3, 7, 6, 9],
        [6, 9, 5, 4, 1, 7, 3, 8, 2]
    ],
    [
        [1, 2, 3, 6, 7, 8, 9, 4, 5],
        [5, 8, 4, 2, 1, 9, 7, 6, 3],
        [9, 6, 7, 5, 4, 3, 1, 2, 8],
        [3, 7, 2, 4, 6, 1, 5, 8, 9],
        [6, 9, 1, 7, 8, 5, 3, 2, 4],
        [4, 5, 8, 9, 3, 2, 6, 1, 7],
        [8, 3, 6, 1, 2, 4, 9, 5, 7],
        [2, 1, 9, 8, 5, 7, 4, 3, 6],
        [7, 4, 5, 3, 9, 6, 2, 8, 1]
    ],
    [
        [5, 3, 1, 6, 7, 8, 4, 9, 2],
        [7, 9, 8, 4, 2, 3, 6, 1, 5],
        [4, 6, 2, 5, 9, 1, 3, 8, 7],
        [8, 7, 6, 9, 4, 5, 2, 3, 1],
        [2, 5, 4, 1, 8, 7, 9, 6, 3],
        [1, 8, 9, 3, 6, 2, 7, 4, 5],
        [3, 4, 5, 2, 1, 9, 8, 7, 6],
        [9, 1, 3, 7, 5, 6, 2, 4, 8],
        [6, 2, 7, 8, 3, 4, 1, 5, 9]
    ]
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(18, 18))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=33, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=33, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "_ANSWERS_sudoku_FNT_33.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file '_ANSWERS_sudoku_FNT_33.pdf' has been created successfully with all Sudoku puzzles.

# %%
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [5, 8, 2, 9, 1, 3, 4, 6, 7],
        [3, 6, 4, 9, 7, 5, 2, 8, 6],
        [9, 1, 7, 2, 8, 6, 3, 4, 5],
        [4, 2, 6, 7, 3, 1, 8, 5, 9],
        [8, 5, 3, 4, 6, 9, 7, 2, 1],
        [1, 7, 9, 8, 2, 5, 6, 3, 4],
        [6, 5, 8, 3, 9, 4, 1, 7, 2],
        [9, 7, 1, 5, 2, 8, 3, 4, 6],
        [2, 4, 3, 6, 5, 7, 9, 1, 8]
    ],
    [
        [4, 8, 3, 9, 2, 1, 6, 5, 7],
        [9, 6, 7, 3, 4, 5, 8, 2, 1],
        [2, 5, 1, 8, 7, 6, 4, 9, 3],
        [5, 4, 8, 1, 3, 2, 9, 7, 6],
        [7, 2, 9, 5, 6, 4, 1, 3, 8],
        [1, 3, 6, 7, 9, 8, 2, 4, 5],
        [3, 7, 2, 6, 8, 9, 5, 1, 4],
        [8, 1, 4, 2, 5, 3, 7, 6, 9],
        [6, 9, 5, 4, 1, 7, 3, 8, 2]
    ],
    [
        [1, 2, 3, 6, 7, 8, 9, 4, 5],
        [5, 8, 4, 2, 1, 9, 7, 6, 3],
        [9, 6, 7, 5, 4, 3, 1, 2, 8],
        [3, 7, 2, 4, 6, 1, 5, 8, 9],
        [6, 9, 1, 7, 8, 5, 3, 2, 4],
        [4, 5, 8, 9, 3, 2, 6, 1, 7],
        [8, 3, 6, 1, 2, 4, 9, 5, 7],
        [2, 1, 9, 8, 5, 7, 4, 3, 6],
        [7, 4, 5, 3, 9, 6, 2, 8, 1]
    ],
    [
        [5, 3, 1, 6, 7, 8, 4, 9, 2],
        [7, 9, 8, 4, 2, 3, 6, 1, 5],
        [4, 6, 2, 5, 9, 1, 3, 8, 7],
        [8, 7, 6, 9, 4, 5, 2, 3, 1],
        [2, 5, 4, 1, 8, 7, 9, 6, 3],
        [1, 8, 9, 3, 6, 2, 7, 4, 5],
        [3, 4, 5, 2, 1, 9, 8, 7, 6],
        [9, 1, 3, 7, 5, 6, 2, 4, 8],
        [6, 2, 7, 8, 3, 4, 1, 5, 9]
    ]
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(16, 16))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=20, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=20, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "_ANSWERS_sudoku_FNT_20.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file '_ANSWERS_sudoku_FNT_20.pdf' has been created successfully with all Sudoku puzzles.

# %%
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [5, 8, 2, 9, 1, 3, 4, 6, 7],
        [3, 6, 4, 9, 7, 5, 2, 8, 6],
        [9, 1, 7, 2, 8, 6, 3, 4, 5],
        [4, 2, 6, 7, 3, 1, 8, 5, 9],
        [8, 5, 3, 4, 6, 9, 7, 2, 1],
        [1, 7, 9, 8, 2, 5, 6, 3, 4],
        [6, 5, 8, 3, 9, 4, 1, 7, 2],
        [9, 7, 1, 5, 2, 8, 3, 4, 6],
        [2, 4, 3, 6, 5, 7, 9, 1, 8]
    ],
    [
        [4, 8, 3, 9, 2, 1, 6, 5, 7],
        [9, 6, 7, 3, 4, 5, 8, 2, 1],
        [2, 5, 1, 8, 7, 6, 4, 9, 3],
        [5, 4, 8, 1, 3, 2, 9, 7, 6],
        [7, 2, 9, 5, 6, 4, 1, 3, 8],
        [1, 3, 6, 7, 9, 8, 2, 4, 5],
        [3, 7, 2, 6, 8, 9, 5, 1, 4],
        [8, 1, 4, 2, 5, 3, 7, 6, 9],
        [6, 9, 5, 4, 1, 7, 3, 8, 2]
    ],
    [
        [1, 2, 3, 6, 7, 8, 9, 4, 5],
        [5, 8, 4, 2, 1, 9, 7, 6, 3],
        [9, 6, 7, 5, 4, 3, 1, 2, 8],
        [3, 7, 2, 4, 6, 1, 5, 8, 9],
        [6, 9, 1, 7, 8, 5, 3, 2, 4],
        [4, 5, 8, 9, 3, 2, 6, 1, 7],
        [8, 3, 6, 1, 2, 4, 9, 5, 7],
        [2, 1, 9, 8, 5, 7, 4, 3, 6],
        [7, 4, 5, 3, 9, 6, 2, 8, 1]
    ],
    [
        [5, 3, 1, 6, 7, 8, 4, 9, 2],
        [7, 9, 8, 4, 2, 3, 6, 1, 5],
        [4, 6, 2, 5, 9, 1, 3, 8, 7],
        [8, 7, 6, 9, 4, 5, 2, 3, 1],
        [2, 5, 4, 1, 8, 7, 9, 6, 3],
        [1, 8, 9, 3, 6, 2, 7, 4, 5],
        [3, 4, 5, 2, 1, 9, 8, 7, 6],
        [9, 1, 3, 7, 5, 6, 2, 4, 8],
        [6, 2, 7, 8, 3, 4, 1, 5, 9]
    ]
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(15, 15))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=14, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=14, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "_ANSWERS_sudoku_FNT_14.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file '_ANSWERS_sudoku_FNT_14.pdf' has been created successfully with all Sudoku puzzles.

# %%
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [5, 8, 2, 9, 1, 3, 4, 6, 7],
        [3, 6, 4, 9, 7, 5, 2, 8, 6],
        [9, 1, 7, 2, 8, 6, 3, 4, 5],
        [4, 2, 6, 7, 3, 1, 8, 5, 9],
        [8, 5, 3, 4, 6, 9, 7, 2, 1],
        [1, 7, 9, 8, 2, 5, 6, 3, 4],
        [6, 5, 8, 3, 9, 4, 1, 7, 2],
        [9, 7, 1, 5, 2, 8, 3, 4, 6],
        [2, 4, 3, 6, 5, 7, 9, 1, 8]
    ],
    [
        [4, 8, 3, 9, 2, 1, 6, 5, 7],
        [9, 6, 7, 3, 4, 5, 8, 2, 1],
        [2, 5, 1, 8, 7, 6, 4, 9, 3],
        [5, 4, 8, 1, 3, 2, 9, 7, 6],
        [7, 2, 9, 5, 6, 4, 1, 3, 8],
        [1, 3, 6, 7, 9, 8, 2, 4, 5],
        [3, 7, 2, 6, 8, 9, 5, 1, 4],
        [8, 1, 4, 2, 5, 3, 7, 6, 9],
        [6, 9, 5, 4, 1, 7, 3, 8, 2]
    ],
    [
        [1, 2, 3, 6, 7, 8, 9, 4, 5],
        [5, 8, 4, 2, 1, 9, 7, 6, 3],
        [9, 6, 7, 5, 4, 3, 1, 2, 8],
        [3, 7, 2, 4, 6, 1, 5, 8, 9],
        [6, 9, 1, 7, 8, 5, 3, 2, 4],
        [4, 5, 8, 9, 3, 2, 6, 1, 7],
        [8, 3, 6, 1, 2, 4, 9, 5, 7],
        [2, 1, 9, 8, 5, 7, 4, 3, 6],
        [7, 4, 5, 3, 9, 6, 2, 8, 1]
    ],
    [
        [5, 3, 1, 6, 7, 8, 4, 9, 2],
        [7, 9, 8, 4, 2, 3, 6, 1, 5],
        [4, 6, 2, 5, 9, 1, 3, 8, 7],
        [8, 7, 6, 9, 4, 5, 2, 3, 1],
        [2, 5, 4, 1, 8, 7, 9, 6, 3],
        [1, 8, 9, 3, 6, 2, 7, 4, 5],
        [3, 4, 5, 2, 1, 9, 8, 7, 6],
        [9, 1, 3, 7, 5, 6, 2, 4, 8],
        [6, 2, 7, 8, 3, 4, 1, 5, 9]
    ]
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=10, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=10, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "_ANSWERS_sudoku_FNT_10.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file '_ANSWERS_sudoku_FNT_10.pdf' has been created successfully with all Sudoku puzzles.

# %%
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [5, 8, 2, 9, 1, 3, 4, 6, 7],
        [3, 6, 4, 9, 7, 5, 2, 8, 6],
        [9, 1, 7, 2, 8, 6, 3, 4, 5],
        [4, 2, 6, 7, 3, 1, 8, 5, 9],
        [8, 5, 3, 4, 6, 9, 7, 2, 1],
        [1, 7, 9, 8, 2, 5, 6, 3, 4],
        [6, 5, 8, 3, 9, 4, 1, 7, 2],
        [9, 7, 1, 5, 2, 8, 3, 4, 6],
        [2, 4, 3, 6, 5, 7, 9, 1, 8]
    ],
    [
        [4, 8, 3, 9, 2, 1, 6, 5, 7],
        [9, 6, 7, 3, 4, 5, 8, 2, 1],
        [2, 5, 1, 8, 7, 6, 4, 9, 3],
        [5, 4, 8, 1, 3, 2, 9, 7, 6],
        [7, 2, 9, 5, 6, 4, 1, 3, 8],
        [1, 3, 6, 7, 9, 8, 2, 4, 5],
        [3, 7, 2, 6, 8, 9, 5, 1, 4],
        [8, 1, 4, 2, 5, 3, 7, 6, 9],
        [6, 9, 5, 4, 1, 7, 3, 8, 2]
    ],
    [
        [1, 2, 3, 6, 7, 8, 9, 4, 5],
        [5, 8, 4, 2, 1, 9, 7, 6, 3],
        [9, 6, 7, 5, 4, 3, 1, 2, 8],
        [3, 7, 2, 4, 6, 1, 5, 8, 9],
        [6, 9, 1, 7, 8, 5, 3, 2, 4],
        [4, 5, 8, 9, 3, 2, 6, 1, 7],
        [8, 3, 6, 1, 2, 4, 9, 5, 7],
        [2, 1, 9, 8, 5, 7, 4, 3, 6],
        [7, 4, 5, 3, 9, 6, 2, 8, 1]
    ],
    [
        [5, 3, 1, 6, 7, 8, 4, 9, 2],
        [7, 9, 8, 4, 2, 3, 6, 1, 5],
        [4, 6, 2, 5, 9, 1, 3, 8, 7],
        [8, 7, 6, 9, 4, 5, 2, 3, 1],
        [2, 5, 4, 1, 8, 7, 9, 6, 3],
        [1, 8, 9, 3, 6, 2, 7, 4, 5],
        [3, 4, 5, 2, 1, 9, 8, 7, 6],
        [9, 1, 3, 7, 5, 6, 2, 4, 8],
        [6, 2, 7, 8, 3, 4, 1, 5, 9]
    ]
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=8, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=8, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "_ANSWERS_sudoku_FNT_8.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file '_ANSWERS_sudoku_FNT_8.pdf' has been created successfully with all Sudoku puzzles.

# %%
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [5, 8, 2, 9, 1, 3, 4, 6, 7],
        [3, 6, 4, 9, 7, 5, 2, 8, 6],
        [9, 1, 7, 2, 8, 6, 3, 4, 5],
        [4, 2, 6, 7, 3, 1, 8, 5, 9],
        [8, 5, 3, 4, 6, 9, 7, 2, 1],
        [1, 7, 9, 8, 2, 5, 6, 3, 4],
        [6, 5, 8, 3, 9, 4, 1, 7, 2],
        [9, 7, 1, 5, 2, 8, 3, 4, 6],
        [2, 4, 3, 6, 5, 7, 9, 1, 8]
    ],
    [
        [4, 8, 3, 9, 2, 1, 6, 5, 7],
        [9, 6, 7, 3, 4, 5, 8, 2, 1],
        [2, 5, 1, 8, 7, 6, 4, 9, 3],
        [5, 4, 8, 1, 3, 2, 9, 7, 6],
        [7, 2, 9, 5, 6, 4, 1, 3, 8],
        [1, 3, 6, 7, 9, 8, 2, 4, 5],
        [3, 7, 2, 6, 8, 9, 5, 1, 4],
        [8, 1, 4, 2, 5, 3, 7, 6, 9],
        [6, 9, 5, 4, 1, 7, 3, 8, 2]
    ],
    [
        [1, 2, 3, 6, 7, 8, 9, 4, 5],
        [5, 8, 4, 2, 1, 9, 7, 6, 3],
        [9, 6, 7, 5, 4, 3, 1, 2, 8],
        [3, 7, 2, 4, 6, 1, 5, 8, 9],
        [6, 9, 1, 7, 8, 5, 3, 2, 4],
        [4, 5, 8, 9, 3, 2, 6, 1, 7],
        [8, 3, 6, 1, 2, 4, 9, 5, 7],
        [2, 1, 9, 8, 5, 7, 4, 3, 6],
        [7, 4, 5, 3, 9, 6, 2, 8, 1]
    ],
    [
        [5, 3, 1, 6, 7, 8, 4, 9, 2],
        [7, 9, 8, 4, 2, 3, 6, 1, 5],
        [4, 6, 2, 5, 9, 1, 3, 8, 7],
        [8, 7, 6, 9, 4, 5, 2, 3, 1],
        [2, 5, 4, 1, 8, 7, 9, 6, 3],
        [1, 8, 9, 3, 6, 2, 7, 4, 5],
        [3, 4, 5, 2, 1, 9, 8, 7, 6],
        [9, 1, 3, 7, 5, 6, 2, 4, 8],
        [6, 2, 7, 8, 3, 4, 1, 5, 9]
    ]
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=6, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=6, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "_ANSWERS_sudoku_FNT_6.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file '_ANSWERS_sudoku_FNT_6.pdf' has been created successfully with all Sudoku puzzles.

# %%
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [5, 8, 2, 9, 1, 3, 4, 6, 7],
        [3, 6, 4, 9, 7, 5, 2, 8, 6],
        [9, 1, 7, 2, 8, 6, 3, 4, 5],
        [4, 2, 6, 7, 3, 1, 8, 5, 9],
        [8, 5, 3, 4, 6, 9, 7, 2, 1],
        [1, 7, 9, 8, 2, 5, 6, 3, 4],
        [6, 5, 8, 3, 9, 4, 1, 7, 2],
        [9, 7, 1, 5, 2, 8, 3, 4, 6],
        [2, 4, 3, 6, 5, 7, 9, 1, 8]
    ],
    [
        [4, 8, 3, 9, 2, 1, 6, 5, 7],
        [9, 6, 7, 3, 4, 5, 8, 2, 1],
        [2, 5, 1, 8, 7, 6, 4, 9, 3],
        [5, 4, 8, 1, 3, 2, 9, 7, 6],
        [7, 2, 9, 5, 6, 4, 1, 3, 8],
        [1, 3, 6, 7, 9, 8, 2, 4, 5],
        [3, 7, 2, 6, 8, 9, 5, 1, 4],
        [8, 1, 4, 2, 5, 3, 7, 6, 9],
        [6, 9, 5, 4, 1, 7, 3, 8, 2]
    ],
    [
        [1, 2, 3, 6, 7, 8, 9, 4, 5],
        [5, 8, 4, 2, 1, 9, 7, 6, 3],
        [9, 6, 7, 5, 4, 3, 1, 2, 8],
        [3, 7, 2, 4, 6, 1, 5, 8, 9],
        [6, 9, 1, 7, 8, 5, 3, 2, 4],
        [4, 5, 8, 9, 3, 2, 6, 1, 7],
        [8, 3, 6, 1, 2, 4, 9, 5, 7],
        [2, 1, 9, 8, 5, 7, 4, 3, 6],
        [7, 4, 5, 3, 9, 6, 2, 8, 1]
    ],
    [
        [5, 3, 1, 6, 7, 8, 4, 9, 2],
        [7, 9, 8, 4, 2, 3, 6, 1, 5],
        [4, 6, 2, 5, 9, 1, 3, 8, 7],
        [8, 7, 6, 9, 4, 5, 2, 3, 1],
        [2, 5, 4, 1, 8, 7, 9, 6, 3],
        [1, 8, 9, 3, 6, 2, 7, 4, 5],
        [3, 4, 5, 2, 1, 9, 8, 7, 6],
        [9, 1, 3, 7, 5, 6, 2, 4, 8],
        [6, 2, 7, 8, 3, 4, 1, 5, 9]
    ]
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=5, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=5, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "_ANSWERS_sudoku_FNT_5.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file '_ANSWERS_sudoku_FNT_5.pdf' has been created successfully with all Sudoku puzzles.

# %%
import matplotlib.pyplot as plt
import numpy as np
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from PIL import Image

# Sample Sudoku puzzles
sudoku_puzzles = [
    [
        [5, 8, 2, 9, 1, 3, 4, 6, 7],
        [3, 6, 4, 9, 7, 5, 2, 8, 6],
        [9, 1, 7, 2, 8, 6, 3, 4, 5],
        [4, 2, 6, 7, 3, 1, 8, 5, 9],
        [8, 5, 3, 4, 6, 9, 7, 2, 1],
        [1, 7, 9, 8, 2, 5, 6, 3, 4],
        [6, 5, 8, 3, 9, 4, 1, 7, 2],
        [9, 7, 1, 5, 2, 8, 3, 4, 6],
        [2, 4, 3, 6, 5, 7, 9, 1, 8]
    ],
    [
        [4, 8, 3, 9, 2, 1, 6, 5, 7],
        [9, 6, 7, 3, 4, 5, 8, 2, 1],
        [2, 5, 1, 8, 7, 6, 4, 9, 3],
        [5, 4, 8, 1, 3, 2, 9, 7, 6],
        [7, 2, 9, 5, 6, 4, 1, 3, 8],
        [1, 3, 6, 7, 9, 8, 2, 4, 5],
        [3, 7, 2, 6, 8, 9, 5, 1, 4],
        [8, 1, 4, 2, 5, 3, 7, 6, 9],
        [6, 9, 5, 4, 1, 7, 3, 8, 2]
    ],
    [
        [1, 2, 3, 6, 7, 8, 9, 4, 5],
        [5, 8, 4, 2, 1, 9, 7, 6, 3],
        [9, 6, 7, 5, 4, 3, 1, 2, 8],
        [3, 7, 2, 4, 6, 1, 5, 8, 9],
        [6, 9, 1, 7, 8, 5, 3, 2, 4],
        [4, 5, 8, 9, 3, 2, 6, 1, 7],
        [8, 3, 6, 1, 2, 4, 9, 5, 7],
        [2, 1, 9, 8, 5, 7, 4, 3, 6],
        [7, 4, 5, 3, 9, 6, 2, 8, 1]
    ],
    [
        [5, 3, 1, 6, 7, 8, 4, 9, 2],
        [7, 9, 8, 4, 2, 3, 6, 1, 5],
        [4, 6, 2, 5, 9, 1, 3, 8, 7],
        [8, 7, 6, 9, 4, 5, 2, 3, 1],
        [2, 5, 4, 1, 8, 7, 9, 6, 3],
        [1, 8, 9, 3, 6, 2, 7, 4, 5],
        [3, 4, 5, 2, 1, 9, 8, 7, 6],
        [9, 1, 3, 7, 5, 6, 2, 4, 8],
        [6, 2, 7, 8, 3, 4, 1, 5, 9]
    ]
]

colors = ['#E5FFCC']

# Function to draw a single Sudoku puzzle
def draw_sudoku(sudoku_puzzle, color, filename):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.set_xlim(0, 9)
    ax.set_ylim(0, 9)

    # Draw grid lines
    for i in range(10):
        lw = 2 if i % 3 == 0 else 1
        ax.axhline(i, color=color, lw=lw)
        ax.axvline(i, color=color, lw=lw)

    # Fill in the Sudoku numbers with adjusted font size
    for row in range(9):
        for col in range(9):
            num = sudoku_puzzle[row][col]
            if num != 0:
                ax.text(col + 0.5, 8.5 - row, str(num), ha='center', va='center', fontsize=4, color=color)

    # Add title with adjusted font size
    plt.text(4.5, 9.5, 'Sudoku puzzle', ha='center', va='center', fontsize=4, color=color, weight='bold')

    # Hide axis
    ax.axis('off')

    # Save the plot as a PNG image
    plt.savefig(filename, dpi=300, bbox_inches='tight')

    # Show the plot
    plt.close()

# Generate images for Sudoku puzzles
image_filenames = []
for i, puzzle in enumerate(sudoku_puzzles):
    for color in colors:
        filename = f"sudoku_{color.replace('#', '')}_{i + 1}.png"
        draw_sudoku(puzzle, color, filename)
        image_filenames.append(filename)

# Create PDF with images
pdf_filename = "_ANSWERS_sudoku_FNT_4.pdf"
pdf = canvas.Canvas(pdf_filename, pagesize=letter)

for image_filename in image_filenames:
    pdf.drawImage(image_filename, 0, 0, width=letter[0], height=letter[1])
    pdf.showPage()

pdf.save()

print(f"PDF file '{pdf_filename}' has been created successfully with all Sudoku puzzles.")
# Out:
# PDF file '_ANSWERS_sudoku_FNT_4.pdf' has been created successfully with all Sudoku puzzles.
